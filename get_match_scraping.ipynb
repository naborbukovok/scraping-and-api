# %% [markdown]
# ### Scraping (GetMatch)

# %%
import pandas as pd
import re
import requests
from bs4 import BeautifulSoup

# %% [markdown]
# Ссылка страницы в списке вакансий имеет вид ```https://getmatch.ru/vacancies?p={page}```, при этом если ввести слишком большой номер страницы, она отображается корректно, просто без вакансий. Поэтому, чтобы собрать все ссылки, будем идти по страницам до тех пор, пока на них есть вакансии.

# %%
def get_page_vacancies_urls(page):
    page_url = f'https://getmatch.ru/vacancies?p={page}'

    page = requests.get(page_url)
    if page.status_code != 200:
        return

    page_vacancies_urls = []

    soup = BeautifulSoup(page.content, 'html.parser')

    for link in soup.find_all('a'):
        if '?s=offers' in link.get('href') and link.get('href').startswith('/vacancies'):
            page_vacancies_urls.append(link.get('href'))

    return page_vacancies_urls

# %%
vacancies_urls = []
page = 1

while True:
    page_vacancies_urls = get_page_vacancies_urls(page)

    if not page_vacancies_urls:
        break

    vacancies_urls.extend(page_vacancies_urls)
    page += 1

print(vacancies_urls)

# %% [markdown]
# Проверим, что собрали. Действительно, на момент выполнения кода на сайте было 1203 вакансий и 2 рекламные страницы (которые имеют такую же ссылку, как вакансии). Итого 1205.

# %%
len(vacancies_urls)

# %% [markdown]
# Изучим полученную разметку на примере одной ссылки. Напишем функцию для сбора информации по конкретной вакансии.

# %%
vacancy = requests.get(f'https://getmatch.ru{vacancies_urls[6]}')
soup = BeautifulSoup(vacancy.content, 'html.parser')
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html dir="ltr" lang="ru">
#  <head>
#   <link crossorigin="" href="https://fonts.gstatic.com" rel="preconnect"/>
#   <meta charset="utf-8"/>
#   <title>
#    Вакансия Affiliate Manager, работа в Winline, в Москве — getmatch
#   </title>
#   <base href="/"/>
#   <meta content="width=device-width, initial-scale=1, maximum-scale=1" name="viewport"/>
#   <meta content="#ffffff" name="theme-color"/>
#   <link href="/uploads/favicons/favicon.svg" rel="icon"/>
#   <link color="#205AED" href="/uploads/favicons/mask-icon.svg" rel="mask-icon"/>
#   <link href="/uploads/favicons/apple-touch-icon.png" rel="apple-touch-icon"/>
#   <link href="/uploads/favicons/manifest.json" rel="manifest"/>
#   <link href="/uploads/favicons/favicon.ico" rel="shortcut icon"/>
#   <style type="text/css">
#    @font-face{font-family:'Montserrat';font-style:normal;font-weight:300;font-display:swap;src:url(https://fonts.gstatic.com/s/montserrat/v29/JTUSjIg1_i6t8kCHKm459WRhyyTh89ZNpQ.woff2) format('woff2');unicode-range:U+0460-052F, U+1C80-1C8A, U+20B4, U+2DE0-2DFF, U+A640-A69F, U+FE2E-FE2F;}@font-face{font-family:'Montserrat';font-style:normal;font-weight:300;font-display:swap;src:url(https://fonts.gstatic.com/s/montserrat/v29/JTUSjIg1_i6t8kCHKm459W1hyyTh89ZNpQ.woff2) format('woff2');unicode-range:U+0301, U+0400-045F, U+0490-0491, U+04B0-04B1, U+2116;}@font-face{font-family:'Montserrat';font-style:normal;font-weight:300;font-display:swap;src:url(https://fonts.gstatic.com/s/montserrat/v29/JTUSjIg1_i6t8kCHKm459WZhyyTh89ZNpQ.woff2) format('woff2');unicode-range:U+0102-0103, U+0110-0111, U+0128-0129, U+0168-0169, U+01A0-01A1, U+01AF-01B0, U+0300-0301, U+0303-0304, U+0308-0309, U+0323, U+0329, U+1EA0-1EF9, U+20AB;}@font-face{font-family:'Montserrat';font-style:normal;font-weight:300;font-display:swap;src:url(https://fonts.gstatic.com/s/montserrat/v29/JTUSjIg1_i6t8kCHKm459WdhyyTh89ZNpQ.woff2) format('woff2');unicode-range:U+0100-02BA, U+02BD-02C5, U+02C7-02CC, U+02CE-02D7, U+02DD-02FF, U+0304, U+0308, U+0329, U+1D00-1DBF, U+1E00-1E9F, U+1EF2-1EFF, U+2020, U+20A0-20AB, U+20AD-20C0, U+2113, U+2C60-2C7F, U+A720-A7FF;}@font-face{font-family:'Montserrat';font-style:normal;font-weight:300;font-display:swap;src:url(https://fonts.gstatic.com/s/montserrat/v29/JTUSjIg1_i6t8kCHKm459WlhyyTh89Y.woff2) format('woff2');unicode-range:U+0000-00FF, U+0131, U+0152-0153, U+02BB-02BC, U+02C6, U+02DA, U+02DC, U+0304, U+0308, U+0329, U+2000-206F, U+20AC, U+2122, U+2191, U+2193, U+2212, U+2215, U+FEFF, U+FFFD;}@font-face{font-family:'Montserrat';font-style:normal;font-weight:400;font-display:swap;src:url(https://fonts.gstatic.com/s/montserrat/v29/JTUSjIg1_i6t8kCHKm459WRhyyTh89ZNpQ.woff2) format('woff2');unicode-range:U+0460-052F, U+1C80-1C8A, U+20B4, U+2DE0-2DFF, U+A640-A69F, U+FE2E-FE2F;}@font-face{font-family:'Montserrat';font-style:normal;font-weight:400;font-display:swap;src:url(https://fonts.gstatic.com/s/montserrat/v29/JTUSjIg1_i6t8kCHKm459W1hyyTh89ZNpQ.woff2) format('woff2');unicode-range:U+0301, U+0400-045F, U+0490-0491, U+04B0-04B1, U+2116;}@font-face{font-family:'Montserrat';font-style:normal;font-weight:400;font-display:swap;src:url(https://fonts.gstatic.com/s/montserrat/v29/JTUSjIg1_i6t8kCHKm459WZhyyTh89ZNpQ.woff2) format('woff2');unicode-range:U+0102-0103, U+0110-0111, U+0128-0129, U+0168-0169, U+01A0-01A1, U+01AF-01B0, U+0300-0301, U+0303-0304, U+0308-0309, U+0323, U+0329, U+1EA0-1EF9, U+20AB;}@font-face{font-family:'Montserrat';font-style:normal;font-weight:400;font-display:swap;src:url(https://fonts.gstatic.com/s/montserrat/v29/JTUSjIg1_i6t8kCHKm459WdhyyTh89ZNpQ.woff2) format('woff2');unicode-range:U+0100-02BA, U+02BD-02C5, U+02C7-02CC, U+02CE-02D7, U+02DD-02FF, U+0304, U+0308, U+0329, U+1D00-1DBF, U+1E00-1E9F, U+1EF2-1EFF, U+2020, U+20A0-20AB, U+20AD-20C0, U+2113, U+2C60-2C7F, U+A720-A7FF;}@font-face{font-family:'Montserrat';font-style:normal;font-weight:400;font-display:swap;src:url(https://fonts.gstatic.com/s/montserrat/v29/JTUSjIg1_i6t8kCHKm459WlhyyTh89Y.woff2) format('woff2');unicode-range:U+0000-00FF, U+0131, U+0152-0153, U+02BB-02BC, U+02C6, U+02DA, U+02DC, U+0304, U+0308, U+0329, U+2000-206F, U+20AC, U+2122, U+2191, U+2193, U+2212, U+2215, U+FEFF, U+FFFD;}@font-face{font-family:'Montserrat';font-style:normal;font-weight:500;font-display:swap;src:url(https://fonts.gstatic.com/s/montserrat/v29/JTUSjIg1_i6t8kCHKm459WRhyyTh89ZNpQ.woff2) format('woff2');unicode-range:U+0460-052F, U+1C80-1C8A, U+20B4, U+2DE0-2DFF, U+A640-A69F, U+FE2E-FE2F;}@font-face{font-family:'Montserrat';font-style:normal;font-weight:500;font-display:swap;src:url(https://fonts.gstatic.com/s/montserrat/v29/JTUSjIg1_i6t8kCHKm459W1hyyTh89ZNpQ.woff2) format('woff2');unicode-range:U+0301, U+0400-045F, U+0490-0491, U+04B0-04B1, U+2116;}@font-face{font-family:'Montserrat';font-st ...
#   </style>
#   <style type="text/css">
#    @font-face{font-family:'Inter';font-style:normal;font-weight:400;font-display:swap;src:url(https://fonts.gstatic.com/s/inter/v18/UcC73FwrK3iLTeHuS_nVMrMxCp50SjIa2JL7W0Q5n-wU.woff2) format('woff2');unicode-range:U+0460-052F, U+1C80-1C8A, U+20B4, U+2DE0-2DFF, U+A640-A69F, U+FE2E-FE2F;}@font-face{font-family:'Inter';font-style:normal;font-weight:400;font-display:swap;src:url(https://fonts.gstatic.com/s/inter/v18/UcC73FwrK3iLTeHuS_nVMrMxCp50SjIa0ZL7W0Q5n-wU.woff2) format('woff2');unicode-range:U+0301, U+0400-045F, U+0490-0491, U+04B0-04B1, U+2116;}@font-face{font-family:'Inter';font-style:normal;font-weight:400;font-display:swap;src:url(https://fonts.gstatic.com/s/inter/v18/UcC73FwrK3iLTeHuS_nVMrMxCp50SjIa2ZL7W0Q5n-wU.woff2) format('woff2');unicode-range:U+1F00-1FFF;}@font-face{font-family:'Inter';font-style:normal;font-weight:400;font-display:swap;src:url(https://fonts.gstatic.com/s/inter/v18/UcC73FwrK3iLTeHuS_nVMrMxCp50SjIa1pL7W0Q5n-wU.woff2) format('woff2');unicode-range:U+0370-0377, U+037A-037F, U+0384-038A, U+038C, U+038E-03A1, U+03A3-03FF;}@font-face{font-family:'Inter';font-style:normal;font-weight:400;font-display:swap;src:url(https://fonts.gstatic.com/s/inter/v18/UcC73FwrK3iLTeHuS_nVMrMxCp50SjIa2pL7W0Q5n-wU.woff2) format('woff2');unicode-range:U+0102-0103, U+0110-0111, U+0128-0129, U+0168-0169, U+01A0-01A1, U+01AF-01B0, U+0300-0301, U+0303-0304, U+0308-0309, U+0323, U+0329, U+1EA0-1EF9, U+20AB;}@font-face{font-family:'Inter';font-style:normal;font-weight:400;font-display:swap;src:url(https://fonts.gstatic.com/s/inter/v18/UcC73FwrK3iLTeHuS_nVMrMxCp50SjIa25L7W0Q5n-wU.woff2) format('woff2');unicode-range:U+0100-02BA, U+02BD-02C5, U+02C7-02CC, U+02CE-02D7, U+02DD-02FF, U+0304, U+0308, U+0329, U+1D00-1DBF, U+1E00-1E9F, U+1EF2-1EFF, U+2020, U+20A0-20AB, U+20AD-20C0, U+2113, U+2C60-2C7F, U+A720-A7FF;}@font-face{font-family:'Inter';font-style:normal;font-weight:400;font-display:swap;src:url(https://fonts.gstatic.com/s/inter/v18/UcC73FwrK3iLTeHuS_nVMrMxCp50SjIa1ZL7W0Q5nw.woff2) format('woff2');unicode-range:U+0000-00FF, U+0131, U+0152-0153, U+02BB-02BC, U+02C6, U+02DA, U+02DC, U+0304, U+0308, U+0329, U+2000-206F, U+20AC, U+2122, U+2191, U+2193, U+2212, U+2215, U+FEFF, U+FFFD;}@font-face{font-family:'Inter';font-style:normal;font-weight:500;font-display:swap;src:url(https://fonts.gstatic.com/s/inter/v18/UcC73FwrK3iLTeHuS_nVMrMxCp50SjIa2JL7W0Q5n-wU.woff2) format('woff2');unicode-range:U+0460-052F, U+1C80-1C8A, U+20B4, U+2DE0-2DFF, U+A640-A69F, U+FE2E-FE2F;}@font-face{font-family:'Inter';font-style:normal;font-weight:500;font-display:swap;src:url(https://fonts.gstatic.com/s/inter/v18/UcC73FwrK3iLTeHuS_nVMrMxCp50SjIa0ZL7W0Q5n-wU.woff2) format('woff2');unicode-range:U+0301, U+0400-045F, U+0490-0491, U+04B0-04B1, U+2116;}@font-face{font-family:'Inter';font-style:normal;font-weight:500;font-display:swap;src:url(https://fonts.gstatic.com/s/inter/v18/UcC73FwrK3iLTeHuS_nVMrMxCp50SjIa2ZL7W0Q5n-wU.woff2) format('woff2');unicode-range:U+1F00-1FFF;}@font-face{font-family:'Inter';font-style:normal;font-weight:500;font-display:swap;src:url(https://fonts.gstatic.com/s/inter/v18/UcC73FwrK3iLTeHuS_nVMrMxCp50SjIa1pL7W0Q5n-wU.woff2) format('woff2');unicode-range:U+0370-0377, U+037A-037F, U+0384-038A, U+038C, U+038E-03A1, U+03A3-03FF;}@font-face{font-family:'Inter';font-style:normal;font-weight:500;font-display:swap;src:url(https://fonts.gstatic.com/s/inter/v18/UcC73FwrK3iLTeHuS_nVMrMxCp50SjIa2pL7W0Q5n-wU.woff2) format('woff2');unicode-range:U+0102-0103, U+0110-0111, U+0128-0129, U+0168-0169, U+01A0-01A1, U+01AF-01B0, U+0300-0301, U+0303-0304, U+0308-0309, U+0323, U+0329, U+1EA0-1EF9, U+20AB;}@font-face{font-family:'Inter';font-style:normal;font-weight:500;font-display:swap;src:url(https://fonts.gstatic.com/s/inter/v18/UcC73FwrK3iLTeHuS_nVMrMxCp50SjIa25L7W0Q5n-wU.woff2) format('woff2');unicode-range:U+0100-02BA, U+02BD-02C5, U+02C7-02CC, U+02CE-02D7, U+02DD-02FF, U+0304, U+0308, U+0329, U+1D00-1DBF, U+1E00-1E9F, U+1EF2-1EFF, U+2020, U+20A0-20AB, U+2 ...
#   </style>
#   <link crossorigin="anonymous" href="https://cdn.jsdelivr.net/npm/bootstrap@4.3.1/dist/css/bootstrap.min.css" integrity="sha384-ggOyR0iXCbMQv3Xipma34MD+dH/1fQ784/j6cY/iJTQUOhcWr7x9JvoRxT2MZw1T" rel="stylesheet"/>
#   <!-- Yandex Captcha -->
#   <script defer="" src="https://captcha-api.yandex.ru/captcha.js?render=onload&amp;onload=onloadFunction">
#   </script>
#   <script>
#    function onloadFunction() {
#         if (!window.smartCaptcha) {
#           return;
#         }
#         const event = document.createEvent('Event');
#         event.initEvent('captchaLoaded', true, true);
#         document.dispatchEvent(event);
#       }
#   </script>
#   <!-- Global site tag (gtag.js) - Google Analytics -->
#   <script async="" src="https://www.googletagmanager.com/gtag/js?id=UA-73568666-2">
#   </script>
#   <script>
#    window.dataLayer = window.dataLayer || [];
#       function gtag() {
#         dataLayer.push(arguments);
#       }
#       gtag('js', new Date());
#
#       gtag('config', 'UA-73568666-2', { send_page_view: false });
#   </script>
#   <script type="text/javascript">
#    (function (m, e, t, r, i, k, a) {
#         m[i] =
#           m[i] ||
#           function () {
#             (m[i].a = m[i].a || []).push(arguments);
#           };
#         m[i].l = 1 * new Date();
#         (k = e.createElement(t)),
#           (a = e.getElementsByTagName(t)[0]),
#           (k.async = 1),
#           (k.src = r),
#           a.parentNode.insertBefore(k, a);
#       })(
#         window,
#         document,
#         'script',
#         'https://mc.yandex.ru/metrika/tag.js',
#         'ym'
#       );
#   </script>
#   <noscript>
#    <div>
#     <img alt="" src="https://mc.yandex.ru/watch/64867504" style="position: absolute; left: -9999px"/>
#    </div>
#   </noscript>
#   <link href="/static-ssr/styles.51f39d6c7513b973.css" rel="stylesheet"/>
#   <style ng-app-id="serverApp">
#    h1,.fs-header-1{font-family:Montserrat;font-style:normal;font-weight:700;font-size:36px;line-height:44px;letter-spacing:normal}h2,.fs-header-2{font-family:Montserrat;font-style:normal;font-weight:700;font-size:24px;line-height:32px;letter-spacing:normal}h3,.fs-header-3{font-family:Montserrat;font-style:normal;font-weight:700;font-size:18px;line-height:24px;letter-spacing:normal}h4,.fs-header-4{font-family:Montserrat;font-style:normal;font-weight:600;font-size:15px;line-height:20px;letter-spacing:normal}h5,.fs-header-5{font-family:Montserrat;font-style:normal;font-weight:600;font-size:14px;line-height:20px;letter-spacing:normal}h6,.fs-subheader{font-family:Inter;font-style:normal;font-weight:500;font-size:14px;line-height:18px;letter-spacing:-.24px}.fs-body-1{font-family:Inter;font-style:normal;font-weight:400;font-size:15px;line-height:24px;letter-spacing:-.24px}.fs-body-2{font-family:Inter;font-style:normal;font-weight:400;font-size:14px;line-height:18px;letter-spacing:normal}.fs-label{font-family:Inter;font-style:normal;font-weight:500;font-size:11px;line-height:13px;letter-spacing:1px;text-transform:uppercase}a,.fs-link{color:#205aed;text-decoration:none;outline:none}a:hover,.fs-link:hover{color:#205aed;text-decoration:underline}a:focus,a:active,.fs-link:focus,.fs-link:active{color:#8000ff}a.no-decoration,.fs-link.no-decoration,a.no-decoration:hover,.fs-link.no-decoration:hover{text-decoration:none}.muted{color:#6c7377}.text-w-600{font-weight:600}.g-btn{display:inline-block;min-width:120px;height:40px;padding:10px 24px;border-radius:6px;border:none;outline:none;cursor:pointer;font-family:Montserrat;font-style:normal;font-weight:600;font-size:15px;line-height:20px;letter-spacing:-.24px;text-align:center;transition:background-color .2s ease-in-out,color .2s ease-in-out}.g-btn:focus{outline:none}.g-btn+.g-btn{margin-left:12px}.g-btn .icon{display:inline-block;width:20px;height:20px;margin-right:8px;margin-top:-2px;transition:filter .2s ease-in-out}.g-btn .icon-16{width:16px;height:16px}.g-btn-xs{height:32px;padding:6px 16px;font-family:Montserrat;font-style:normal;font-weight:600;font-size:14px;line-height:20px;letter-spacing:normal}.g-btn-sm{height:36px;padding:8px 12px;font-family:Montserrat;font-style:normal;font-weight:600;font-size:14px;line-height:20px;letter-spacing:-.24px}.g-btn-sm .icon{width:18px;height:18px}.g-btn-lg{height:48px;padding:14px 24px;min-width:149px}.g-btn-lg .icon{width:24px;height:24px}.g-btn-primary{background-color:#0c2231;color:#fff!important}.g-btn-primary .icon:not(.no-filter){filter:brightness(0) invert(100%)}.g-btn-primary:hover{background-color:#ffe953;color:#0c2231!important;text-decoration:none!important}.g-btn-primary:hover .icon:not(.no-filter){filter:brightness(0) saturate(100%) invert(10%) sepia(13%) saturate(2706%) hue-rotate(161deg) brightness(98%) contrast(96%)}.g-btn-primary:active{background-color:#ffe953;color:#6c7377!important;outline:none}.g-btn-primary:active .icon:not(.no-filter){filter:brightness(0) saturate(100%) invert(46%) sepia(9%) saturate(283%) hue-rotate(158deg) brightness(95%) contrast(90%)}.g-btn-primary[disabled]{cursor:not-allowed;background-color:#eff2f3;color:#9ca2a6!important}.g-btn-primary[disabled] .icon:not(.no-filter){filter:brightness(0) saturate(100%) invert(74%) sepia(7%) saturate(224%) hue-rotate(161deg) brightness(87%) contrast(88%)}.g-btn-primary[disabled]:hover{color:#9ca2a6!important}.g-btn-primary[disabled]:hover .icon:not(.no-filter){filter:brightness(0) saturate(100%) invert(74%) sepia(7%) saturate(224%) hue-rotate(161deg) brightness(87%) contrast(88%)}.g-btn-secondary{background-color:#eff2f3;color:#0c2231!important}.g-btn-secondary .icon:not(.no-filter){filter:brightness(0) saturate(100%) invert(10%) sepia(13%) saturate(2706%) hue-rotate(161deg) brightness(98%) contrast(96%)}.g-btn-secondary:hover{background-color:#e3e4e5;color:#0c2231!important;text-decoration:none!important}.g-btn-secondary:hover .icon:not(.no-filter){filter:brightness(0) sa ...
#   </style>
#   <style ng-app-id="serverApp">
#    .page-container[_ngcontent-serverApp-c1263125476]{min-height:calc(100vh - 418px)}.page-container--anonymous[_ngcontent-serverApp-c1263125476]{min-height:calc(100vh - 390px)}.page-container--no-footer[_ngcontent-serverApp-c1263125476]{min-height:unset}@media (max-width: 768px){.page-container[_ngcontent-serverApp-c1263125476]{min-height:100vh}.page-container--no-footer[_ngcontent-serverApp-c1263125476]{min-height:unset}}
#   </style>
#   <style ng-app-id="serverApp">
#    .b-header[_ngcontent-serverApp-c708908426]{background:#ffffff;height:91px}@media (min-width: 769px){.b-header[_ngcontent-serverApp-c708908426]{height:92px;border-bottom:1px solid #e3e4e5}}.b-header[_ngcontent-serverApp-c708908426]   .container[_ngcontent-serverApp-c708908426]{display:flex;align-items:center;flex-direction:row;height:100%}.b-header__logotype[_ngcontent-serverApp-c708908426]{display:block;width:134px;height:28px;background:url(/static/img/getmatch-logo.svg) no-repeat 0 0;background-size:contain;border:none;outline:none;margin-right:51px}@media (max-width: 768px){.b-header__logotype[_ngcontent-serverApp-c708908426]{margin-right:auto}}.b-header__navigation[_ngcontent-serverApp-c708908426]{display:flex;flex-wrap:nowrap;margin-right:auto;height:20px}.b-header__navigation-link[_ngcontent-serverApp-c708908426]{font-family:Montserrat;font-style:normal;font-weight:500;font-size:14px;line-height:18px;letter-spacing:normal;white-space:nowrap;color:#0c2231;margin-left:20px;position:relative}.b-header__navigation-link[_ngcontent-serverApp-c708908426]:hover, .b-header__navigation-link[_ngcontent-serverApp-c708908426]:active, .b-header__navigation-link[_ngcontent-serverApp-c708908426]:focus{text-decoration:none;color:#0c2231}.b-header__navigation-link[_ngcontent-serverApp-c708908426]:first-of-type{margin-left:0}.b-header__navigation-link[_ngcontent-serverApp-c708908426]:before{content:" ";position:absolute;width:0;border-bottom:1px solid #0c2231;top:55px;left:50%;transform:translate(-50%);transition:width .2s}.b-header__navigation-link--active[_ngcontent-serverApp-c708908426]:before{width:100%}@media (max-width: 768px){.b-header__navigation[_ngcontent-serverApp-c708908426]{display:none}}.b-header__buttons[_ngcontent-serverApp-c708908426]{white-space:nowrap}.b-header__buttons-digest[_ngcontent-serverApp-c708908426], .b-header__buttons-vacancy[_ngcontent-serverApp-c708908426]{padding:11px 16px;letter-spacing:-.408px;line-height:18px}.b-header__buttons-digest[_ngcontent-serverApp-c708908426]:hover, .b-header__buttons-vacancy[_ngcontent-serverApp-c708908426]:hover{background-color:#0c2231;color:#fff!important}.b-header__buttons-telegram[_ngcontent-serverApp-c708908426]   img[_ngcontent-serverApp-c708908426]{margin-top:-4px}.b-header__buttons-invite[_ngcontent-serverApp-c708908426]{margin-left:20px}.b-header__buttons-invite__button[_ngcontent-serverApp-c708908426]{font-family:Montserrat;font-style:normal;font-weight:600;font-size:15px;line-height:18px;letter-spacing:-.408px;text-align:center;color:#0c2231;background-color:transparent;transition:color .2s;cursor:pointer;text-transform:none;overflow:visible;border-radius:0;border:none;outline:none;margin-bottom:5px}.b-header__buttons-invite__button[_ngcontent-serverApp-c708908426]:hover{color:#6c7377}@media (max-width: 992px){.b-header__buttons-invite[_ngcontent-serverApp-c708908426], .b-header__buttons-telegram[_ngcontent-serverApp-c708908426], .b-header__buttons-vacancy--desktop[_ngcontent-serverApp-c708908426], .b-header__buttons-login[_ngcontent-serverApp-c708908426]{display:none}}.b-header__buttons-vacancy--mobile[_ngcontent-serverApp-c708908426]{display:none;padding:8px 12px;font-size:14px;line-height:20px;letter-spacing:-.408px}@media (max-width: 768px){.b-header__buttons-vacancy--mobile[_ngcontent-serverApp-c708908426]{display:inline-block}.b-header__buttons-digest[_ngcontent-serverApp-c708908426]{padding:8px 12px;font-size:14px;line-height:20px;letter-spacing:-.408px;height:36px}}.b-header__user-block-candidate[_ngcontent-serverApp-c708908426]{margin-left:28px;display:flex;align-items:center;height:40px}.b-header__user-block-candidate__avatar[_ngcontent-serverApp-c708908426]{display:inline-block;width:40px;height:40px;background:#0c2231;color:#fff;border-radius:500px;text-align:center;font-family:Montserrat;font-style:normal;font-weight:600;font-size:15px;line-height:40px;letter-spacing:-.41px;text-transform:uppercase;overflow:hidden}.b-header__user-block-candidate__avat ...
#   </style>
#   <style ng-app-id="serverApp">
#    @charset "UTF-8";.b-vacancy[_ngcontent-serverApp-c3083313915]{padding-top:28px}.b-vacancy--recruiter[_ngcontent-serverApp-c3083313915]{padding-top:60px}@media (max-width: 768px){.b-vacancy--recruiter[_ngcontent-serverApp-c3083313915]{padding-top:24px}}.b-vacancy__seo-links[_ngcontent-serverApp-c3083313915]{margin:40px 0}@media (max-width: 768px){.b-vacancy__seo-links[_ngcontent-serverApp-c3083313915]{margin:24px 0}}.b-vacancy__breadcrumbs[_ngcontent-serverApp-c3083313915]{margin-top:24px}.b-vacancy[_ngcontent-serverApp-c3083313915]   .row[_ngcontent-serverApp-c3083313915]{margin:0 -20px}.b-vacancy[_ngcontent-serverApp-c3083313915]   .col[_ngcontent-serverApp-c3083313915], .b-vacancy[_ngcontent-serverApp-c3083313915]   .col-md-10[_ngcontent-serverApp-c3083313915], .b-vacancy[_ngcontent-serverApp-c3083313915]   .col-12[_ngcontent-serverApp-c3083313915], .b-vacancy[_ngcontent-serverApp-c3083313915]   .col-md-8[_ngcontent-serverApp-c3083313915], .b-vacancy[_ngcontent-serverApp-c3083313915]   .col-sm-12[_ngcontent-serverApp-c3083313915], .b-vacancy[_ngcontent-serverApp-c3083313915]   .col-3[_ngcontent-serverApp-c3083313915], .b-vacancy[_ngcontent-serverApp-c3083313915]   .col-md-9[_ngcontent-serverApp-c3083313915]{padding:0 20px}.b-vacancy-v2[_ngcontent-serverApp-c3083313915]{font-family:Inter,sans-serif;font-weight:400;font-size:15px;line-height:24px;letter-spacing:-.24px;margin-top:-12px}.b-vacancy-v2[_ngcontent-serverApp-c3083313915]   .b-header[_ngcontent-serverApp-c3083313915]   h1[_ngcontent-serverApp-c3083313915]{font-family:Montserrat;font-size:36px;line-height:44px;font-weight:600;margin:24px 0 0;padding:0;color:#0c2231}.b-vacancy-v2[_ngcontent-serverApp-c3083313915]   .b-header[_ngcontent-serverApp-c3083313915]   h2[_ngcontent-serverApp-c3083313915]{font-family:Montserrat;font-size:24px;line-height:32px;font-weight:600;margin:4px 0 0;padding:0;color:#0c2231}.b-vacancy-v2[_ngcontent-serverApp-c3083313915]   .b-header[_ngcontent-serverApp-c3083313915]   h3[_ngcontent-serverApp-c3083313915]{font-family:Montserrat;font-weight:600;font-size:18px;line-height:24px;margin:16px 0 0;padding:0;color:#0c2231}.b-vacancy-v2[_ngcontent-serverApp-c3083313915]   .b-header[_ngcontent-serverApp-c3083313915]   h3[_ngcontent-serverApp-c3083313915]   img[_ngcontent-serverApp-c3083313915]{filter:brightness(0) saturate(100%) invert(46%) sepia(9%) saturate(283%) hue-rotate(158deg) brightness(95%) contrast(90%)}.b-vacancy-v2[_ngcontent-serverApp-c3083313915]   .b-back[_ngcontent-serverApp-c3083313915]{font-family:Inter;font-style:normal;font-weight:500;font-size:14px;line-height:18px;letter-spacing:-.24px}.b-vacancy-v2[_ngcontent-serverApp-c3083313915]   .b-back[_ngcontent-serverApp-c3083313915]   img[_ngcontent-serverApp-c3083313915]{display:inline-block}.b-vacancy-v2[_ngcontent-serverApp-c3083313915]   .b-location[_ngcontent-serverApp-c3083313915]{margin:28px 0 0}@media (max-width: 768px){.b-vacancy-v2[_ngcontent-serverApp-c3083313915]   .b-location[_ngcontent-serverApp-c3083313915]{margin:24px 0 0}}.b-vacancy-v2[_ngcontent-serverApp-c3083313915]   .b-specs[_ngcontent-serverApp-c3083313915]{margin:24px 0 0}@media (max-width: 768px){.b-vacancy-v2[_ngcontent-serverApp-c3083313915]   .b-specs[_ngcontent-serverApp-c3083313915]{margin:20px 0 0}}.b-vacancy-v2[_ngcontent-serverApp-c3083313915]   .b-specs[_ngcontent-serverApp-c3083313915]   .b-term[_ngcontent-serverApp-c3083313915]{max-width:125px;font-size:14px;line-height:18px;color:#6c7377}.b-vacancy-v2[_ngcontent-serverApp-c3083313915]   .b-specs[_ngcontent-serverApp-c3083313915]   .b-value[_ngcontent-serverApp-c3083313915]{font-size:14px;line-height:18px}.b-vacancy-v2[_ngcontent-serverApp-c3083313915]   .b-specs[_ngcontent-serverApp-c3083313915]   .row[_ngcontent-serverApp-c3083313915]{margin-top:12px}.b-vacancy-v2[_ngcontent-serverApp-c3083313915]   .b-apply-block[_ngcontent-serverApp-c3083313915]{padding:0;margin-top:36px;gap:8px}@media (min-width: 768px){.b-vacancy-v2[_ngcontent-serverApp-c30 ...
#   </style>
#   <style ng-app-id="serverApp">
#    .b-footer[_ngcontent-serverApp-c1446189509]{background:#ffffff;border-top:#e3e4e5 1px solid;padding-top:24px}.b-footer[_ngcontent-serverApp-c1446189509]   .b-logotype[_ngcontent-serverApp-c1446189509]{margin:0;display:block;border:none;outline:none;width:134px;height:28px}@media (max-width: 768px){.b-footer[_ngcontent-serverApp-c1446189509]   .b-logotype[_ngcontent-serverApp-c1446189509]{margin-right:auto}}.b-footer[_ngcontent-serverApp-c1446189509]   li[_ngcontent-serverApp-c1446189509]{line-height:21px}.b-footer[_ngcontent-serverApp-c1446189509]   li[_ngcontent-serverApp-c1446189509]   a[_ngcontent-serverApp-c1446189509]{font-size:14px;line-height:18px;letter-spacing:-.24px;font-family:Inter;font-style:normal;font-weight:500}.b-footer-logo[_ngcontent-serverApp-c1446189509]{margin-bottom:24px}.b-footer-logo[_ngcontent-serverApp-c1446189509]   img[_ngcontent-serverApp-c1446189509]{max-height:100%}.b-footer-content[_ngcontent-serverApp-c1446189509]{display:flex;justify-content:space-between;flex-direction:row;flex-wrap:nowrap;margin-bottom:24px}.b-footer-left[_ngcontent-serverApp-c1446189509]{display:flex;flex-direction:row}.b-footer-links[_ngcontent-serverApp-c1446189509]{list-style:none;padding:0}.b-footer-links[_ngcontent-serverApp-c1446189509]   li[_ngcontent-serverApp-c1446189509]{margin-bottom:16px}.b-footer-links[_ngcontent-serverApp-c1446189509]   li[_ngcontent-serverApp-c1446189509]:last-of-type{margin:0}.b-footer-links[_ngcontent-serverApp-c1446189509]   a[_ngcontent-serverApp-c1446189509]:hover{color:#205aed}.b-footer-links[_ngcontent-serverApp-c1446189509]:nth-child(2){margin-left:48px}.b-footer-right[_ngcontent-serverApp-c1446189509]{max-width:220px}.b-footer-right[_ngcontent-serverApp-c1446189509]   h6[_ngcontent-serverApp-c1446189509]{font-size:14px;line-height:18px;letter-spacing:-.24px;font-family:Inter;font-style:normal;font-weight:600;margin-bottom:8px;color:#0c2231}.b-footer-right[_ngcontent-serverApp-c1446189509]   p[_ngcontent-serverApp-c1446189509]{font-size:14px;line-height:18px;letter-spacing:-.24px;font-family:Inter;font-style:normal;font-weight:500;margin-bottom:8px;color:#0c2231}.b-footer-contacts[_ngcontent-serverApp-c1446189509]{list-style:none;padding:0}.b-footer-contacts[_ngcontent-serverApp-c1446189509]   li[_ngcontent-serverApp-c1446189509]{margin-bottom:8px}.b-footer-contacts[_ngcontent-serverApp-c1446189509]   li[_ngcontent-serverApp-c1446189509]   a[_ngcontent-serverApp-c1446189509]{display:flex;align-items:center}.b-footer-contacts[_ngcontent-serverApp-c1446189509]   li[_ngcontent-serverApp-c1446189509]   a[_ngcontent-serverApp-c1446189509]   img[_ngcontent-serverApp-c1446189509]{max-width:20px;filter:brightness(0) saturate(100%) invert(23%) sepia(92%) saturate(3258%) hue-rotate(222deg) brightness(96%) contrast(93%)}.b-footer-contacts[_ngcontent-serverApp-c1446189509]   li[_ngcontent-serverApp-c1446189509]   a[_ngcontent-serverApp-c1446189509]   span[_ngcontent-serverApp-c1446189509]{margin-left:8px}.b-footer-contacts[_ngcontent-serverApp-c1446189509]   li[_ngcontent-serverApp-c1446189509]   a[_ngcontent-serverApp-c1446189509]:hover{color:#205aed}.b-footer-social[_ngcontent-serverApp-c1446189509]{margin-top:16px;display:flex;flex-direction:row;flex-wrap:nowrap;gap:8px}.b-footer-social-item[_ngcontent-serverApp-c1446189509]{display:flex;justify-content:center;align-items:center;border:#9ca2a6 1px solid;background:none;height:30px;width:30px;border-radius:6px;transition:border .2s ease-in-out,background .2s ease-in-out}.b-footer-social-item[_ngcontent-serverApp-c1446189509]   img[_ngcontent-serverApp-c1446189509]{filter:brightness(0) saturate(100%) invert(74%) sepia(7%) saturate(224%) hue-rotate(161deg) brightness(87%) contrast(88%)}.b-footer-social-item[_ngcontent-serverApp-c1446189509]:hover{border:#ffe953 1px solid;background:#ffe953}.b-footer-social-item[_ngcontent-serverApp-c1446189509]:hover   img[_ngcontent-serverApp-c1446189509]{filter:brightness(0) saturate(100%) invert(10%) sepia ...
#   </style>
#   <style ng-app-id="serverApp">
#    .b-mobile-menu[_ngcontent-serverApp-c1098070990]{position:fixed;top:0;left:0;width:100%;height:100%;transition:left .2s;z-index:2147483010}.b-mobile-menu.hidden[_ngcontent-serverApp-c1098070990]{left:-100%}.b-mobile-menu-content-wrapper[_ngcontent-serverApp-c1098070990]{background:#ffffff;min-height:100%;position:relative}.b-mobile-menu-close[_ngcontent-serverApp-c1098070990]{width:45px;height:45px;position:absolute;top:0;right:0;padding:19px 15px 15px;z-index:50}.b-mobile-menu-close[_ngcontent-serverApp-c1098070990]   img[_ngcontent-serverApp-c1098070990]{width:15px;height:15px;object-fit:contain}.b-mobile-menu-content[_ngcontent-serverApp-c1098070990]{display:flex;flex-direction:column;padding:20px;position:absolute;align-content:space-between;min-height:100%;width:100%}.b-mobile-menu-content[_ngcontent-serverApp-c1098070990]   .b-logotype[_ngcontent-serverApp-c1098070990]{margin:0}.b-mobile-menu[_ngcontent-serverApp-c1098070990]   .b-logotype[_ngcontent-serverApp-c1098070990]{display:block;border:none;outline:none;width:134px;height:28px}.b-mobile-menu[_ngcontent-serverApp-c1098070990]   .b-logotype[_ngcontent-serverApp-c1098070990]   img[_ngcontent-serverApp-c1098070990]{width:134px;height:28px}@media (max-width: 768px){.b-mobile-menu[_ngcontent-serverApp-c1098070990]   .b-logotype[_ngcontent-serverApp-c1098070990]{margin-right:auto}}.b-mobile-menu[_ngcontent-serverApp-c1098070990]   ul[_ngcontent-serverApp-c1098070990]{list-style:none;padding:0;margin:36px 0 0;flex:500}.b-mobile-menu[_ngcontent-serverApp-c1098070990]   ul[_ngcontent-serverApp-c1098070990]   li[_ngcontent-serverApp-c1098070990]{list-style:none;margin:0;padding:20px 0}.b-mobile-menu[_ngcontent-serverApp-c1098070990]   ul[_ngcontent-serverApp-c1098070990]   li[_ngcontent-serverApp-c1098070990]   a[_ngcontent-serverApp-c1098070990]{font-family:Montserrat;font-style:normal;font-weight:500;font-size:15px;line-height:18.29px;letter-spacing:-.24px;padding:0;text-decoration:none;color:#0c2231;border-radius:100px;transition:background .5s}.b-mobile-menu[_ngcontent-serverApp-c1098070990]   ul[_ngcontent-serverApp-c1098070990]   li[_ngcontent-serverApp-c1098070990]   a[_ngcontent-serverApp-c1098070990]:focus, .b-mobile-menu[_ngcontent-serverApp-c1098070990]   ul[_ngcontent-serverApp-c1098070990]   li[_ngcontent-serverApp-c1098070990]   a[_ngcontent-serverApp-c1098070990]:active{background:none}.b-mobile-menu[_ngcontent-serverApp-c1098070990]   ul[_ngcontent-serverApp-c1098070990]   li[_ngcontent-serverApp-c1098070990]   a[_ngcontent-serverApp-c1098070990]:hover{background:none}.b-mobile-menu-footer[_ngcontent-serverApp-c1098070990]{flex:1}.b-mobile-menu-backdrop[_ngcontent-serverApp-c1098070990]{position:fixed;inset:0;background:rgba(0,0,0,.35);backdrop-filter:blur(4px);-o-backdrop-filter:blur(4px);-ms-backdrop-filter:blur(4px);-moz-backdrop-filter:blur(4px);-webkit-backdrop-filter:blur(4px);z-index:2147483009;display:flex;flex-direction:column;justify-content:space-between;transition:opacity .35s;opacity:1}.b-mobile-menu-backdrop.hidden[_ngcontent-serverApp-c1098070990]{opacity:0;left:-999999999px;right:999999999px}
#   </style>
#   <style ng-app-id="serverApp">
#    .b-similar-vacancies__header[_ngcontent-serverApp-c3647274225]{font-size:24px;line-height:32px;letter-spacing:normal;font-family:Montserrat;font-style:normal;font-weight:700;color:#0c2231}.b-similar-vacancies__list[_ngcontent-serverApp-c3647274225]{margin-top:36px}@media (max-width: 768px){.b-similar-vacancies__list[_ngcontent-serverApp-c3647274225]{margin-top:36px}}.b-similar-vacancies__more-link[_ngcontent-serverApp-c3647274225]{font-size:15px;line-height:20px;letter-spacing:normal;display:inline-block;font-weight:600;color:#205aed}.b-similar-vacancies__more-link[_ngcontent-serverApp-c3647274225]:hover{text-decoration:underline}.b-similar-vacancies__more-link[_ngcontent-serverApp-c3647274225]   img[_ngcontent-serverApp-c3647274225]{display:inline-block}
#   </style>
#   <link href="https://getmatch.ru/vacancies/26158-affiliate-manager" rel="canonical"/>
#   <meta content="getmatch.ru" name="og:site_name"/>
#   <meta content="Вакансия Affiliate Manager, работа в Winline, в Москве — getmatch" name="og:title"/>
#   <meta content="Вакансия Affiliate Manager, работа в компании Winline, Москва (офис или гибрид). Зарплата: 150 000 — 200 000 ₽/мес на руки. Дата публикации: 05.03.2025." name="og:description"/>
#   <meta content="Вакансия Affiliate Manager, работа в компании Winline, Москва (офис или гибрид). Зарплата: 150 000 — 200 000 ₽/мес на руки. Дата публикации: 05.03.2025." name="description"/>
#   <meta content="summary_large_image" name="twitter:card"/>
#   <meta content="https://getmatch.ru/uploads/telegram_pictures/da76057e-e921-4eb9-a6e2-8c5d044c40ce.png" name="twitter:image"/>
#   <meta content="https://getmatch.ru/uploads/telegram_pictures/da76057e-e921-4eb9-a6e2-8c5d044c40ce.png" name="og:image"/>
#   <meta content="1562" name="og:image:width"/>
#   <meta content="921" name="og:image:height"/>
#   <script class="structured-data-breadcrumbs" type="application/ld+json">
#    {"@context":"https://schema.org","@type":"BreadcrumbList","itemListElement":[{"@type":"ListItem","position":1,"item":{"@id":"https://getmatch.ru/vacancies","name":"Все вакансии"}},{"@type":"ListItem","position":2,"item":{"@id":"https://getmatch.ru/vacancies/product_analyst","name":"Product Analyst"}},{"@type":"ListItem","position":3,"item":{"@id":"https://getmatch.ru/vacancies/product_analyst/moscow","name":"Москва"}},{"@type":"ListItem","position":4,"item":{"@id":"https://getmatch.ru/vacancies/product_analyst/moscow/middle","name":"Middle"}}]}
#   </script>
#   <script class="structured-data-job-posting" type="application/ld+json">
#    {"@context":"https://schema.org/","@type":"JobPosting","title":"Affiliate Manager","hiringOrganization":{"@type":"Organization","name":"Winline","logo":"https://getmatch.ru/uploads/companies_logos/8a5c52e8-043a-4d01-9e44-10550b36361f.png"},"baseSalary":{"@type":"MonetaryAmount","currency":"RUB","value":{"@type":"QuantitativeValue","unitText":"MONTH","minValue":150000,"maxValue":200000}},"employmentType":"FULL_TIME","salaryCurrency":"RUB","datePosted":"2025-03-05","description":"Вакансия Affiliate Manager, работа в компании Winline, Москва (офис или гибрид). Зарплата: 150 000 — 200 000 ₽/мес на руки. Дата публикации: 05.03.2025.","jobLocation":[{"@type":"Place","address":{"@type":"PostalAddress","addressCountry":"RU","addressLocality":"Москва, Россия"}}]}
#   </script>
#   <style ng-app-id="serverApp">
#    [_nghost-serverApp-c3967332199]{display:block}.b-seo-links[_ngcontent-serverApp-c3967332199]{display:flex;flex-direction:column}.b-seo-links__column[_ngcontent-serverApp-c3967332199]{display:flex;flex-direction:column;margin-bottom:24px;flex-shrink:0}.b-seo-links__column[_ngcontent-serverApp-c3967332199]:last-of-type{margin:0}.b-seo-links__title[_ngcontent-serverApp-c3967332199]{font-family:Montserrat;font-style:normal;font-weight:700;font-size:18px;line-height:24px;letter-spacing:normal;color:#0c2231;margin-bottom:8px}.b-seo-links__item[_ngcontent-serverApp-c3967332199]{font-family:Inter;font-style:normal;font-weight:400;font-size:14px;line-height:18px;letter-spacing:normal;color:#205aed;margin-bottom:8px;width:-moz-fit-content;width:fit-content}.b-seo-links__item[_ngcontent-serverApp-c3967332199]:last-of-type{margin:0}@media (min-width: 768px){.b-seo-links[_ngcontent-serverApp-c3967332199]{flex-direction:row}.b-seo-links__column[_ngcontent-serverApp-c3967332199]{margin:0 32px 0 0;max-width:205px}.b-seo-links__item[_ngcontent-serverApp-c3967332199]{margin-bottom:4px}}@media (min-width: 1024px){.b-seo-links__column[_ngcontent-serverApp-c3967332199]{margin:0 72px 0 0;max-width:285px}}
#   </style>
#   <style ng-app-id="serverApp">
#    @charset "UTF-8";[_nghost-serverApp-c2668210061]{display:block;line-height:18px}.b-breadcrumbs[_ngcontent-serverApp-c2668210061]{display:block;line-height:18px}.b-breadcrumbs__item[_ngcontent-serverApp-c2668210061]{display:inline-block;padding:0 8px 0 0}.b-breadcrumbs__item[_ngcontent-serverApp-c2668210061]:before{content:"\2022";font-family:Inter;font-style:normal;font-weight:400;font-size:14px;line-height:18px;letter-spacing:normal;color:#9ca2a6;padding:0 8px 0 0}.b-breadcrumbs__item[_ngcontent-serverApp-c2668210061]:nth-child(1):before{display:none}.b-breadcrumbs__item-link[_ngcontent-serverApp-c2668210061]{color:#205aed;font-family:Inter;font-style:normal;font-weight:400;font-size:14px;line-height:18px;letter-spacing:normal}
#   </style>
#   <style ng-app-id="serverApp">
#    .b-vacancy-locations[_ngcontent-serverApp-c2595184480]{display:flex;flex-wrap:wrap;gap:4px}.b-vacancy-locations--first[_ngcontent-serverApp-c2595184480]{padding-left:8px}.b-vacancy-locations[_ngcontent-serverApp-c2595184480]   .g-label[_ngcontent-serverApp-c2595184480]{white-space:nowrap;overflow:hidden;text-overflow:ellipsis}.b-odo[_ngcontent-serverApp-c2595184480]   .g-label[_ngcontent-serverApp-c2595184480]{color:#0c2231;background-color:#fff}
#   </style>
#   <style ng-app-id="serverApp">
#    .b-share[_ngcontent-serverApp-c391075571]{position:relative}.b-share__button[_ngcontent-serverApp-c391075571]{display:inline-block}.b-share__button[_ngcontent-serverApp-c391075571]:after{display:none}.b-share[_ngcontent-serverApp-c391075571]   .dropdown-menu[_ngcontent-serverApp-c391075571]{z-index:1000;float:none;min-width:0;padding:0;margin:0;background:none;border:none;border-radius:0;box-shadow:none}.b-share[_ngcontent-serverApp-c391075571]   .dropdown-menu[x-placement^=top][_ngcontent-serverApp-c391075571]   .b-share__dropdown[_ngcontent-serverApp-c391075571]{margin-bottom:12px}.b-share[_ngcontent-serverApp-c391075571]   .dropdown-menu[x-placement^=bottom][_ngcontent-serverApp-c391075571]   .b-share__dropdown[_ngcontent-serverApp-c391075571]{margin-top:12px}.b-share__dropdown[_ngcontent-serverApp-c391075571]{background:#ffffff;padding:24px 24px 32px;max-width:420px;box-shadow:0 8px 20px #0000001a;border-radius:12px;border:1px solid #e3e4e5}.b-share__dropdown-title[_ngcontent-serverApp-c391075571]{color:#0c2231;margin-bottom:16px}.b-share__dropdown-buttons[_ngcontent-serverApp-c391075571]{display:flex;margin:0 0 8px}.b-share__dropdown-buttons-item[_ngcontent-serverApp-c391075571]{padding:10px;flex:1;margin:0 8px 0 0;width:181px}.b-share__dropdown-buttons-item[_ngcontent-serverApp-c391075571]:last-of-type{margin:0}.b-share__dropdown-link[_ngcontent-serverApp-c391075571]{display:flex;flex-wrap:nowrap;margin-top:16px}.b-share__dropdown-link-input[_ngcontent-serverApp-c391075571]{background:#eff2f3;border:none;outline:none;box-sizing:border-box;border-radius:6px;width:100%;padding:9px 12px;cursor:pointer;transition:background-color .2s;white-space:nowrap;overflow:hidden;text-overflow:ellipsis;font-family:Inter;font-style:normal;font-weight:400;font-size:15px;line-height:24px;letter-spacing:-.24px;color:#0c2231}.b-share__dropdown-link-input[_ngcontent-serverApp-c391075571]:hover{background-color:#e3e4e5}.b-share__dropdown-link[_ngcontent-serverApp-c391075571]   .g-btn-icon[_ngcontent-serverApp-c391075571]{padding:10px;margin-left:8px}.b-share__dropdown-link[_ngcontent-serverApp-c391075571]   .g-btn-icon[_ngcontent-serverApp-c391075571]   .icon[_ngcontent-serverApp-c391075571]{width:20px;height:20px}
#   </style>
#   <style ng-app-id="serverApp">
#    .b-similar-vacancy[_ngcontent-serverApp-c3944807383]{padding-bottom:20px;margin-bottom:20px}.b-similar-vacancy[_ngcontent-serverApp-c3944807383]   a[_ngcontent-serverApp-c3944807383]{text-decoration:none}.b-similar-vacancy__title[_ngcontent-serverApp-c3944807383]   h3[_ngcontent-serverApp-c3944807383]{font-size:15px;line-height:20px;letter-spacing:normal;margin:0;display:inline-block;color:#205aed}.b-similar-vacancy__title[_ngcontent-serverApp-c3944807383]   h3[_ngcontent-serverApp-c3944807383]:hover{text-decoration:underline}.b-similar-vacancy__logo[_ngcontent-serverApp-c3944807383]{display:flex;height:42px;max-height:42px;max-width:80px;align-items:center}.b-similar-vacancy__logo[_ngcontent-serverApp-c3944807383]   img[_ngcontent-serverApp-c3944807383]{max-width:100%;max-height:100%;margin-left:auto;margin-right:auto}@media (max-width: 768px){.b-similar-vacancy__logo[_ngcontent-serverApp-c3944807383]{max-height:60px}}.b-similar-vacancy__salary[_ngcontent-serverApp-c3944807383], .b-similar-vacancy__location[_ngcontent-serverApp-c3944807383]{font-family:Inter;font-style:normal;font-weight:400;font-size:14px;line-height:18px;letter-spacing:normal;color:#0c2231;margin-top:4px}.b-similar-vacancy--delimiter[_ngcontent-serverApp-c3944807383]{border-bottom:solid 1px #e3e4e5}
#   </style>
#  </head>
#  <body>
#   <div class="zeropixel">
#    <!-- Rating Mail.ru counter -->
#    <script type="text/javascript">
#     var _tmr = window._tmr || (window._tmr = []);
#         (function (d, w, id) {
#           if (d.getElementById(id)) return;
#           var ts = d.createElement('script');
#           ts.type = 'text/javascript';
#           ts.async = true;
#           ts.id = id;
#           ts.src = 'https://top-fwz1.mail.ru/js/code.js';
#           var f = function () {
#             var s = d.getElementsByTagName('script')[0];
#             s.parentNode.insertBefore(ts, s);
#           };
#           if (w.opera == '[object Opera]') {
#             d.addEventListener('DOMContentLoaded', f, false);
#           } else {
#             f();
#           }
#         })(document, window, 'topmailru-code');
#    </script>
#    <noscript>
#     <div>
#      <img alt="Top.Mail.Ru" src="https://top-fwz1.mail.ru/counter?id=3253566;js=na" style="border: 0; position: absolute; left: -9999px"/>
#     </div>
#    </noscript>
#    <!-- /Rating Mail.ru counter -->
#    <!--LiveInternet counter-->
#    <script>
#     new Image().src =
#           'https://counter.yadro.ru/hit?r' +
#           escape(document.referrer) +
#           (typeof screen == 'undefined'
#             ? ''
#             : ';s' +
#               screen.width +
#               '*' +
#               screen.height +
#               '*' +
#               (screen.colorDepth ? screen.colorDepth : screen.pixelDepth)) +
#           ';u' +
#           escape(document.URL) +
#           ';h' +
#           escape(document.title.substring(0, 150)) +
#           ';' +
#           Math.random();
#    </script>
#    <!--/LiveInternet-->
#    <!-- Top100 (Kraken) Counter -->
#    <script>
#     (function (w, d, c) {
#           (w[c] = w[c] || []).push(function () {
#             var options = {
#               project: 7670794,
#               manualControl: true,
#             };
#             try {
#               w.top100Counter = new top100(options);
#             } catch (e) {}
#           });
#           var n = d.getElementsByTagName('script')[0],
#             s = d.createElement('script'),
#             f = function () {
#               n.parentNode.insertBefore(s, n);
#             };
#           s.type = 'text/javascript';
#           s.async = true;
#           s.src =
#             (d.location.protocol == 'https:' ? 'https:' : 'http:') +
#             '//st.top100.ru/top100/top100.js';
#
#           if (w.opera == '[object Opera]') {
#             d.addEventListener('DOMContentLoaded', f, false);
#           } else {
#             f();
#           }
#         })(window, document, '_top100q');
#    </script>
#    <noscript>
#     <img alt="Топ-100" src="//counter.rambler.ru/top100.cnt?pid=7670794"/>
#    </noscript>
#    <!-- END Top100 (Kraken) Counter -->
#   </div>
#   <app-root ng-server-context="ssr" ng-version="16.2.9">
#    <router-outlet>
#    </router-outlet>
#    <app-container _nghost-serverapp-c1263125476="">
#     <app-header _ngcontent-serverapp-c1263125476="" _nghost-serverapp-c708908426="">
#      <header _ngcontent-serverapp-c708908426="" class="b-header b-header--anonymous">
#       <div _ngcontent-serverapp-c708908426="" class="container">
#        <a _ngcontent-serverapp-c708908426="" class="b-header__logotype" href="/">
#        </a>
#        <nav _ngcontent-serverapp-c708908426="" class="b-header__navigation">
#         <a _ngcontent-serverapp-c708908426="" class="b-header__navigation-link b-header__navigation-link--active" href="/vacancies?s=menu" routerlink="/vacancies">
#          Вакансии
#         </a>
#         <!-- -->
#         <!-- -->
#         <!-- -->
#         <a _ngcontent-serverapp-c708908426="" class="b-header__navigation-link" href="/salaries?s=menu" routerlink="/salaries">
#          Зарплаты
#         </a>
#        </nav>
#        <div _ngcontent-serverapp-c708908426="" class="b-header__buttons">
#         <!-- -->
#         <!-- -->
#         <!-- -->
#         <!-- -->
#         <button _ngcontent-serverapp-c708908426="" class="g-btn g-btn-primary b-header__buttons-telegram">
#          <img _ngcontent-serverapp-c708908426="" class="icon" src="/static/img/icons/icon-telegram-white.svg"/>
#          <span _ngcontent-serverapp-c708908426="">
#           Добавить в Telegram
#          </span>
#         </button>
#         <!-- -->
#         <button _ngcontent-serverapp-c708908426="" class="g-btn g-btn-secondary b-header__buttons-login" id="loginButton">
#          Вход
#         </button>
#         <!-- -->
#        </div>
#        <!-- -->
#        <!-- -->
#        <div _ngcontent-serverapp-c708908426="" class="b-header__mobile-menu">
#         <img _ngcontent-serverapp-c708908426="" src="/static/img/icons/icon-menu-black.svg"/>
#        </div>
#        <app-menu-mobile-candidate _ngcontent-serverapp-c708908426="" _nghost-serverapp-c1098070990="">
#         <!-- -->
#        </app-menu-mobile-candidate>
#        <!-- -->
#        <!-- -->
#        <!-- -->
#        <!-- -->
#       </div>
#      </header>
#     </app-header>
#     <!-- -->
#     <!-- -->
#     <!-- -->
#     <div _ngcontent-serverapp-c1263125476="" class="page-container page-container--anonymous">
#      <router-outlet _ngcontent-serverapp-c1263125476="">
#      </router-outlet>
#      <app-vacancy _nghost-serverapp-c3083313915="">
#       <div _ngcontent-serverapp-c3083313915="" class="b-vacancy">
#        <!-- -->
#        <!-- -->
#        <section _ngcontent-serverapp-c3083313915="" class="container b-vacancy-v2">
#         <!-- -->
#         <!-- -->
#         <!-- -->
#         <!-- -->
#         <!-- -->
#         <div _ngcontent-serverapp-c3083313915="" class="row">
#          <div _ngcontent-serverapp-c3083313915="" class="col-12 d-md-none">
#           <div _ngcontent-serverapp-c3083313915="" class="b-company-logotype-container">
#            <div _ngcontent-serverapp-c3083313915="" class="b-company-logotype">
#             <img _ngcontent-serverapp-c3083313915="" alt="Winline" src="/uploads/companies_logos/8a5c52e8-043a-4d01-9e44-10550b36361f.png"/>
#            </div>
#           </div>
#           <!-- -->
#          </div>
#          <div _ngcontent-serverapp-c3083313915="" class="col-md-8 col-sm-12">
#           <section _ngcontent-serverapp-c3083313915="" class="b-header">
#            <app-breadcrumbs _ngcontent-serverapp-c3083313915="" _nghost-serverapp-c2668210061="" class="b-vacancy__breadcrumbs" source="vacancy_breadcrumbs">
#             <div _ngcontent-serverapp-c2668210061="" class="b-breadcrumbs">
#              <span _ngcontent-serverapp-c2668210061="" class="b-breadcrumbs__item">
#               <a _ngcontent-serverapp-c2668210061="" class="b-breadcrumbs__item-link" href="/vacancies?s=vacancy_breadcrumbs">
#                Все вакансии
#               </a>
#               <!-- -->
#               <!-- -->
#              </span>
#              <span _ngcontent-serverapp-c2668210061="" class="b-breadcrumbs__item">
#               <a _ngcontent-serverapp-c2668210061="" class="b-breadcrumbs__item-link" href="/vacancies/product_analyst?s=vacancy_breadcrumbs">
#                Product Analyst
#               </a>
#               <!-- -->
#               <!-- -->
#              </span>
#              <span _ngcontent-serverapp-c2668210061="" class="b-breadcrumbs__item">
#               <a _ngcontent-serverapp-c2668210061="" class="b-breadcrumbs__item-link" href="/vacancies/product_analyst/moscow?s=vacancy_breadcrumbs">
#                Москва
#               </a>
#               <!-- -->
#               <!-- -->
#              </span>
#              <span _ngcontent-serverapp-c2668210061="" class="b-breadcrumbs__item">
#               <a _ngcontent-serverapp-c2668210061="" class="b-breadcrumbs__item-link" href="/vacancies/product_analyst/moscow/middle?s=vacancy_breadcrumbs">
#                Middle
#               </a>
#               <!-- -->
#               <!-- -->
#              </span>
#              <!-- -->
#             </div>
#            </app-breadcrumbs>
#            <!-- -->
#            <h1 _ngcontent-serverapp-c3083313915="">
#             Affiliate Manager
#            </h1>
#            <h2 _ngcontent-serverapp-c3083313915="">
#             в
#             <a _ngcontent-serverapp-c3083313915="" href="/companies/bxlV9dQ5-winline?s=vacancy" target="_blank">
#              Winline
#             </a>
# ...
#           <div _ngcontent-serverapp-c3967332199="" class="b-seo-links">
#            <div _ngcontent-serverapp-c3967332199="" class="b-seo-links__column">
#             <h3 _ngcontent-serverapp-c3967332199="" class="b-seo-links__title">
#              Больше вакансий
#             </h3>
#             <a _ngcontent-serverapp-c3967332199="" class="b-seo-links__item" href="/vacancies/product_analyst/regions/senior?s=vacancy_seo_links_more_vacancies">
#              Senior Product Analyst`ов в регионах РФ
#             </a>
#             <a _ngcontent-serverapp-c3967332199="" class="b-seo-links__item" href="/vacancies/product_analyst/remote?s=vacancy_seo_links_more_vacancies">
#              Product Analyst`ов удалённо
#             </a>
#             <a _ngcontent-serverapp-c3967332199="" class="b-seo-links__item" href="/vacancies/product_management/russia?s=vacancy_seo_links_more_vacancies">
#              Product Manager’ов в России
#             </a>
#             <a _ngcontent-serverapp-c3967332199="" class="b-seo-links__item" href="/vacancies/product_analyst/spb/senior?s=vacancy_seo_links_more_vacancies">
#              Senior Product Analyst`ов в Санкт-Петербурге
#             </a>
#             <a _ngcontent-serverapp-c3967332199="" class="b-seo-links__item" href="/vacancies/project_management/senior?s=vacancy_seo_links_more_vacancies">
#              Senior Project Manager`ов
#             </a>
#             <a _ngcontent-serverapp-c3967332199="" class="b-seo-links__item" href="/vacancies/product_analyst/moscow/middle?s=vacancy_seo_links_more_vacancies">
#              Middle Product Analyst`ов в Москве
#             </a>
#             <!-- -->
#            </div>
#            <div _ngcontent-serverapp-c3967332199="" class="b-seo-links__column">
#             <h3 _ngcontent-serverapp-c3967332199="" class="b-seo-links__title">
#              Похожие вакансии
#             </h3>
#             <a _ngcontent-serverapp-c3967332199="" class="b-seo-links__item" href="/vacancies/spb?s=vacancy_seo_links_similar_vacancies">
#              В Санкт-Петербурге
#             </a>
#             <a _ngcontent-serverapp-c3967332199="" class="b-seo-links__item" href="/vacancies/product_management/senior?s=vacancy_seo_links_similar_vacancies">
#              Senior Product Manager’ов
#             </a>
#             <a _ngcontent-serverapp-c3967332199="" class="b-seo-links__item" href="/vacancies/product_analyst/remote/lead?s=vacancy_seo_links_similar_vacancies">
#              Lead Product Analyst`ов удалённо
#             </a>
#             <a _ngcontent-serverapp-c3967332199="" class="b-seo-links__item" href="/vacancies/product_analyst/spb?s=vacancy_seo_links_similar_vacancies">
#              Product Analyst`ов в Санкт-Петербурге
#             </a>
#             <a _ngcontent-serverapp-c3967332199="" class="b-seo-links__item" href="/vacancies/product_management/russia/senior?s=vacancy_seo_links_similar_vacancies">
#              Senior Product Manager’ов в России
#             </a>
#             <a _ngcontent-serverapp-c3967332199="" class="b-seo-links__item" href="/vacancies/product_management/moscow/lead?s=vacancy_seo_links_similar_vacancies">
#              Lead Product Manager’ов в Москве
#             </a>
#             <!-- -->
#            </div>
#            <div _ngcontent-serverapp-c3967332199="" class="b-seo-links__column">
#             <h3 _ngcontent-serverapp-c3967332199="" class="b-seo-links__title">
#              Зарплаты
#             </h3>
#             <a _ngcontent-serverapp-c3967332199="" class="b-seo-links__item" href="/salaries/%5Bobject%20Object%5D?s=vacancy_seo_links_salaries">
#              Project Manager`ов
#             </a>
#             <a _ngcontent-serverapp-c3967332199="" class="b-seo-links__item" href="/salaries/%5Bobject%20Object%5D?s=vacancy_seo_links_salaries">
#              Project Manager`ов
#             </a>
#             <a _ngcontent-serverapp-c3967332199="" class="b-seo-links__item" href="/salaries/%5Bobject%20Object%5D?s=vacancy_seo_links_salaries">
#              Product Manager’ов
#             </a>
#             <a _ngcontent-serverapp-c3967332199="" class="b-seo-links__item" href="/salaries/%5Bobject%20Object%5D?s=vacancy_seo_links_salaries">
#              Product Analyst`ов
#             </a>
#             <a _ngcontent-serverapp-c3967332199="" class="b-seo-links__item" href="/salaries/%5Bobject%20Object%5D?s=vacancy_seo_links_salaries">
#              Product Analyst`ов
#             </a>
#             <a _ngcontent-serverapp-c3967332199="" class="b-seo-links__item" href="/salaries/%5Bobject%20Object%5D?s=vacancy_seo_links_salaries">
#              Product Manager’ов
#             </a>
#             <!-- -->
#            </div>
#           </div>
#          </app-seo-links>
#         </div>
#        </section>
#        <!-- -->
#       </div>
#      </app-vacancy>
#      <!-- -->
#     </div>
#     <app-footer _ngcontent-serverapp-c1263125476="" _nghost-serverapp-c1446189509="">
#      <footer _ngcontent-serverapp-c1446189509="" class="b-footer">
#       <div _ngcontent-serverapp-c1446189509="" class="container">
#        <div _ngcontent-serverapp-c1446189509="" class="b-footer-logo">
#         <!-- -->
#         <a _ngcontent-serverapp-c1446189509="" aria-label="Главная" class="b-logotype" href="/?s=footer">
#          <img _ngcontent-serverapp-c1446189509="" src="/static/img/getmatch-logo.svg"/>
#         </a>
#         <!-- -->
#        </div>
#        <div _ngcontent-serverapp-c1446189509="" class="b-footer-content">
#         <div _ngcontent-serverapp-c1446189509="" class="b-footer-left">
#          <ul _ngcontent-serverapp-c1446189509="" class="b-footer-links">
#           <li _ngcontent-serverapp-c1446189509="">
#            <a _ngcontent-serverapp-c1446189509="" href="https://t.me/g_jobbot?start=u_footer__YV9fMTUw" rel="noopener noreferrer nofollow" target="_blank">
#             Телеграм-бот с вакансиями 🤖
#            </a>
#           </li>
#           <li _ngcontent-serverapp-c1446189509="">
#            <a _ngcontent-serverapp-c1446189509="" href="/vacancies?s=footer">
#             Вакансии
#            </a>
#           </li>
#           <li _ngcontent-serverapp-c1446189509="">
#            <a _ngcontent-serverapp-c1446189509="" href="/salaries?s=footer">
#             Зарплаты
#            </a>
#           </li>
#           <li _ngcontent-serverapp-c1446189509="">
#            <a _ngcontent-serverapp-c1446189509="" href="/catalog?s=footer">
#             Каталог
#            </a>
#           </li>
#           <!-- -->
#           <!-- -->
#           <!-- -->
#          </ul>
#          <ul _ngcontent-serverapp-c1446189509="" class="b-footer-links">
#           <!-- -->
#           <li _ngcontent-serverapp-c1446189509="">
#            <a _ngcontent-serverapp-c1446189509="" href="https://getmatch.ru/companies?s=footer" rel="noopener" target="_blank">
#             Работодателям
#            </a>
#           </li>
#           <li _ngcontent-serverapp-c1446189509="">
#            <a _ngcontent-serverapp-c1446189509="" href="https://getmatch.ru/demo/vacancies?s=footer" rel="noopener" target="_blank">
#             Разместить вакансию
#            </a>
#           </li>
#           <li _ngcontent-serverapp-c1446189509="">
#            <a _ngcontent-serverapp-c1446189509="" href="javascript:void(0)">
#             Зарегистрироваться
#            </a>
#           </li>
#           <!-- -->
#           <li _ngcontent-serverapp-c1446189509="">
#            <a _ngcontent-serverapp-c1446189509="" href="javascript:void(0)">
#             Войти
#            </a>
#           </li>
#           <!-- -->
#          </ul>
#          <!-- -->
#         </div>
#         <div _ngcontent-serverapp-c1446189509="" class="b-footer-right">
#          <h6 _ngcontent-serverapp-c1446189509="">
#           Нужна помощь?
#          </h6>
#          <p _ngcontent-serverapp-c1446189509="">
#           Мы на связи по будням с 10:00 до 19:00
#          </p>
#          <ul _ngcontent-serverapp-c1446189509="" class="b-footer-contacts">
#           <li _ngcontent-serverapp-c1446189509="">
#            <a _ngcontent-serverapp-c1446189509="" href="mailto:hello@getmatch.ru" rel="noopener noreferrer nofollow" target="_blank">
#             <img _ngcontent-serverapp-c1446189509="" alt="Иконка почты" src="/static/img/icons/icon-mail-outline-black.svg"/>
#             <span _ngcontent-serverapp-c1446189509="">
#              hello@getmatch.ru
#             </span>
#            </a>
#           </li>
#           <!-- -->
#           <!-- -->
#          </ul>
#          <div _ngcontent-serverapp-c1446189509="" class="b-footer-social">
#           <a _ngcontent-serverapp-c1446189509="" href="https://habr.com/ru/company/getmatch/" rel="noopener noreferrer nofollow" target="_blank">
#            <div _ngcontent-serverapp-c1446189509="" class="b-footer-social-item">
#             <img _ngcontent-serverapp-c1446189509="" alt="habr" src="/static/img/icons/icon-habr-black.svg"/>
#            </div>
#           </a>
#           <a _ngcontent-serverapp-c1446189509="" href="https://www.linkedin.com/company/2253808" rel="noopener noreferrer nofollow" target="_blank">
#            <div _ngcontent-serverapp-c1446189509="" class="b-footer-social-item">
#             <img _ngcontent-serverapp-c1446189509="" alt="lin" src="/static/img/icons/icon-lin-black.svg"/>
#            </div>
#           </a>
#           <a _ngcontent-serverapp-c1446189509="" href="https://twitter.com/getmatch_team" rel="noopener noreferrer nofollow" target="_blank">
#            <div _ngcontent-serverapp-c1446189509="" class="b-footer-social-item">
#             <img _ngcontent-serverapp-c1446189509="" alt="tw" src="/static/img/icons/icon-tw-black.svg"/>
#            </div>
#           </a>
#           <a _ngcontent-serverapp-c1446189509="" href="https://vk.com/getmatch" rel="noopener noreferrer nofollow" target="_blank">
#            <div _ngcontent-serverapp-c1446189509="" class="b-footer-social-item">
#             <img _ngcontent-serverapp-c1446189509="" alt="vk" src="/static/img/icons/icon-vk-black.svg"/>
#            </div>
#           </a>
#           <a _ngcontent-serverapp-c1446189509="" href="https://t.me/g_jobchannel" rel="noopener noreferrer nofollow" target="_blank">
#            <div _ngcontent-serverapp-c1446189509="" class="b-footer-social-item">
#             <img _ngcontent-serverapp-c1446189509="" alt="tg" src="/static/img/icons/icon-tg-black.svg" width="14"/>
#            </div>
#           </a>
#          </div>
#         </div>
#        </div>
#       </div>
#       <div _ngcontent-serverapp-c1446189509="" class="b-footer-bottom">
#        <div _ngcontent-serverapp-c1446189509="" class="container">
#         <p _ngcontent-serverapp-c1446189509="">
#          © 2025 getmatch.ru
#         </p>
#         <div _ngcontent-serverapp-c1446189509="" class="b-footer-bottom-tos">
#          <a _ngcontent-serverapp-c1446189509="" href="https://getmatch.ru/docs/terms-of-service/" target="_blank">
#           Пользовательское соглашение
#          </a>
#          <a _ngcontent-serverapp-c1446189509="" href="https://getmatch.ru/docs/privacy-policy/" target="_blank">
#           Политика обработки персональных данных
#          </a>
#         </div>
#        </div>
#       </div>
#      </footer>
#     </app-footer>
#     <!-- -->
#    </app-container>
#    <!-- -->
#   </app-root>
#   <script crossorigin="anonymous" src="https://code.jquery.com/jquery-3.5.1.min.js">
#   </script>
#   <script crossorigin="anonymous" integrity="sha384-Q6E9RHvbIyZFJoft+2mJbHaEWldlvI9IOYy5n3zV9zzTtmI3UksdQRVvoxMfooAo" src="https://cdn.jsdelivr.net/npm/popper.js@1.16.0/dist/umd/popper.min.js">
#   </script>
#   <script crossorigin="anonymous" integrity="sha384-OgVRvuATP1z7JjHLkuOU7Xw704+h835Lr+6QL9UvYjZE3Ipu6Tp75j7Bh/kR0JKI" src="https://stackpath.bootstrapcdn.com/bootstrap/4.5.0/js/bootstrap.min.js">
#   </script>
#   <script src="/static-ssr/runtime.4c364a204d546d23.js" type="module">
#   </script>
#   <script src="/static-ssr/polyfills.30a98df15192b4b1.js" type="module">
#   </script>
#   <script src="/static-ssr/main.2c0a4405ea7cbb64.js" type="module">
#   </script>
#   <script id="serverApp-state" type="application/json">
#    {"isAnonymous":true,"role":"anonymous","user":null,"G.json.https://getmatch.ru/api/specializations?":{"body":[{"id":13,"name":"JS/Frontend Developer","slug":"js_frontend","morphs":{"form_first":"Frontend-разработчика","form_second":"frontend-разработчикам","plural":"JavaScript разработчики","form_first_plural":"Frontend разработчиков","form5":"Frontend-разработчиков"},"seo_morphs":{"form1":"Frontend разработчик","form2":"Frontend developer","form3":"Фронтенд разработчиком","form4":"Frontend разработчика","form5":"JavaScript"},"category":{"id":5,"slug":"frontend","name":"Frontend"}},{"id":11,"name":"QA Auto","slug":"qa_auto","morphs":{"form_first":"automation QA-инженера","form_second":"automation QA-инженерам","plural":"automation QA-инженеры","form_first_plural":"automation QA тестировщиков","form5":"Automation QA-тестировщиков"},"seo_morphs":{"form1":"QA / Auto","form2":"Automation QA-инженером","form3":"Automation QA-тестировщиком","form4":"QA / Auto","form5":"QA Auto"},"category":{"id":1,"slug":"qa","name":"QA"}},{"id":1,"name":"DevOps","slug":"dev_ops","morphs":{"form_first":"DevOps’а","form_second":"DevOps’ам","plural":"DevOps’ы","form_first_plural":"девопсов","form5":"DevOps’ов"},"seo_morphs":{"form1":"DevOps инженер","form2":"DevOps инженером","form3":"Девопсом","form4":"DevOps инженера","form5":"DevOps"},"category":{"id":10,"slug":"administration_sre","name":"Administration & SRE"}},{"id":25,"name":"Data Engineering","slug":"data_engineering","morphs":{"form_first":"Data Engineer","form_second":"дата-инженерам","plural":"дата инженеры","form_first_plural":"дата инженеров","form5":"Data Engineer’ов"},"seo_morphs":{"form1":"Data Engineer","form2":"дата инженером","form3":"Data Engineer'ом","form4":"Data Engineer'а","form5":"Data Engineer"},"category":{"id":14,"slug":"data_ml","name":"Data & ML"}},{"id":22,"name":"IT HR / Recruiter","slug":"tech_recruitment","morphs":{"form_first":"HR менеджера","form_second":"IT-рекрутерам","plural":"IT-рекрутеры","form_first_plural":"HR managers","form5":"IT-рекрутеров"},"seo_morphs":{"form1":"IT HR","form2":"Рекрутером","form3":"IT HR","form4":"IT HR","form5":"Recruiter"},"category":{"id":15,"slug":"hr_recruitment","name":"HR / Recruitment"}},{"id":12,"name":"Python","slug":"python","morphs":{"form_first":"Python-разработчика","form_second":"Python-разработчикам","plural":"Python-разработчики","form_first_plural":"разработчиков на Питоне","form5":"Python-разработчиков"},"seo_morphs":{"form1":"Python разработчик","form2":"Python developer","form3":"Python разработчиком","form4":"Python разработчика","form5":"Python"},"category":{"id":4,"slug":"backend","name":"Backend"}},{"id":15,"name":"PHP","slug":"php","morphs":{"form_first":"PHP-разработчика","form_second":"PHP-разработчикам","plural":"PHP-разработчики","form_first_plural":"PHP-разработчиков","form5":"PHP-разработчиков"},"seo_morphs":{"form1":"PHP разработчик","form2":"PHP developer","form3":"PHP разработчиком","form4":"PHP разработчика","form5":"PHP"},"category":{"id":4,"slug":"backend","name":"Backend"}},{"id":18,"name":"Java / Scala ","slug":"java_scala","morphs":{"form_first":"Java-разработчика","form_second":"Java-разработчикам","plural":"Java-разработчики","form_first_plural":"Джава разработчиков","form5":"Java-разработчиков"},"seo_morphs":{"form1":"Java разработчик","form2":"Java developer","form3":"Java разработчиком","form4":"Java разработчика","form5":"Java"},"category":{"id":4,"slug":"backend","name":"Backend"}},{"id":4,"name":"C#","slug":"c_sharp","morphs":{"form_first":"С# разработчика","form_second":"С# разработчикам","plural":"С# разработчики","form_first_plural":"С# разработчиков","form5":"С# разработчиков"},"seo_morphs":{"form1":"С# разработчик","form2":"С# developer","form3":"С# разработчиком","form4":"С# разработчика","form5":"С#"},"category":{"id":4,"slug":"backend","name":"Backend"}},{"id":17,"name":"C / C++","slug":"c_cpp","morphs":{"form_first":"C++ разработчика","form_second":"C++ разработчикам","plural": ...
#   </script>
#  </body>
# </html>

# %%
def get_info(soup):
    info = {}

    # название вакансии и компании
    info['title'] = soup.find('h1').text.strip()
    info['company'] = soup.find('h2').find('a').text.strip()

    # зарплата
    salary_container = soup.find(lambda tag: tag.name == 'h3' and any(char in tag.get_text() for char in ['₽', '$', '€']))

    if salary_container:
      info['salary'] = salary_container.text.strip()

    # места и типы работы
    place_container = soup.find('div', {'class': 'b-vacancy-locations'})

    if place_container:
      locations = place_container.find_all('span', {'class': 'g-label-secondary'})

      if locations:
        info['locations'] = [item.text.strip() for item in locations]

      categories = place_container.find_all('span', {'class': 'g-label-zanah'})

      if categories:
          info['categories'] = [item.text.strip() for item in categories]

    # основные условия
    terms_container = soup.find('div', {'class': 'b-specs'})

    if terms_container:
      term_titles = terms_container.find_all('div', {'class': 'b-term'})

      if term_titles:
        terms = {}

        for term_title in term_titles:
          term_value = term_title.find_next('div', {'class': 'b-value'})

          if term_value:
            terms[term_title.text.strip()] = term_value.text.strip()

        info['terms'] = terms

    # стек технологий
    stack_container = soup.find('div', {'class': 'b-vacancy-stack-container'})

    if stack_container:
      stack = stack_container.find_all('span')
      info['stack'] = [item.text.strip() for item in stack]

    # описание
    description_container = soup.find('section', {'class': 'b-vacancy-description'})

    if description_container:
      description_titles = description_container.find_all('h2') + description_container.find_all('h3')

      if description_titles:
        descriptions = {}

        for description_title in description_titles:
          description_list = description_title.find_next('ul')

          if not description_list:
            continue

          description_bullets = description_list.find_all('li')


          if description_bullets:
            description_value = ''

            for description_bullet in description_bullets:
              description_value += description_bullet.text.strip() + ' '

            if len(description_value) != 0:
              description_value = description_value[:-1]
              descriptions[description_title.text.strip()] = description_value

        info['descriptions'] = descriptions

    return info

# %% [markdown]
# Посмотрим, как выглядит получившийся словарь. Все соответсвует ожиданиям :)

# %%
get_info(soup)
# Out:
# {'title': 'Affiliate Manager',
#  'company': 'Winline',
#  'salary': '150 000 —\u200d 200 000 ₽/мес на руки',
#  'locations': ['📍 Москва (м. Шелепиха)'],
#  'categories': ['Офис несколько дней в неделю'],
#  'terms': {'Специализация': 'Product Analyst / Product Manager / Project Manager',
#   'Уровень': 'Middle',
#   'Требуемый опыт': '2+ лет'},
#  'stack': ['Google Analytics', 'Яндекс.Метрика', 'Excel', 'PowerPoint'],
#  'descriptions': {'Обязанности': 'Поддерживать и развивать партнерские отношения с текущими веб-мастерами. Искать новых целевых клиентов. Вести отчетность и анализировать текущий трафик. Контролировать размещение промо-материалов на сайтах СМИ. Проводить сверку и еженедельный контроль партнеров на предмет фрода. Оперативно коммуницировать с партнерами в чатах и по почте. Отслеживать тренды рынка и мониторить конкурентов для оперативного реагирования и изменений.',
#   'Требования': 'Опыт работы в Affiliate-маркетинге на позиции менеджер (от 2 лет). Понимание видов трафика и принципов их работы, как performance, так и brand. Опыт подключения и поиска новых источников трафика. Умение анализировать трафик, понимание принципов работы антифрод-систем. Понимание и принцип работы веб-трафика. Уверенное знание Excel и PowerPoint. Уверенный опыт работы с Google Analytics и Яндекс.Метрикой. Сильные аналитические способности. Развитые коммуникативные навыки, умение презентовать проекты и защищать результаты. Умение работать в команде и проактивность — быть драйвером процессов, а не просто реагировать на запросы.',
#   'Условия': 'Оформление по ТК. График работы: 5/2 в офисе с 11:00 до 19:00. Адрес офиса: Москва, Причальный проезд, 2А. Полный офис без гибрида и удаленки.'}}

# %% [markdown]
# Соберем информацию о вакансиях по каждой из полученных ранее ссылок (пропустим первые три, как и было замечено ранее, это реклама: weekend offer и прочее).

# %%
vacancies = []

for url in vacancies_urls[2:]:
    vacancy = requests.get(f'https://getmatch.ru{url}')
    soup = BeautifulSoup(vacancy.content, 'html.parser')

    info = get_info(soup)
    vacancies.append(info)

print(vacancies)

# %% [markdown]
# Посмотрим какие есть значения у разных ключей.

# %%
unique_titles = set(vacancy.get('title') for vacancy in vacancies)

print('\n'.join(unique_titles))
# Out:
# Content Product Manager
# Бизнес партнер по информационной безопасности
# Руководитель команды аналитики маркетинга (Работа)
# Тимлид разработки DWH
# Тимлид команды продуктовой аналитики
# Старший аналитик
# Talent Acquisition Researcher
# Руководитель направления по аналитике (Лояльность)
# Ведущий аналитик 1С
# Руководитель инфраструктурной команды
# Разработчик на Golang/Python (Платёжный шлюз)
# Специалист сопровождения АБС (Финтех-сервисы)
# DevOps (Финтех)
# Middle/Senior Product Designer
# Marketing Analyst
# Инженер доступности сервисов / SRE (Cloud Storage)
# QA Automation Engineer
# Сетевой инженер
# Node.js Developer (Парсинг)
# Infrastructure Engineering Lead / Менеджер ИТ-инфраструктуры
# Senior Frontend Developer (React)
# Senior Golang Developer (Продуктовая платформа)
# Младший инженер технической поддержки пользователей
# Системный администратор технической поддержки
# DevSecOps & Security Engineering Team Lead
# Security Champion in SW Development / Специалист по информационной безопасности (TATLIN.OBJECT)
# Product Analyst (Seller Experience)
# SDET (Python)
# Бэкенд-разработчик (Monitoring/Observability)
# Fullstack C# Developer
# Специалист технической поддержки пользователей / Системный администратор
# Инженер технической поддержки L3 (Сетевое оборудование)
# Инженер по нагрузочному тестированию (Система быстрых платежей)
# Продуктовый аналитик (Авто.ру)
# ML-инженер (Information Retrieval)
# Frontend Developer (VK Видео)
# Тимлид разработки (Команда Подработки)
# Senior Data Scientist (блок "Сеть Продаж")
# Golang-разработчик (Xранение данных)
# BI-разработчик (Репутационная система)
# Senior Go Developer
# Data Engineer (Big Data)
# Flutter-разработчик (CityLens)
# ML-разработчик
# Руководитель проектов BPMSoft / Тимлид
# Frontend Developer
# Go-разработчик
# Recruiter (Non-tech)
# Аналитик по информационной безопасности (Compliance, внутренний аудит)
# Разработчик хранилища данных
# Аналитик (Аналитика выплат)
# Senior Frontend Developer
# Разработчик инфраструктуры автоматического UI-тестирования приложений (iOS)
# Инженер автоматизированного тестирования (JavaScript)
# Специалист технической поддержки
# Backend-разработчик (Jobs)
# Product Analyst (Buyer Experience)
# Разработчик интерфейсов (Директ)
# Head of ML (NLP)
# Старший системный аналитик
# IT Support Specialist (L1)
# Инженер мониторинга (L1)
# Бэкенд-разработчик (Yandex Cloud)
# Разработчик на С++ (Телеметрия)
# Аналитик данных (RuBackup)
# Разработчик виртуальной сети (Overlay)
# Java Developer (IAM)
# Менеджер продукта 1С (Финансовый блок)
# Golang-разработчик (2GIS.KIT)
# Администратор PostgreSQL
# Vue.js-разработчик
# Тестировщик (OEBS-разработка)
# Lead ML Engineer
# Инженер технической поддержки (Linux, 2 линия)
# Автотестировщик (Java)
# Ведущий аналитик SQL
# DevOps-инженер (WorkSpace)
# Инженер SOC (Партнерский найм)
# Senior Python Backend Engineer
# Senior Data Scientist (Rec. System)
# Fullstack Engineer (Attribute Enrichment)
# Go-разработчик (Performance)
# QA Engineer (Ручное тестирование)
# Тимлид разработки (DataWave)
# Лидер платформенной команды
# С++ Developer (Путешествия)
# Старший системный администратор Linux
# Senior DWH Developer
# Разработчик на C++
# Senior Backend-разработчик
# Data архитектор / Старший аналитик данных
# Консультант по поддержке веб-решений (1С:Битрикс)
# Backend Team Lead (Python)
# ETL-разработчик
# Python Backend Developer
# iOS-разработчик (Architecture & Culture)
# Руководитель группы разработки с бэкграундом senior-разработчика и опытом руководства (Платформа рейтингов и отзывов)
# Старший аналитик данных (Sales Efficiency)
# Системный аналитик (ОС Аврора)
# Fullstack-разработчик (PL/SQL + Java)
# Архитектор YDB
# Руководитель команды аналитики (Авито Реклама)
# Инженер по тестированию (Десктопное приложение Диска)
# Руководитель центра диджитализации процессов
# Разработчик 1С:УХ
# Инженер presale (WorksPad)
# Linux Server Engineer
# Руководитель по внедрению решений продвинутой аналитики (AI-product)
# Аналитик данных (Операции)
# Backend-разработчик (PlatformX)
# Старший разработчик интерфейсов (Финтех)
# Golang Developer (SRE-команда)
# Technical Product Manager
# Руководитель команды инфраструктурной кибербезопасности
# Senior Product Manager (СMS)
# Руководитель команды разработки (Python)
# SDET-инженер (Ozon Банк)
# Go Developer / Старший инженер-программист Go (Telecom)
# Senior Data Scientist (Поисковое ранжирование)
# Backend-разработчик (Node.js)
# Python-разработчик инфраструктуры Big Data
# Golang-разработчик
# Senior Frontend Developer (Vue.js)
# Algorithms and Models Engineer
# Platform Architect
# Продуктовый дизайнер (Карта)
# Project Manager
# Аналитик данных (Антифрод)
# Senior Database Engineer
# BI-разработчик
# Старший Backend-разработчик (Auto Private)
# UX/UI-дизайнер
# Java-разработчик (Кинопоиск)
# Старший аналитик данных (Communications)
# Multitrack для фронтенд-разработчиков
# Backend Engineer
# Database Developer (ClickHouse)
# Data Engineer (ML Team)
# Разработчик системы логирования (Cloud)
# Senior User Behavior Analyst
# Финансовый аналитик (B2C)
# Младший дата-аналитик (Контент)
# Machine Learning Engineer (Attribute Enrichment)
# Менеджер продукта (Видео)
# Системный администратор
# Software Engineer C/C++ (Telecom)
# Service Delivery Lead
# Руководитель платёжных сервисов (B2B-направление)
# Fullstack QA Engineer (Частное облако)
# Риск-менеджер (Валидация моделей некредитного риска)
# Golang Team Lead (SDN)
# Пресейл-инженер по информационной безопасности
# Системный инженер (Data Lake)
# ML-разработчик (Исследования видеосжатия Кинопоиска)
# System Engineer
# Архитектор ПО (Абонентское оборудование)
# Архитектор СРК
# Инженер по автоматизации тестирования Python (Ozon Bank)
# Аналитик данных (Monetization Efficiency)
# Продуктовый менеджер
# Junior/Middle Data Engineer
# Корпоративный архитектор
# Технолог бизнес-процессов
# Инженер по автоматизации тестирования (Cloud)
# Маркетинговый аналитик (Ozon Банк)
# Тестировщик
# Golang/Python Developer
# Заместитель руководителя отдела тестирования (Termidesk)
# Senior Data Engineer (DWH)
# Senior iOS Developer (Магнит Косметик)
# Специалист по информационной безопасности
# Инженер технической поддержки
# Senior Automation QA Engineer
# Директор направления аналитики 1С
# ML-инженер (Сomputer Vision)
# Разработчик DWH
# Системный аналитик (Зарплата)
# Android Developer
# Технический архитектор
# Инженер технической поддержки серверов x86
# Head of Product (Monetization)
# Архитектор модели данных
# Эксперт CLTV
# Backend Developer (Support Systems)
# Backend Engineer (Experiments Team)
# R&D Software Engineer
# Дизайнер презентаций
# Разработчик Go (Ozon Банк)
# Fullstack-разработчик (Symfony, Vue.js)
# Python-разработчик
# Аналитик данных (Walk-in)
# Senior Data Scientist (Recommender Systems)
# Специалист технической поддержки (Поддержка информационных систем)
# Специалист технической поддержки (L2)
# Бизнес-аналитик ЦФА
# Senior Backend QA (Core Team)
# Backend-разработчик (Команда Подработки)
# Разработчик PL/pgSQL
# Аналитик (РТИТС)
# Дежурный аналитик SecOps
# Data Engineer
# Разработчик Inference Server на C++ (ML-инфраструктура)
# Инженер SOC L2 (Партнерский найм)
# Сервис-менеджер
# AppSec / Специалист по безопасной разработке
# Senior Data Engineer
# Senior QA Engineer (Portal FSP)
# Аналитик-разработчик (Противодействие пиратству, Кинопоиск)
# Инженер по тестированию (Мобильный Диск)
# Ведущий инженер-программист С++ (Framework)
# Технический менеджер платформы Observability
# Старший инженер VMware
# Разработчик на С++ (Инфраструктура распределённого биддера Рекламы)
# Senior Data Analyst (Маркетинг)
# Инженер по нагрузочному тестированию
# Lead C++ Software Engineer
# Backend Developer (Node.js)
# Старший системный администратор KSC
# Дата-инженер (Oracle, поддержка SL2)
# SRE-инженер (Эксперт по надежности)
# Backend Node.js Developer
# LabOps / Инженер ЦОД (KORNFELD)
# Senior Java-разработчик (Маркет Хабы)
# Solution Architect (Платформенные сервисы)
# Инженер DevOps (Едадил)
# Консультант по внедрению систем класса WMS
# Mobile UX/UI дизайнер (Трайб Digital)
# Ведущий аналитик (Финтех)
# Аналитик (Автоматизация аналитики для крупных клиентов)
# Инженер по автотестированию
# Golang-разработчик (Network Operations Center)
# Senior DevOps Engineer (Infrastructure)
# Аналитик данных (Дата-команда)
# DevOps / Infrastructure Engineer
# Project Manager (UX/UI)
# Product Manager (API)
# Ведущий инженер систем мониторинга
# Разработчик сетевого блочного устройства
# Chief Product Officer
# Senior Java Developer (RuStore)
# Дежурный системный инженер
# Программист
# Аналитик данных (Marketing Mix Modeling)
# Operations Product Owner
# Backend Developer Scala (Вертикали)
# Технический Presale-инженер по инфраструктурной автоматизации
# QA Automation (Python)
# Team Lead Java
# Системный аналитик в инвестиционное направление (СОФР, Диасофт, Брокер)
# Продуктовый дизайнер (Яндекс ID)
# System Engineer (TATLIN.OBJECT)
# System Analyst (SberData)
# Аналитик данных (Авто.ру)
# Senior .NET Developer (Dephaze)
# Senior Golang Developer
# ML-разработчик (Генеративные e-com-сценарии, LLM)
# Инженер по инфраструктурной безопасности
# DevOps-инженер (Kafka)
# Специалист поддержки рабочих мест
# Специалист отдела управления доступом (Партнерский найм)
# Backend Engineer (Sponsored Listings)
# Инженер (R&D RuPost)
# Аналитик 1С (Revenue & Bank)
# Analytics Engineer
# Product Analyst
# Senior DevOps Engineer
# Engineering Manager (B2B Unit)
# PHР + Go Developer (Ж/Д)
# Senior BI Analyst
# Разработчик C++
# ETL-разработчик (CVM)
# DL-разработчик
# Технический продакт-менеджер (Tech Excellence)
# Продуктовый аналитик / Аналитик данных (Фиджитал)
# Ночной инженер технической поддержки (Linux)
# Product Manager (FinTech)
# Программист 1С (БИТ.Финанс)
# Tech Recruiter
# Ведущий инженер-программист в QA (Grafana and PostgreSQL)
# Старший Python/Go-разработчик
# Тимлид команды разработки поискового сервиса (Работа)
# Старший разработчик С++
# Tech Lead / Team lead Java
# Эксперт по сопровождению банковского процессинга
# C++ Developer
# Старший инженер экспертной поддержки СХД (TATLIN R&D)
# Сменный инженер технической поддержки
# Multitrack для С++-разработчиков
# BI-аналитик
# Senior С++ Developer (Mobile SDK)
# Архитектор решений (Solution Architect)
# Инженер данных
# Специалист технической поддержки 1С
# Аналитик мультимодальных генеративных моделей
# Разработчик на C++ (Разработка и развитие внешнего инвентаря)
# Product Marketing Manager
# Инженер по системам мониторинга
# Руководитель направления по реагированию на инциденты информационной безопасности (Lead SOC L2)
# Тестировщик (Финтех и Плюс)
# Team Lead Backend (Python: Django)
# Middle Fullstack Developer (React.js + Node.js)
# Lead Data Engineer (Сеть продаж)
# Системный аналитик (Обработка и архив данных)
# Product Designer
# Аналитик-разработчик (Реклама)
# Java-разработчик (Дзен)
# Разработчик 1С:ЗУП
# Senior Product Analyst (CVM)
# AppSec-инженер (Партнерский найм)
# PHP Developer / Backend (Symfony)
# Инженер внутренней технической поддержки
# Аналитик по информационной безопасности (WAF/Anti-DDoS)
# Аналитик по информационной безопасности (Платежные системы)
# DevOps-инженер (Виртуализация)
# Дизайнер пользовательских интерфейсов
# Senior Backend Developer (С#/.NET)
# Team Lead DS (Рекомендательные системы)
# Senior AI/ML Engineer
# Team Lead Frontend Developer
# Data Engineer (Data Platform)
# Аналитик (Кампейн)
# Руководитель по развитию продукта («Дебетовая карта» в онлайн-каналах)
# Frontend Developer / React Developer
# Продуктовый аналитик (Путешествия)
# Senior Frontend Developer (Rust)
# Data Engineer (Clickstream, Flink)
# Product Manager (B2B)
# Senior Java/Kotlin Developer (GigaCode)
# QA Automation Engineer (Ж/Д)
# Разработчик БД PosgreSQL / Oracle
# Старший дизайнер продукта (Алиса)
# Инженер сопровождения (Астра Консалтинг)
# Market Data Engineer
# QA Automation в команду Private Users
# Старший системный аналитик (Core Banking Platform)
# Специалист QA Web
# Senior HTML / Markup Developer
# Privacy Engineer (DPO)
# UI/UX Designer
# Product Owner (CRM)
# Разработчик для iOS (Карты и Навигатор)
# Аналитик (Маркет для бизнеса)
# Java-разработчик (Risk Controls Services)
# Java Developer
# Senior Recruiter
# Начальник отдела технической экспертизы и сопровождения ЦОД
# Java/Kotlin-разработчик (Платформа дебетовых продуктов)
# Руководитель SOC (Партнерский найм)
# Senior QA Automation Engineer (Android)
# Senior Frontend Developer (Vue)
# Product Lead (B2C)
# Руководитель команды аналитики HR
# iOS-разработчик (Фича-команда Дзен)
# Principal C++ Developer
# Релиз-менеджер
# Старший аналитик (Клиенты)
# Архитектор решений / Solution Architect
# Solution Architect
# Senior PHP Developer
# Старший системный аналитик (Client Taxes)
# Менеджер по ИТ бизнес-решений
# Разработчик BPMSoft
# Senior Developer (Логистическая платформа)
# Data Engineer (Мой дом в СБОЛ)
# Разработчик Swift (Инфраструктура клиентской аналитики и тестирования)
# Flutter Developer
# Senior Product Analyst (Средний и малый бизнес)
# Infrastructure Security Engineer
# Middle/Senior С# Developer (YouRa)
# Консультант 1С:ERP
# Архитектор по облачным решениям
# Продуктовый аналитик (Монетизация Дзен)
# Senior Data Scientist
# Руководитель проектов информационной безопасности
# Backend-разработчик (Документы)
# Ведущий продакт-менеджер экосистемы по взаимодействию с продавцами
# Разработчик на Java (Core Backend)
# Backend Developer (Symfony)
# Системный аналитик (Виртуализация)
# Talent Acquisition Partner (Tech)
# Аналитик (Антифрод)
# Lead Algorithms and Models L2+ Layer Manager
# Специалист DS NLP (RAG и LLM, блок "Сеть Продаж")
# Технический бизнес-аналитик (TADS)
# Архитектор данных
# Специалист технической поддержки (Магнит Маркет)
# Разработчик (Engineering Infrastructure)
# Прикладной администратор (Поддержка L3)
# Data Scientist
# Senior Python Developer (RuPost)
# Архитектор
# Главный специалист по развитию источников данных
# Техлид (Системное администрирование дежурной службы)
# Старший коммуникационный дизайнер
# Senior Data Scientist (Search & Recommendation)
# Аналитик-разработчик (Рекламная платформа)
# Fullstack-разработчик C#/.NET
# Старший инженер технического сопровождения (3 линия)
# Senior Data Scientist (Computer Vision в RnD)
# Разработчик интерфейсов (Монетизация Поиска)
# Инженер мониторинга
# Senior Fullstack Analyst
# QA TypeScript+Playwright Engineer
# Senior Python Developer
# Аналитик (Аналитика курьерского дохода)
# Специалист по непрерывной технической поддержке
# Разработчик PostgreSQL
# Network & Infrastructure Team Lead
# JavaScript Full-Stack Developer
# ML Engineer (Digital Financing)
# Software Engineer (Embedded, C)
# BI-разработчик (Антифрод)
# Senior QA Python Automation Engineer
# Разработчик алгоритмов ценообразования (C++)
# Senior HR Business Partner
# Service Monitoring and Support Specialist (Linux)
# Senior Product Manager (AI, Telegram Bots)
# Odoo Developer
# Инцидент-менеджер
# Fullstack-разработчик C++ (Виртуализация)
# Java/Kotlin-разработчик (Разработка KYC и AML)
# Инженер технической поддержки (Yandex Cloud)
# Бизнес-партнер по информационной безопасности (Домен CIB)
# JavaScript Fullstack Developer
# Портфельный риск-менеджер
# Team Lead разработки (Auto Finance)
# Руководитель группы разработки (Node.js)
# Разработчик Unified Agent
# Продуктовый дизайнер (Сервисы развития)
# Senior Network Engineer (PreSale Support / KORNFELD)
# Business Analyst
# Data Scientist / ML Engineer (Прогноз промо-продаж)
# Разработчик C# (Tessa)
# Аналитик данных (Финансовые модели, финансовый результат)
# Head of AI
# Продуктовый аналитик депозитных продуктов
# Инженер по сопровождению (OLAP Analytics)
# 3D-моделлер (Лаборатория дизайна)
# Архитектор облачных решений
# Sourcer (IT/Product)
# Frontend Tech Lead
# Разработчик С++ (Алгоритмы ранжирования поиска)
# Senior Product Analyst
# Haxe Frontend Developer (Mobile)
# Senior Product Manager (Ranking)
# Backend Engineer (Go)
# Delivery Manager
# DevOps-инженер (Развитие инструментов мониторинга систем)
# Frontend-разработчик (Взгляд)
# Backend-разработчик (Core Services / Инфомодель)
# Разработчик 1С
# Функциональный архитектор 1С
# Go Developer (Mail)
# Tech Lead
# Консультант по информационной безопасности (Ключевые цифровые системы и персональные данные)
# Ведущий эксперт по виртуализации сетевой инфраструктуры
# Специалист технической поддержки (2 и 3 линия)
# Tech Lead .NET (Collateral Platform)
# Senior UI Designer
# Go-разработчик (Финтех)
# Fullstack Developer
# Аналитик данных / Data Scientist
# Сетевой архитектор
# Старший инженер технической поддержки
# Системный администратор Linux
# Domain Architect
# Администратор СУБД Greenplum (DBA)
# Kernel Developer
# QA Automation Java
# Fullstack-разработчик (Карты)
# Разработчик Go
# Fullstack QA Auto Specialist
# Senior DevOps Engineer (MongoDB)
# Fullstack-разработчик
# Lead QA Automation (iOS)
# Руководитель отдела разработки
# Старший инженер по управлению уязвимостями
# Менеджер продуктов вовлечения (Авто.ру)
# Руководитель группы разработки (VK Музыка)
# PHP Developer
# Python Developer
# Ведущий продуктовый аналитик
# Infrastructure Architect
# IT Lead (Java)
# Team Lead (Symfony)
# Senior Backend Developer (Python)
# Руководитель отдела внутреннего ИТ
# Linux-инженер
# Senior System Administrator
# Продуктовый аналитик (Отели)
# DevOps Engineer / Python Developer
# Go Developer
# Head of Product (Offer Walls)
# Senior Data Scientist / ML Engineer (Чековая аналитика)
# System Analyst
# QA-инженер (Customer Tech)
# Product Designer (Сплит и Кредиты)
# Разработчик бэкенда (Managed Kubernetes)
# Ведущий Python-разработчик (Цифровой двойник)
# Разработчик БД Oracle
# Tech Lead C#
# Бэкенд-разработчик (Core Services / Items)
# DWH Engineer
# Application Security Engineer (Путешествия)
# Senior Engineer Python
# Backend Tech Lead
# Senior Node.js Engineer
# Руководитель команды разработки (Торговый эквайринг)
# Архитектор решений
# Data Analyst / Data Scientist (HR MAX)
# Growth-аналитик
# Инженер сопровождения VDI-решения
# ИТ-лидер кластера аналитической отчетности
# Лидер кластера Сделка
# SRE (Инфраструктурный Kubernetes)
# Администратор инфраструктуры
# Автор курса «Продуктовый аналитик»
# Junior Game Designer
# Fullstack Engineer
# Дежурный инженер
# Senior/Lead Product Designer (Investments)
# Администратор ОС Linux (Эксплуатация серверных ОС)
# Инженер-аналитик
# Аналитик данных
# Разработчик на Python
# Product Team Lead
# Руководитель группы разработки C/C++
# Golang Tech Lead
# Frontend-разработчик (ПК СВ Брест)
# QA Engineer Mobile (Java)
# Senior Golang Engineer (Отелло)
# Product Manager / Product Оwner (Web B2B)
# Старший Kotlin-разработчик (Обучение и развитие)
# Middle+ System Analyst (Личный кабинет)
# DevOps Engineer (ML & Analytics)
# Инженер DevSecOps
# Архитектор ИБ (Департамент информационной безопасности)
# Junior QA / Тестировщик (Нагрузочное тестирование)
# Android-разработчик (Инфраструктура клиентской аналитики и тестирования)
# Application Security Engineer
# Разработчик Arenadata
# Python Software Engineer
# Менеджер продукта
# Python Developer (ML Team)
# АQA Java
# Руководитель группы разработки встроенных систем (Абонентское оборудование)
# C++ SWE
# Senior IT Recruiter
# Team Lead PHP
# Product Manager
# SRE (Managed Service for PostgreSQL)
# Backend-разработчик
# Lead QA Automation Engineer (Python)
# Аналитик данных (Клиентская аналитика)
# Разработчик на Java
# Бизнес-архитектор
# Старший Java-разработчик
# Техлид (BPMSoft)
# Технический менеджер продукта (DevTools)
# Project / Account Manager
# Старший инженер по эксплуатации (Облако)
# Reliability Engineer
# Lead Backend Developer
# Системный аналитик 1С
# C++ Developer (Gates Team)
# Senior Software Engineer (Data Platform)
# Linux-инженер (VDI)
# Backend Developer
# Руководитель направления продуктового дизайна (Лаборатория дизайна)
# Quantitative Researcher
# Аналитик BI
# Python Developer (KORNFELD)
# Разработчик С++ (Поисковые запросы)
# Cпециалист по прикладной/сетевой безопасности (Партнерский найм)
# Data Architect
# Аналитик-разработчик (Meta DWH)
# Data Scientist Lead
# Разработчик бэкенда (Маркетплейс)
# Golang Developer
# Site Reliability Engineer / Инженер по надежности
# Автотестировщик
# Team Lead (Работа)
# QA Automation Engineer (JavaScript / TypeScript)
# Консультант по внедрению информационных систем
# Senior C++ Developer
# Руководитель команды моделирования розничного риск-менеджмента
# Go-разработчик (Продукты e-com для бизнеса)
# Автор на курс «Middle C++ Developer»
# C++ Team Lead (3D-карта)
# Разработчик на Java (Диск)
# Тимлид команды аналитики доли (Поиск)
# Senior Fullstack Developer
# Lead UI/UX Designer
# Senior Data Scientist (Оптимизация ценообразования)
# Бизнес-аналитик по направлению идентификации клиентов (KYC)
# Разработчик Oracle
# Менеджер по интеграции IT-систем
# Специалист технической поддержки (ОС Linux)
# Лид продуктовый аналитик (Кросс-сервисные проекты экосистемы Банка)
# Системный / DevOps-инженер (Проектирование инфраструктуры ЦОД и управление развертыванием)
# Technical Product Lead
# Программист C/C++ (STL, Boost)
# Senior Data Analyst
# Инженер данных DWH
# AI Developer
# Руководитель направления плагинов для IDE
# Старший аналитик данных (Зарплатные продукты)
# Senior Software Engineer
# Senior Product Manager (Ипотека)
# ML Engineer (Вертикали)
# DevOps (Windows, C#, MS SQL)
# Руководитель комплексных проектов (Сеть и радиосвязь)
# Тимлид (Развитие Автосборки)
# iOS Developer
# Tech Lead Golang
# Senior System Engineer (TATLIN.UNIFIED)
# Архитектор информационной безопасности
# DevOps Engineer (Kubernetes)
# Software Architect
# Junior Data Analyst (Блок "Стратегия и развитие")
# Аналитик по привлечению и маркетингу
# Старший Go-разработчик (Продукты e-com для бизнеса)
# Ведущий разработчик .NET
# Ведущий инженер поддержки Data Platform (Yandex Cloud)
# Product Manager (Дзен)
# Data Scientist (Поиск Маркета)
# Разработчик баз данных (PostgreSQL)
# MultiTrack для фронтенд-разработчиков
# Backend Javа Developer
# Middle+/Senior C# and MS SQL Developer
# IT Support Engineer L2 / System Аdministrator
# Senior / Team Lead Java Developer
# Senior Java Developer
# QA-инженер (Авито Подработка)
# Ведущий бизнес-аналитик (SQL)
# Инженер технической поддержки 1С:ЗУП
# Разработчик Oracle (Финтех)
# Старший специалист группы соответствия регуляторным требованиям и внешней отчетности
# Промышленный дизайнер (Умные устройства с Алисой)
# Инженер RnD (RPA)
# Ведущий сетевой инженер
# Технический писатель (PaaS)
# Продуктовый аналитик (Реклама)
# Разработчик Go (Банк)
# Android-разработчик (Delivery & Performance)
# Разработчик для Android (Рекламная сеть)
# Ведущий инженер технической поддержки
# Senior Java Developer (ЦФА)
# Team Lead Developer (Python)
# 3D-дизайнер
# Site Reliability Engineer
# DWH Developer
# Менеджер продукта (Международное развитие)
# Разработчик 1С (Legal Tech)
# Go Backend Developer (VK Видео)
# Руководитель группы автоматизации тестирования (Ozon Банк)
# Core Infrastructure Engineer (HCI + VDI)
# Системный администратор (Linux)
# Аналитик данных BizDev (Реклама)
# Продуктовый аналитик (Маркетинг)
# Python Developer (Labs)
# Администратор баз знаний / Knowledge-менеджер
# Разработчик интерфейсов (Арканум)
# Solution Architect / Lead MLOps Engineer (ML-платформа)
# Разработчик C++/Python (Управление роботами)
# Инженер 2 линии технической поддержки
# Lead Go Developer (PT Application Firewall)
# Ведущий разработчик бэкенда (Ecom-cценарии)
# DevOps Engineer (PaaS App.Farm)
# Системный аналитик (Автономный транспорт)
# Разработчик на Go (CloudGate)
# Руководитель направления DevOps-инженеров
# Инженер технической поддержки (3 линия)
# Менеджер / Технический руководитель проектов
# Разработчик интерфейсов (Буткемп Поиска)
# SRE Engineer
# Системный инженер / DevOps (ИТ-инфраструктура)
# DBA
# Data Engineer (Коммуникационные платформы)
# ML Lead (Дзен)
# Бэкенд-разработчик (DEV)
# Middle+ Backend Java Developer
# DBA (PostgreSQL)
# Data Engineer (ML)
# Инженер систем мониторинга и оповещений
# AppSec Engineer
# Tech Lead Frontend Developer (Astra Monitoring)
# TL Data Engineer
# Старший разработчик (ML-инфраструктура YTsaurus)
# Team Lead Backend Developer (Cyprus)
# Principal Tech Lead (Digital Financing)
# Старший системный инженер Linux
# C++-разработчик (3D Карта)
# Системный аналитик (Онлайн-банк)
# Frontend-разработчик (CDC RBO)
# Android-разработчик приложений
# Аналитик DWH
# Senior Fullstack Developer (.NET, React)
# Java-разработчик (Нирвана)
# Tech Lead Kotlin/Java
# Senior Business/System Analyst
# Product Manager (ID)
# Продуктовый аналитик платформы коммуникаций
# Product Designer (Карты)
# Ведущий эксперт по транспортной сети
# DWH Analyst
# System Level Simulator Engineer (AME-L2-SIM)
# Инженер поддержки в команду разработки
# Старший специалист по тестированию (Senior QA Web)
# Product Design Lead
# Разработчик в Арканум (Сервис управления исходным кодом)
# Аналитик направления анализа защищенности мобильных приложений (Рentest)
# Технический архитектор 1С
# Менеджер продукта (Клиентский опыт)
# Design Lead (B2C)
# Business System Analyst
# Главный специалист по поддержке SAP HR
# Python-разработчик (Yandex DataLens)
# System Analyst (IT Finance)
# Data Engineer (Экосистемные сервисы)
# Архитектор / Java Tech Lead
# Team Lead команды мониторинга
# Ведущий инженер данных (Data Platform / ML)
# Programmer-researcher
# Аналитик данных (Промо платформа)
# Frontend-разработчик (Яндекс.Вертикали)
# Бизнес-аналитик
# Инженер отдела технической поддержки
# BI-разработчик (Работа)
# Team Lead of Prompt Engineers
# Frontend Tech Lead / Senior Developer
# Senior DevОps Engineer
# Инженер качества данных
# Архитектор ПО
# Инженер по автоматизации тестирования
# Ведущий аналитик 1С:ЗУП
# Ведущий продуктовый дизайнер (Истории)
# Senior BI Developer
# Frontend Team Lead
# Data Engineer (GreenPlum)
# Разработчик инфраструктуры (Мобильные Яндекс Карты)
# Go Team Lead
# Разработчик (E-com продукты для бизнеса)
# Data Analyst (Блок "Сеть Продаж")
# Senior Android Developer
# Core Desk Go Developer
# Data Scientist (CoreML + RecSys)
# Network Engineer
# Архитектор кластера (Цифровая платформа)
# iOS-разработчик тестового фреймворка (Speed)
# C++ Developer (KORNFELD)
# Разработчик инфраструктурного облака (Go)
# Разработчик компьютерного зрения (SportTech)
# Senior Frontend Developer (Digital Financing)
# Технический писатель (Хранение данных)
# C# Developer (.Net)
# Senior Performance QA Engineer
# Специалист технической поддержки (2-я линия)
# SRE-инженер (PAM)
# Разработчик интерфейсов (Ecom-сценарии)
# Руководитель проектов (Сеть и радиосвязь)
# Senior/Senior+ Java Developer
# Team Lead / Architect TypeScript, NodeJS
# Team Lead Data Science (Рекомендации)
# Старший аналитик данных (Реклама)
# Middle/Senior Frontend Developer
# Senior System Analyst
# Руководитель направления мониторинга (NLP-модели)
# Python Developer (OAM/NMS)
# Senior Frontend Engineer (Web3)
# Аналитик данных (Отелло)
# IT Product Owner
# Специалист технической поддержки iGaming (B2B)
# Консультант 1С (Бухгалтерия)
# Системный инженер Microsoft (MECM, SCCM)
# Lead Python Developer (Backend / Server Side)
# QA Automation Engineer (Python)
# DevSecOps Engineer
# Технический лидер (Сеть)
# Главный инженер IDM
# Руководитель разработки (Internal Systems)
# Аналитик-разработчик (антифрод Рекламы)
# Старший системный администратор / SRE
# Разработчик PHP/Go (Aвиа)
# Продуктовый дизайнер (Контентные сервисы)
# Разработчик IBM PA/Cognos TM1
# QA-инженер (Операционное управление)
# Системный аналитик BI (Senior)
# Администратор баз данных (PostgreSQL)
# Data Scientist / ML Engineer (Развитие искусственного интеллекта)
# Главный системный аналитик (DWH)
# Аналитик данных (Performance-маркетинг)
# Промышленный дизайнер (Лаборатория дизайна)
# Тимлид (Ядро системы сборки)
# Коммуникационный дизайнер
# Team Lead DWH (Data Office)
# Инженер внедрения (Службы каталогов)
# Data Engineer (Integration)
# Platform Engineer (PaaS)
# QA Engineer (Payments Fiat Domain)
# Коммуникационный дизайнер (Гейм-студия)
# Fullstack Software Engineer (React + Python)
# SRE-инженер
# Бизнес-аналитик данных
# Разработчик интерфейсов (Группа развития финансов Поиска)
# Разработчик (Гибридные облака)
# Менеджер по продуктам
# Разработчик в команду алертинга
# Ведущий системный администратор СУБД
# Golang Engineer
# Аналитик данных (Работа)
# Golang-разработчик (Social)
# С++-разработчик
# Менеджер по нагрузочному тестированию
# Growth Рroject Мanager (Яндекс Пэй и Сплит)
# Архитектор по информационной безопасности
# Data Analyst (Блок "В2С")
# Middle Backend Developer (PHP)
# Lead Data Scientist (Сеть продаж)
# Специалист QA (Mobile/SmartTV)
# Аналитик 1С:УХ (Управление холдингом)
# HR Business Partner
# C++ Developer (Алгоритмы Поиска)
# Аналитик (Развитие централизованных платформ)
# Senior Python Developer (SDET)
# ИТ-лидер (Cистемы LES MES)
# Product Manager (Генеративные решения и цифровые помощники)
# AppWebSec (Rustore)
# Frontend-разработчик
# Системный аналитик DWH
# Java-разработчик (Служба управления роботами)
# Системный аналитик (Банковский процессинг)
# ML-разработчик (Ценообразование)
# QA Engineer (PSP Integration)
# Senior Data Scientist (B2С)
# DevOps-инженер (ML-сервисы)
# Senior ML Engineer (NLP)
# Senior Product Designer
# Разработчик интерфейсов (DataLens)
# Администратор Atlassian
# Тимлид разработки (HRM)
# Senior DS NLP (Центр компетенций по внедрению ИИ-агентов / блок «Стратегия и развитие»)
# Рython-разработчик
# QA Engineer (Client Interaction Platforms)
# Начальник технической поддержки
# Middle QA Automation Engineer
# Senior Frontend Developer (Angular 15)
# Java/Kotlin-разработчик (Платформа кредитных продуктов)
# Java/Kotlin-разработчик
# Frontend-разработчик (Создание инструментов стабильности)
# DevOps-инженер (Развитие платежных сервисов)
# Data Engineer (Служба подготовки и анализа больших данных)
# Director of Frontend Development
# Главный аналитик
# Lead Frontend Developer
# Senior Node.js Developer
# Разработчик на С++/Python (Система управления флотом роботов)
# Десктоп-разработчик в Сore-команду (С++, Qt)
# Системный аналитик
# IT Tech Lead / IT Solution Lead (Track & Trace)
# Java-разработчик (Spring)
# Senior DBA
# Virtualisation's DevOps Engineer
# Manual QA Engineer
# DevOps/SRE-инженер
# Менеджер проектов (Банк)
# Frontend Developer (Vue.js)
# Разработчик на C++ (Управление автономного транспорта)
# Продуктовый / Дата-аналитик (Транспорт)
# Старший системный администратор Windows
# Архитектор / Staff Engineer
# Разработчик (Yandex Platform Engineering)
# ИТ-лидер (Кредиты)
# Эксперт по разработке сервисов данных (Разработчик C++)
# Архитектор 1С
# Affiliate Manager
# Инженер технической поддержки (СХД TATLIN)
# Tech Lead Go (Platform Security)
# QA Auto Engineer (Python, Магнит Маркет)
# Аналитик-разработчик (AliceGPT)
# DevOps-инженер (Corporate & SME)
# Senior Linux Administrator
# Разработчик контент-системы и статистики на C++ (Реклама)
# DevOps-инженер
# Системный архитектор
# Тимлид разработки (Arch Governance)
# Старший Go / PHP-разработчик (Автоматизация продаж)
# Data Engineer / Analyst (Управление данными)
# Tech Lead Fullstack Developer (React.js + Node.js)
# Разработчик в команду безопасности
# Аналитик SQL
# Разработчик 1С (HR Tech)
# Ведущий продуктовый дизайнер (B2С Mobile)
# QA Automation
# HR Admin / People Partner
# HPC DevOps Engineer
# Senior C++ SWE
# Технический архитектор 1С:УТ
# ML Developer (Рекомендации Дзен)
# Team Lead (Python) команды разработки
# Архитектор продукта (1С: Управление проектами)
# Руководитель команды HR DWH (Эйчартех)
# iOS-разработчик (Буткемп)
# AQA Engineer (C#)
# Senior AI Engineer
# IT-специалист по миграции на OS Linux
# Младший сетевой инженер
# Haxe Frontend Developer (Web)
# Data Analyst (B2B Sales)
# Инженер по информационной безопасности
# Аналитик 1С (УХА + Бюджетирование К4)
# Data Engineer (AntiFraud)
# DevOps Engineer
# AQA Java
# Руководитель команды аналитики (GIG Авито Работы)
# Ведущий разработчик PL/pgSQL
# Tech Lead (Инфраструктура веб-сервисов)
# Специалист технической поддержки финансовых решений (Oracle E-Business Suite)
# Windows Server Engineer
# Senior ML Python Developer
# Java Team Lead
# Бэкенд-разработчик (Финтех)
# Директор по управлению IT-проектами внедрения
# Middle DBA
# Аналитик 1С:ЗУП
# Старший менеджер продукта (Картинки)
# DevOps Database Engineer
# Senior Backend Engineer (Kotlin/PHP)
# Инженер Cisco
# Senior Go Developer (Alert)
# Data Scientist (Анализ цены)
# Администратор баз данных
# Player Support Specialist
# Разработчик (VDI Yandex Cloud Security)
# Системный аналитик (Collateral Retail)
# Аналитик-разработчик (Релевантность ответов Алисы)
# Руководитель проекта (HR Tek)
# Разработчик (Managed Greenplum)
# Дежурный системный администратор технической поддержки
# Руководитель направления ИБ Cloud
# Разработчик на Java (B2B-промо)
# Android-разработчик (Карты)
# NetOps (Python) / Сетевой инженер по автоматизации (KORNFELD)
# SOC Analyst (L1)
# Automation QA Engineer (JavaScript)
# Инженер/Администратор DBaaS (Cloud)
# Старший Python-разработчик (Разработка проектов)
# System Administrator
# Архитектор СХД и SAN
# Product Analyst (Data Team)
# Team Lead PHP (Symfony)
# Go-разработчик (GR-инструменты)
# Разработчик платформы управления данными (Суперапп Яндекс Go)
# Координатор по направлению CMDB (Tехподдержка)
# Senior Network Еngineer (KORNFELD)
# Frontend-разработчик (Vue.js)
# Ведущий SRE-инженер
# Ведущий аналитик бизнес-систем (1С:ЗУП)
# QA Engineer (KYC)
# Администратор ОС Linux
# Системный администратор Linux / DevOps
# Аналитик-разработчик (Cинтез речи)
# Администратор проекта
# Главный специалист по информационной безопасности (Партнерский найм)
# ML-разработчик (Поиск и рекомендации)
# Ведущий системный аналитик
# Прикладной администратор (Поддержка L2)
# Системный аналитик (СОМЕТА)
# Senior QA (WholeSaler)
# iOS-разработчик
# Инженер внедрения (ALD Pro)
# Разработчик бэкенда на Python и Go
# Руководитель отдела аналитики
# Product Owner (Развитие экосистемы мультиподписок)
# Java-разработчик
# ML-разработчик в службу ML Финтеха (Международные проекты)
# Senior Server Engineer (Go)
# Руководитель отдела технической поддержки пользователей B2B (Termidesk)
# Разработчик баз данных
# IT Recruiter
# DevOps Engineer (Platform Team)
# Java/Kotlin-разработчик (Платформа аналитического учета)
# Senior Infrastructure Security Engineer
# SRE-инженер (IaaS)
# Head of Product Analytics
# Machine Learning Engineer (Search Quality)
# Senior System Analyst (Ядро)
# Tech Lead Backend Developer (Node.js)
# AppSec Team Lead
# System Architect / Solution Architect
# ML-разработчик (E-com-блендер, Поиск)
# Инженер сопровождения SAP (FI)
# System / Software Architect
# Бизнес-аналитик (Кампейн)
# GameDev Recruiter
# Java-разработчик (Registry)
# Data Analyst
# Бренд-дизайнер
# Продуктовый аналитик
# Lead Product Designer (SberPrivate)
# Head of Recruitment
# Аналитик 1С:ERP / 1С:УТ
# SRE-инженер (Клиентский интерфейс)
# Senior Java Developer (Спецпроекты)
# Тимлид разработки (Товары / Запчасти и аксессуары)
# Разработчик интерфейсов (Игры)
# Team Lead Fullstack .NET Developer (Административные cервисы)
# Разработчик PL/Plus (ЦФТ)
# Senior .NET + React.js Fullstack Developer (HR-сервисы)
# Продуктовый дизайнер
# Системный аналитик (Кредиты)
# Разработчик (MWP бэкенда Кинопоиска)
# DevOps-инженер (Customer Analytics Pulse)
# Аналитик SOC L3 (Информационная безопасность)
# Системный архитектор по импортозамещению (Tech Lead)
# Архитектор ИТ-инфраструктуры
# Merchant Intelligence Fullstack Engineer
# Аналитик 1С
# Старший Java-разработчик (Развитие платежных сервисов)
# Backend Engineer (Query Team)
# Senior Data Analyst (Блок "Стратегия и развитие")
# Тестировщик RPA
# Senior Python Developer (Research Platform)
# Java-разработчик (стрим СОПТБ)
# Разработчик (Мобильная инфраструктура)
# Продуктовый аналитик (Платформа)
# Эксперт по информационной безопасности
# Senior Java Developer (Разработка платформы для инвестиционных продуктов)
# Системный администратор Linux / SRE-инженер
# Разработчик оптимизационных моделей
# Разработчик бэкенда (D&C)
# QA Manual
# Аналитик 1С ERP
# Fullstack Software Engineer (Python/React)
# Старший аналитик (Доля Поиска)
# Старший разработчик на Go (Kubernetes Security Posture Management)

# %%
unique_companies = set(vacancy.get('company') for vacancy in vacancies)

print('\n'.join(unique_companies))
# Out:
# Альфа-банк
# ОТП Банк
# JTI
# Collectly
# М.Видео
# Dodo Brands
# Сравни
# Pari
# Flocktory
# Яндекс MultiTrack
# Деметра Холдинг
# Spectral::Technologies
# Galileosky
# CV Recruitment
# Payler
# Плюс Фантех
# Axiom JDK
# Aston
# Kuvelli
# Inita
# Selectel
# =nil; Foundation
# TradingView
# Navio
# Okko
# Банк Точка
# Just AI
# Название скрыто
# Rubbles
# Делимобиль
# Softline
# Sportmaster Lab
# Газпром нефть
# Лига Ставок
# Гринатом
# Faraway
# Timeweb
# Findmykids
# РСХБ-Интех
# Kupsilla
# CUSTIS
# Яндекс
# Yandex.Practicum
# Muse Group
# R-Vision
# Serenity
# X5 Tech
# Exness
# Garage Eight
# Click
# BrainRocket
# EX CORP.
# Avito
# CMT
# Алабуга
# KnowledgeCity
# P2P.ORG
# Brainway
# Linked Helper
# VOLKA GAMES
# X5 Digital
# Hoodies
# БАРС Груп
# Яндекс Райдтех
# Название скрыто (Ритейл)
# UNIREST
# MTS
# Сбер
# Название скрыто (Банк)
# Emerging Travel Group
# Fundraise Up
# Okkam
# МБС
# Название скрыто (Финансовые технологии)
# CONTENT AI
# ITNTalents
# Rocket Tech
# GGSel
# Яндекс Финтех
# Yandex Cloud
# Веб-Сервер
# EdgeЦентр
# Dif.tech (Plata)
# Eqwile
# Rusprofile
# BI.ZONE
# Kviku
# Мир Plat.Form (команда НСПК)
# CIAN
# Mindbox
# Яндекс (Поисковый портал)
# ГНИВЦ
# Smart Horizon
# Usetech
# Банк Уралсиб
# Dats.Team
# Zvonok
# HR Prime
# GISMETEO
# TrueConf
# Playrix
# Maker.co
# Островок
# CMS Digital
# СберСпасибо
# Название скрыто (Medtech)
# Kokoc Group
# Elly Analytics
# Сбербанк Страхование
# Передовые Платежные Решения
# Alber Blanc
# inDrive
# ООО "Марс"
# T2
# Limavi
# YADRO
# Флант
# Бюро 1440
# Яндекс Вертикали
# Банк ВТБ
# PESCO
# Winline
# RTDLab
# VK
# LIFE PAY
# Хантфлоу
# getmatch agency
# Flipper Devices
# ICL Soft
# Yandex Infrastructure
# Звук
# Магнит
# Лучи (ex. BestDoctor)
# Название скрыто (Сфера развлечений)
# MetaQuotes
# Gameram
# ОМП, Открытая Мобильная Платформа
# Совкомбанк Технологии
# X-ON
# МегаФон
# Peter Partner
# Tutu
# Иркутская нефтяная компания
# ДОМ.РФ
# Профи.ру
# РТК ИТ
# Nexign
# Мой Офис
# Холдинг Т1
# Positive Technologies
# Название скрыто (FMCG)
# Яндекс IT
# МТС ИИ
# BCraft
# ITTC
# Marfatech
# Wheely
# Индид
# Argo.Tech
# Яндекс Foodtech
# Т-Банк
# Группа Астра
# Pinely
# Домклик
# СГМК
# Яндекс 360
# NtechLab
# Constructor.io
# UULA Technologies
# Palark
# Ozon Fintech
# Иви
# Planner 5D
# 2ГИС
# Яндекс.Маркет
# OctoNus
# Volt
# Wert
# Tripster
# DSSL
# Название скрыто (Fintech)
# FunCorp
# Upfirst
# На_Пoлке
# Think-cell
# Skyeng

# %%
unique_salaries = set(vacancy.get('salary') for vacancy in vacancies if vacancy.get('salary') is not None)

print('\n'.join(unique_salaries))
# Out:
# 104 400 —‍ 113 000 ₽/мес на руки
# 220 000 —‍ 350 000 ₽/мес на руки
# 160 000 —‍ 250 000 ₽/мес на руки
# 170 000 —‍ 190 000 ₽/мес на руки
# 250 000 —‍ 340 000 ₽/мес на руки
# 290 000 —‍ 325 000 ₽/мес на руки
# от 225 000 ₽/мес на руки
# 190 000 —‍ 350 000 ₽/мес на руки
# 160 000 —‍ 680 000 ₽/мес на руки
# 200 000 —‍ 440 000 ₽/мес на руки
# 70 000 —‍ 90 000 ₽/мес на руки
# 170 000 —‍ 300 000 ₽/мес на руки
# 230 000 —‍ 300 000 ₽/мес на руки
# от 4 400 €/мес на руки
# от 280 000 ₽/мес на руки
# 180 000 —‍ 400 000 ₽/мес на руки
# 450 000 —‍ 550 000 ₽/мес на руки
# 170 000 —‍ 220 000 ₽/мес на руки
# от 120 000 ₽/мес на руки
# 180 000 —‍ 300 000 ₽/мес на руки
# 383 000 —‍ 585 000 ₽/мес на руки
# 60 000 —‍ 100 000 ₽/мес на руки
# 400 000 —‍ 500 000 ₽/мес на руки
# 100 000 —‍ 250 000 ₽/мес на руки
# 220 000 —‍ 270 000 ₽/мес на руки
# 380 000 —‍ 450 000 ₽/мес на руки
# 450 000 —‍ 750 000 ₽/мес на руки
# 50 000 —‍ 70 000 ₽/мес на руки
# от 4 900 €/мес на руки
# 1 500 —‍ 2 500 €/мес на руки
# 290 000 —‍ 400 000 ₽/мес на руки
# от 360 000 ₽/мес на руки
# от 70 000 ₽/мес на руки
# 3 600 —‍ 5 700 $/мес на руки
# 270 000 —‍ 400 000 ₽/мес на руки
# 9 000 —‍ 10 000 $/мес на руки
# 200 000 —‍ 430 000 ₽/мес на руки
# ≈ 250 000 —‍ 350 000 ₽/мес на руки
# 10 000 —‍ 13 000 $/мес на руки
# 7 500 —‍ 9 150 $/мес на руки
# 4 700 —‍ 5 000 $/мес на руки
# 800 —‍ 1 000 $/мес на руки
# 270 000 —‍ 450 000 ₽/мес на руки
# от 3 000 $/мес на руки
# 560 000 —‍ 680 000 ₽/мес на руки
# 4 200 —‍ 6 600 €/мес на руки
# 600 000 —‍ 800 000 ₽/мес на руки
# 190 000 —‍ 280 000 ₽/мес на руки
# 250 000 —‍ 450 000 ₽/мес на руки
# от 260 000 ₽/мес на руки
# 6 000 —‍ 8 500 €/мес на руки
# 230 000 —‍ 350 000 ₽/мес на руки
# 170 000 —‍ 350 000 ₽/мес на руки
# 1 500 —‍ 2 000 $/мес на руки
# 4 000 —‍ 6 000 €/мес на руки
# 220 000 —‍ 290 000 ₽/мес на руки
# от 3 500 $/мес на руки
# 250 000 —‍ 320 000 ₽/мес на руки
# 350 000 —‍ 450 000 ₽/мес на руки
# 230 000 —‍ 330 000 ₽/мес на руки
# 300 000 —‍ 435 000 ₽/мес на руки
# 2 500 —‍ 3 000 €/мес на руки
# 4 000 —‍ 8 000 $/мес на руки
# 150 000 —‍ 300 000 ₽/мес на руки
# 400 000 —‍ 600 000 ₽/мес на руки
# 150 000 —‍ 250 000 ₽/мес на руки
# 450 000 —‍ 600 000 ₽/мес на руки
# 200 000 —‍ 235 000 ₽/мес на руки
# от 365 000 ₽/мес на руки
# 240 000 —‍ 320 000 ₽/мес на руки
# от 240 000 ₽/мес на руки
# от 4 600 €/мес на руки
# ≈ 200 000 —‍ 300 000 ₽/мес на руки
# 300 000 —‍ 330 000 ₽/мес на руки
# от 5 000 €/мес на руки
# 275 000 —‍ 295 000 ₽/мес на руки
# 400 000 —‍ 530 000 ₽/мес на руки
# 60 000 —‍ 80 000 ₽/мес на руки
# 326 000 —‍ 488 000 ₽/мес на руки
# 375 000 —‍ 457 000 ₽/мес на руки
# ≈ 400 000 —‍ 500 000 ₽/мес на руки
# 120 000 —‍ 220 000 ₽/мес на руки
# 140 000 —‍ 220 000 ₽/мес на руки
# 170 000 —‍ 200 000 ₽/мес на руки
# 220 000 —‍ 370 000 ₽/мес на руки
# 150 000 —‍ 500 000 ₽/мес на руки
# 230 000 —‍ 470 000 ₽/мес на руки
# 250 000 —‍ 350 000 ₽/мес на руки
# 290 000 —‍ 360 000 ₽/мес на руки
# 220 000 —‍ 470 000 ₽/мес на руки
# от 220 000 ₽/мес на руки
# 250 000 —‍ 380 000 ₽/мес на руки
# от 285 000 ₽/мес на руки
# 425 000 —‍ 558 000 ₽/мес на руки
# 4 000 —‍ 5 500 $/мес на руки
# от 275 000 ₽/мес на руки
# 150 000 —‍ 400 000 ₽/мес на руки
# 150 000 —‍ 185 000 ₽/мес на руки
# 210 000 —‍ 400 000 ₽/мес на руки
# 3 000 —‍ 5 000 $/мес на руки
# от 2 200 €/мес на руки
# 400 000 —‍ 420 000 ₽/мес на руки
# 6 660 —‍ 9 150 $/мес на руки
# от 7 000 €/мес на руки
# 220 000 —‍ 330 000 ₽/мес на руки
# 50 000 —‍ 80 000 ₽/мес на руки
# 240 000 —‍ 285 000 ₽/мес на руки
# 150 000 —‍ 350 000 ₽/мес на руки
# ≈ 150 000 —‍ 250 000 ₽/мес на руки
# 500 000 —‍ 650 000 ₽/мес на руки
# 180 000 —‍ 280 000 ₽/мес на руки
# от 330 000 ₽/мес на руки
# 50 000 —‍ 55 000 ₽/мес на руки
# 7 500 —‍ 9 000 $/мес на руки
# 80 000 —‍ 150 000 ₽/мес на руки
# 250 000 —‍ 490 000 ₽/мес на руки
# 3 500 —‍ 5 000 €/мес на руки
# 300 000 —‍ 540 000 ₽/мес на руки
# 110 000 —‍ 160 000 ₽/мес на руки
# 4 000 —‍ 7 000 $/мес на руки
# 180 000 —‍ 350 000 ₽/мес на руки
# 2 000 —‍ 3 500 $/мес на руки
# от 400 000 ₽/мес на руки
# 380 000 —‍ 420 000 ₽/мес на руки
# 6 000 —‍ 7 000 €/мес на руки
# от 250 000 ₽/мес на руки
# 420 000 —‍ 550 000 ₽/мес на руки
# 270 000 —‍ 330 000 ₽/мес на руки
# 110 000 —‍ 130 000 ₽/мес на руки
# 100 000 —‍ 150 000 ₽/мес на руки
# от 200 000 ₽/мес на руки
# от 243 000 ₽/мес до налогов
# 410 000 —‍ 540 000 ₽/мес на руки
# 8 100 —‍ 10 300 $/мес на руки
# 200 000 —‍ 360 000 ₽/мес на руки
# 230 000 —‍ 450 000 ₽/мес на руки
# 150 000 —‍ 170 000 ₽/мес до налогов
# 300 000 —‍ 490 000 ₽/мес на руки
# 200 000 —‍ 345 000 ₽/мес до налогов
# 200 000 —‍ 400 000 ₽/мес на руки
# 4 000 —‍ 4 500 €/мес на руки
# 150 000 —‍ 280 000 ₽/мес на руки
# от 380 000 ₽/мес на руки
# 375 000 —‍ 450 000 ₽/мес на руки
# 100 000 —‍ 130 000 ₽/мес на руки
# от 195 000 ₽/мес на руки
# 350 000 —‍ 600 000 ₽/мес на руки
# 2 000 —‍ 4 000 $/мес на руки
# 270 000 —‍ 485 000 ₽/мес на руки
# 3 000 —‍ 4 000 $/мес на руки
# 306 000 —‍ 370 000 ₽/мес на руки
# 305 000 —‍ 348 000 ₽/мес на руки
# от 450 000 ₽/мес на руки
# 100 000 —‍ 300 000 ₽/мес на руки
# от 4 500 €/мес на руки
# 90 000 —‍ 140 000 ₽/мес на руки
# от 130 000 ₽/мес на руки
# 300 000 —‍ 380 000 ₽/мес на руки
# 8 300 —‍ 10 100 $/мес на руки
# 190 000 —‍ 580 000 ₽/мес на руки
# 218 000 —‍ 348 000 ₽/мес на руки
# 5 000 —‍ 6 000 $/мес на руки
# от 500 000 ₽/мес на руки
# 320 000 —‍ 420 000 ₽/мес на руки
# от 270 000 ₽/мес на руки
# 5 000 —‍ 8 000 €/мес на руки
# 105 000 —‍ 140 000 ₽/мес на руки
# 150 000 —‍ 190 000 ₽/мес на руки
# 70 000 —‍ 110 000 ₽/мес на руки
# от 160 000 ₽/мес на руки
# 150 000 —‍ 208 000 ₽/мес на руки
# 2 800 —‍ 3 300 $/мес на руки
# 230 000 —‍ 250 000 ₽/мес на руки
# 230 000 —‍ 270 000 ₽/мес на руки
# 180 000 —‍ 370 000 ₽/мес на руки
# 300 000 —‍ 400 000 ₽/мес на руки
# 200 000 —‍ 280 000 ₽/мес на руки
# 355 000 —‍ 466 000 ₽/мес на руки
# 130 000 —‍ 180 000 ₽/мес на руки
# 250 000 —‍ 410 000 ₽/мес на руки
# 210 000 —‍ 240 000 ₽/мес на руки
# 1 500 —‍ 3 000 €/мес на руки
# 250 000 —‍ 500 000 ₽/мес на руки
# от 320 000 ₽/мес на руки
# 194 000 —‍ 232 000 ₽/мес на руки
# 2 000 —‍ 2 500 $/мес на руки
# 320 000 —‍ 450 000 ₽/мес на руки
# от 5 000 €/мес до налогов
# от 85 000 ₽/мес на руки
# 150 000 —‍ 200 000 ₽/мес на руки
# 120 000 —‍ 300 000 ₽/мес на руки
# 2 500 —‍ 3 000 $/мес на руки
# 300 000 —‍ 350 000 ₽/мес на руки
# 350 000 —‍ 420 000 ₽/мес на руки
# 400 000 —‍ 480 000 ₽/мес на руки
# от 700 000 ₽/мес на руки
# 65 000 —‍ 85 000 ₽/мес на руки
# от 2 500 $/мес на руки
# от 383 000 ₽/мес на руки
# 250 000 —‍ 550 000 ₽/мес на руки
# 4 000 —‍ 6 000 $/мес на руки
# 270 000 —‍ 435 000 ₽/мес на руки
# от 800 000 ₽/мес на руки
# 90 000 —‍ 110 000 ₽/мес на руки
# от 210 000 ₽/мес на руки
# 238 000 —‍ 347 000 ₽/мес на руки
# 350 000 —‍ 500 000 ₽/мес на руки
# 255 000 —‍ 355 000 ₽/мес на руки
# 120 000 —‍ 270 000 ₽/мес на руки
# 2 500 —‍ 4 500 €/мес на руки
# 140 000 —‍ 200 000 ₽/мес на руки
# 250 000 —‍ 360 000 ₽/мес на руки
# 150 000 —‍ 180 000 ₽/мес на руки
# 4 000 —‍ 6 500 $/мес на руки
# 400 000 —‍ 450 000 ₽/мес на руки
# 150 000 —‍ 220 000 ₽/мес на руки
# 240 000 —‍ 270 000 ₽/мес на руки
# 70 000 —‍ 87 000 ₽/мес на руки
# от 5 500 €/мес на руки
# 5 000 —‍ 7 000 $/мес на руки
# от 235 000 ₽/мес на руки
# 365 000 —‍ 585 000 ₽/мес на руки
# 117 000 —‍ 200 000 ₽/мес на руки
# 380 000 —‍ 580 000 ₽/мес на руки
# 350 000 —‍ 435 000 ₽/мес на руки
# 220 000 —‍ 490 000 ₽/мес на руки
# 200 000 —‍ 255 000 ₽/мес на руки
# от 160 000 ₽/мес до налогов
# 348 000 —‍ 391 000 ₽/мес на руки
# 8 000 —‍ 13 000 $/мес до налогов
# 270 000 —‍ 370 000 ₽/мес на руки
# от 1 000 $/мес на руки
# от 265 000 ₽/мес на руки
# 4 000 —‍ 8 000 $/мес до налогов
# 2 500 —‍ 3 500 €/мес на руки
# 200 000 —‍ 450 000 ₽/мес на руки
# 190 000 —‍ 250 000 ₽/мес на руки
# от 87 000 ₽/мес на руки
# ≈ 100 000 —‍ 150 000 ₽/мес на руки
# от 7 000 $/мес на руки
# 1 700 —‍ 1 900 $/мес на руки
# 3 200 —‍ 3 600 $/мес до налогов
# 200 000 —‍ 450 000 ₽/мес до налогов
# 6 000 —‍ 7 000 $/мес на руки
# 240 000 —‍ 480 000 ₽/мес на руки
# 250 000 —‍ 425 000 ₽/мес на руки
# от 150 000 ₽/мес на руки
# 50 000 —‍ 130 000 ₽/мес на руки
# от 230 000 ₽/мес на руки
# 207 000 —‍ 345 000 ₽/мес до налогов
# 40 000 —‍ 50 000 ₽/мес на руки
# 5 000 —‍ 7 000 €/мес на руки
# от 350 000 ₽/мес на руки
# 180 000 —‍ 250 000 ₽/мес на руки
# 90 000 —‍ 150 000 ₽/мес на руки
# 6 600 —‍ 10 000 $/мес на руки
# от 100 000 ₽/мес на руки
# 10 000 —‍ 12 000 $/мес на руки
# 74 000 —‍ 100 000 ₽/мес на руки
# 4 000 —‍ 5 800 €/мес на руки
# 70 000 —‍ 100 000 ₽/мес на руки
# от 1 500 €/мес на руки
# 6 000 —‍ 9 000 €/мес на руки
# 5 000 —‍ 8 500 €/мес на руки
# от 2 500 €/мес на руки
# 300 000 —‍ 370 000 ₽/мес на руки
# 70 000 —‍ 80 000 ₽/мес на руки
# от 305 000 ₽/мес на руки
# от 5 000 $/мес на руки
# 210 000 —‍ 300 000 ₽/мес на руки
# от 180 000 ₽/мес на руки
# 200 000 —‍ 250 000 ₽/мес на руки
# 3 800 —‍ 6 500 $/мес на руки
# 4 500 —‍ 5 500 €/мес на руки
# 247 000 —‍ 325 000 ₽/мес на руки
# ≈ 100 000 —‍ 200 000 ₽/мес на руки
# от 6 000 €/мес на руки
# 8 000 —‍ 15 000 $/мес на руки
# 120 000 —‍ 200 000 ₽/мес на руки
# 3 500 —‍ 6 300 $/мес на руки
# 300 000 —‍ 360 000 ₽/мес на руки
# от 340 000 ₽/мес на руки
# 3 000 —‍ 5 000 €/мес на руки
# 65 000 —‍ 90 000 ₽/мес на руки
# от 600 000 ₽/мес на руки
# 261 000 —‍ 326 000 ₽/мес на руки
# 120 000 —‍ 140 000 ₽/мес на руки
# 180 000 —‍ 210 000 ₽/мес на руки
# 100 000 —‍ 300 000 ₽/мес до налогов
# 220 000 —‍ 450 000 ₽/мес на руки
# 150 000 —‍ 260 000 ₽/мес на руки
# 100 000 —‍ 170 000 ₽/мес на руки
# 4 500 —‍ 5 500 $/мес на руки
# 300 000 —‍ 500 000 ₽/мес на руки
# 321 000 —‍ 485 000 ₽/мес на руки
# от 4 000 $/мес на руки
# от 321 000 ₽/мес на руки
# 200 000 —‍ 500 000 ₽/мес на руки
# 100 000 —‍ 200 000 ₽/мес на руки
# 150 000 —‍ 230 000 ₽/мес на руки
# 2 500 —‍ 3 500 $/мес на руки
# 450 000 —‍ 500 000 ₽/мес на руки
# 140 000 —‍ 185 000 ₽/мес на руки
# 100 000 —‍ 110 000 ₽/мес на руки
# 200 000 —‍ 350 000 ₽/мес на руки
# 350 000 —‍ 400 000 ₽/мес на руки
# 3 500 —‍ 4 500 €/мес на руки
# 3 500 —‍ 6 000 €/мес на руки
# 250 000 —‍ 400 000 ₽/мес на руки
# 250 000 —‍ 300 000 ₽/мес на руки
# 400 000 —‍ 750 000 ₽/мес на руки
# 220 000 —‍ 510 000 ₽/мес на руки
# 300 000 —‍ 560 000 ₽/мес на руки
# 200 000 —‍ 390 000 ₽/мес на руки
# 80 000 —‍ 100 000 ₽/мес на руки
# 7 000 —‍ 9 000 $/мес на руки
# 550 000 —‍ 750 000 ₽/мес на руки
# 120 000 —‍ 170 000 ₽/мес на руки
# 280 000 —‍ 350 000 ₽/мес на руки
# 5 000 —‍ 7 500 €/мес на руки
# 8 000 —‍ 10 000 €/мес до налогов
# 100 000 —‍ 120 000 ₽/мес на руки
# 300 000 —‍ 390 000 ₽/мес на руки
# 200 000 —‍ 320 000 ₽/мес на руки
# от 290 000 ₽/мес на руки
# 130 000 —‍ 200 000 ₽/мес на руки
# 212 000 —‍ 230 000 ₽/мес до налогов
# 150 000 —‍ 235 000 ₽/мес на руки
# 300 000 —‍ 450 000 ₽/мес на руки
# 160 000 —‍ 490 000 ₽/мес на руки
# от 550 000 ₽/мес на руки
# 65 000 —‍ 70 000 ₽/мес на руки
# от 2 000 €/мес на руки
# от 480 000 ₽/мес на руки
# 350 000 —‍ 430 000 ₽/мес на руки
# 7 000 —‍ 8 500 $/мес на руки
# 236 000 —‍ 325 000 ₽/мес на руки
# 3 000 —‍ 3 500 $/мес на руки
# 280 000 —‍ 300 000 ₽/мес на руки
# от 80 000 ₽/мес на руки
# от 560 000 ₽/мес на руки
# 6 000 —‍ 9 000 $/мес на руки
# от 300 000 ₽/мес на руки
# 80 000 —‍ 125 000 ₽/мес на руки
# 212 000 —‍ 350 000 ₽/мес на руки
# 200 000 —‍ 380 000 ₽/мес на руки
# 600 000 —‍ 700 000 ₽/мес на руки
# от 4 000 €/мес на руки
# 290 000 —‍ 340 000 ₽/мес на руки
# 120 000 —‍ 175 000 ₽/мес на руки
# 80 000 —‍ 120 000 ₽/мес на руки
# 2 500 —‍ 4 000 $/мес на руки
# 5 000 —‍ 8 000 $/мес до налогов
# ≈ 250 000 —‍ 300 000 ₽/мес на руки
# 270 000 —‍ 320 000 ₽/мес на руки
# 70 000 —‍ 105 000 ₽/мес на руки
# 6 500 —‍ 6 700 $/мес на руки
# 180 000 —‍ 240 000 ₽/мес на руки
# 1 500 —‍ 2 000 €/мес на руки
# от 157 000 ₽/мес на руки
# от 3 000 €/мес на руки
# 218 000 —‍ 278 000 ₽/мес на руки
# 410 000 —‍ 680 000 ₽/мес на руки
# от 348 000 ₽/мес на руки
# 4 000 —‍ 7 000 €/мес на руки
# от 140 000 ₽/мес на руки
# 200 000 —‍ 300 000 ₽/мес на руки
# 220 000 —‍ 260 000 ₽/мес на руки
# 4 000 —‍ 5 000 €/мес на руки
# 60 000 —‍ 70 000 ₽/мес на руки
# 5 000 —‍ 6 500 €/мес на руки
# 237 000 —‍ 366 000 ₽/мес на руки
# 410 000 —‍ 490 000 ₽/мес на руки
# 155 000 —‍ 165 000 ₽/мес до налогов
# 300 000 —‍ 520 000 ₽/мес на руки
# от 1 800 $/мес на руки
# от 170 000 ₽/мес на руки
# 188 000 —‍ 274 000 ₽/мес на руки
# от 390 000 ₽/мес на руки
# от 4 800 €/мес на руки
# 210 000 —‍ 360 000 ₽/мес на руки
# 150 000 —‍ 170 000 ₽/мес на руки

# %%
unique_locations = set()

for vacancy in vacancies:
    locations = vacancy.get('locations', [])
    unique_locations.update(locations)

print('\n'.join(unique_locations))
# Out:
# 📍 Москва (м. Смоленская)
# Санкт-Петербург (м. Маяковская)
# 📍 Москва (м. Румянцево)
# 📍 Новосибирск
# 📍 Москва (м. Технопарк)
# Белгород
# Новокузнецк
# 📍 Лимасcол (Кипр)
# 📍 Санкт-Петербург (м. Спортивная)
# Санкт-Петербург (м. Владимирская)
# 📍 Пермь
# 📍 Москва (м. Арбатская)
# 📍 Москва (м. Краснопресненская)
# 📍 Москва (м. Охотный ряд / Площадь Революции / Театральная)
# Испания
# Владивосток
# 📍 Москва (м. Верхние Котлы)
# 📍 Никосия (Кипр)
# Португалия
# Майкоп
# Иваново
# 📍 Лимасол (Кипр)
# 📍 Москва (м. Спортивная)
# Краснодар
# 📍 Москва (м. Отрадное)
# 📍 Санкт-Петербург (м. Чернышевская)
# Волгоград
# 📍 Санкт-Петербург (м. Беговая)
# 📍 Санкт-Петербург (м. Лиговский проспект)
# 📍 Москва (м. Белорусская)
# 📍 Малага (Испания)
# Великий Новгород
# Нижний Новогород
# 📍 Москва (Волгоградский проспект)
# 📍 Москва (м. Шаболовская)
# 📍 Москва (м. Третьяковская)
# Санкт-Петербург (м. Невский проспект)
# Санкт-Петербург (м. Площадь Александра Невского)
# 📍 Москва (м. Новослободская)
# Белград (Сербия)
# Санкт-Петербург (м. Новочеркасская)
# 📍 Нижний Новгород
# 📍 Москва (м. Октябрьское поле)
# Армения
# 📍 Санкт-Петербург (м. Фрунзенская)
# 📍 Москва (м. Павелецкая / м. Нагатинская)
# 📍 Новокузнецк
# Хабаровск
# 📍 Москва (м. ВДНХ)
# 📍 Воронеж
# 📍 Казань
# 📍 Санкт-Петербург (м. Невский проспект)
# Санкт-Петербург (м. Адмиралтейская)
# 📍 Москва (м. Добрынинская / м. Савёловская)
# Липецк
# Орел
# 📍 Москва (м. Семёновская)
# 📍 Кипр
# 📍 Москва (м. Площадь Ильича)
# 📍 Москва (м. Крестьянская застава)
# 📍 Москва
# Санкт-Петербург (м. Площадь Ленина / м. Новочеркасская)
# 📍 Вильнюс (Литва)
# Турция
# Екатеринбург, Нижний Новгород
# 📍 Москва (м. Улица 1905 года)
# 📍 Мексика
# 📍 Москва (м. Авиамоторная)
# 📍 Москва (м. Крылатское)
# 📍 Москва (м. Преображенская площадь)
# 📍 Татарстан
# 📍 Санкт-Петербург (м. Владимирская / м. Достоевская)
# 📍 Москва (м. Бутырская)
# 📍 Санкт-Петербург (м. Проспект Ветеранов)
# Уфа
# 📍 Москва (м. Краснопресненская / м. Улица 1905 года)
# Малага (Испания)
# 📍 Лондон (Великобритания)
# 📍 Москва (м. Динамо)
# Сочи
# 📍 Москва (м. Сокол)
# 📍 Москва (м. Калужская)
# 📍 Казань (м. Площадь Тукая)
# Сербия
# 📍 Москва (м. Маяковская)
# Москва
# Нижний Новгород
# 📍 Москва (м. Павелецкая)
# 📍 Москва (м. Волгоградский проспект / МЦД «Калитники» / м. Добрынинская)
# Пермь
# София (Болгария)
# 📍 Москва (м. Таганская)
# 📍 Москва (м. Аэропорт)
# 📍 Москва (м. Добрынинская)
# 📍 Все города РФ, кроме Москвы
# 📍 Москва (м. Тверская / м. Пушкинская)
# 📍 Москва (м. Ленинский проспект)
# 📍 Тбилиси (Грузия)
# 📍 Москва (м. Охотный ряд)
# 📍 Москва (м. Красносельская)
# 📍 Россия
# 📍 Владивосток
# 📍 Москва (м. Дмитровская)
# 📍 Пафос (Кипр)
# 📍 Москва (м. Кропоткинская)
# Санкт-Петербург (м. Лесная)
# 📍 Москва (м. Текстильщики)
# 📍 Москва (м. Площадь Революции/м. Театральная/м. Охотный Ряд)
# Лимасол (Кипр)
# Санкт-Петербург (м. Обводный канал)
# Астана, Алматы (Казахстан)
# 📍 Москва (м. Парк культуры / м. Савеловская)
# Нижний Новгород (м. Горьковская)
# 📍 Санкт-Петербург (м. Московские ворота)
# 📍 Москва (м. Марксистская)
# 📍 Москва (м. Цветной бульвар)
# 📍 Москва (м. Балтийская)
# Казань
# 📍 Санкт-Петербург (м. Новочеркасская)
# 📍 Ростов-на-Дону
# Астрахань
# Тбилиси (Грузия)
# Все города РФ, кроме Москвы
# 📍 Москва (м. Парк культуры)
# Беларусь
# Санкт-Петербург (м. Ладожская)
# 📍 Санкт-Петербург (м. Достоевская / м. Владимирская)
# 📍 Москва (м. Площадь Революции)
# Санкт-Петербург (м. Лиговский проспект)
# Санкт-Петербург
# Польша
# 📍 Москва (м. Новослободская, м. Маяковская, м. Пушкинская)
# Сочи, Самара
# 📍 ЕС
# 📍 Москва (м. Войковская)
# 📍 Москва (м. Савёловская)
# Санкт-Петербург (м. Беговая)
# Санкт-Петербург (м. Балтийская)
# 📍 Москва (м. Выставочная / м. Деловой центр)
# Екатеринбург
# Ростов-на-Дону
# Санкт-Петербург (м. Выборгская)
# 📍 Иннополис
# 📍 Москва (м. Пролетарская)
# 📍 Европа
# Зеленодольск
# Калуга
# 📍 Санкт-Петербург
# 📍 Санкт-Петербург (м. Площадь Александра Невского)
# Санкт-Петербург (м. Достоевская)
# 📍 Иркутск
# 📍 Санкт-Петербург (м. Достоевская/Владимирская)
# 📍 Москва (м. Проспект Мира)
# 📍 Москва (м. Автозаводская)
# 📍 Москва (м. ЦСКА)
# Все города РФ
# Казань, Новосибирск, Симферополь
# 📍 Москва (м. Выставочная)
# Санкт-Петербург (м. Площадь Восстания)
# 📍 Москва (м. Тёплый стан)
# 📍 Москва (м. Тушинская)
# Санкт-Петербург (м. Площадь Ленина / Выборгская / Новочеркасская)
# Томск
# Санкт-Петербург (м. Площадь Восстания / м. Маяковская)
# Минск (Беларусь)
# 📍 Москва (м. Тропарёво)
# 📍 Санкт-Петербург (м. Ладожская)
# Самара
# 📍 Санкт-Петербург (м. Адмиралтейская)
# 📍 Москва (м. Тульская / Нагатинская)
# Новосибирск
# Череповец
# Санкт-Петербург (м. Петроградская)
# 📍 Москва (м. Савеловская)
# Санкт-Петербург (м. Василеостровская)
# Грузия
# 📍 Санкт-Петербург (м. Старая Деревня)
# Санкт-Петербург (м. Гостиный двор)
# Ереван (Армения)
# 📍 Москва (м. Алексеевская)
# 📍 Москва (м. Тульская)
# Красноярск
# Санкт-Петербург (м. Площадь Ленина)
# 📍 Ульм (Германия)
# 📍 Санкт-Петербург (м. Площадь Ленина / м. Новочеркасская)
# 📍 Москва (м. Нагатинская)
# 📍 Берлин (Германия)
# Ярославль
# 📍 Каймановы Острова
# Санкт-Петербург (м. Звенигородская)
# 📍 Саратов
# Тюмень
# 📍 Москва (м. Киевская)
# 📍 Москва (м. Кутузовская)
# 📍 Краснодар
# 📍 Москва (м. Проспект Вернадского)
# 📍 Санкт-Петербург (м. Площадь Восстания)
# 📍 Казахстан
# Симферополь
# Регионы РФ
# Московская область
# 📍 Москва (м. Курская)
# 📍 Москва (м. Римская)
# Воронеж
# 📍 Москва (м. Кунцевская)
# 📍 Санкт-Петербург (м. Петроградская)
# 📍 Москва (м. Новокузнецкая)
# 📍 Казахстан (Армения, Сербия)
# 📍 Москва (м. Динамо / м. Петровский Парк)
# Иннополис
# 📍 Лимассол (Кипр)
# 📍 Москва (Новослободская / Маяковская / Цветной бульвар)
# 📍 Москва (м Тёплый стан)
# Алматы (Казахстан)
# Омск
# Вологда
# Муром
# Тула
# 📍 Санкт-Петербург (м. Выборгская)
# Кипр
# 📍 Москва (м. Комсомольская)
# 📍 Москва (м. Добрынинская / м. Волгоградский проспект)
# 📍 Санкт-Петербург (м. Василеостровская)
# Екатеринбург, Нижний Новгород, Казань, Новосибирск, Симферополь
# 📍 Москва (м. Электрозаводская)
# 📍 Екатеринбург
# 📍 Москва (м. Волгоградский проспект)
# Казахстан
# 📍 Москва (м. Добрынинская / м. Савеловская)
# 📍 Москва (м. Шелепиха)
# Санкт-Петербург (м. Московские ворота)
# 📍 Армения
# Черногория
# 📍 Москва (м. Деловой центр)
# 📍 Беларусь

# %%
locations = list(unique_locations)

def extract_city(location):
    return re.sub(r"📍\s*|\s*\(.*\)", "", location).strip()

cities = [extract_city(location) for location in locations]

print('\n'.join(set(cities)))
# Out:
# Белгород
# Новокузнецк
# Владивосток
# Испания
# Пафос
# Португалия
# Вильнюс
# Майкоп
# Иваново
# Россия
# Краснодар
# Волгоград
# Каймановы Острова
# Великий Новгород
# Нижний Новогород
# Армения
# Хабаровск
# Белград
# Липецк
# Орел
# Лимассол
# София
# Турция
# Екатеринбург, Нижний Новгород
# Уфа
# Сочи
# Лимасол
# Сербия
# Москва
# Нижний Новгород
# Пермь
# Никосия
# Тбилиси
# Казань
# Саратов
# Астрахань
# Ульм
# Все города РФ, кроме Москвы
# Беларусь
# Лондон
# Санкт-Петербург
# Польша
# Сочи, Самара
# Екатеринбург
# Ростов-на-Дону
# Ереван
# Зеленодольск
# Калуга
# Астана, Алматы
# Европа
# Берлин
# Татарстан
# Все города РФ
# Казань, Новосибирск, Симферополь
# Томск
# ЕС
# Самара
# Алматы
# Новосибирск
# Череповец
# Грузия
# Красноярск
# Ярославль
# Тюмень
# Мексика
# Симферополь
# Регионы РФ
# Московская область
# Воронеж
# Малага
# Иннополис
# Омск
# Вологда
# Муром
# Тула
# Кипр
# Иркутск
# Екатеринбург, Нижний Новгород, Казань, Новосибирск, Симферополь
# Казахстан
# Лимасcол
# Минск
# Черногория

# %%
unique_categories = set()

for vacancy in vacancies:
    categories = vacancy.get('categories', [])
    unique_categories.update(categories)

print('\n'.join(unique_categories))
# Out:
# Можно удалённо из РФ
# Офис или гибрид
# Офис несколько дней в неделю
# Помощь с переездом
# Самостоятельный переезд
# Полная удалёнка

# %%
unique_terms_keys = set()

for vacancy in vacancies:
    terms = vacancy.get('terms', {})
    unique_terms_keys.update(terms.keys())

print(unique_terms_keys)
# Out:
# {'Требуемый опыт', 'Уровень', 'Английский', 'Специализация'}

# %%
unique_terms_values = {}

for vacancy in vacancies:
    terms = vacancy.get('terms', {})
    for key, value in terms.items():
        if key not in unique_terms_values:
            unique_terms_values[key] = set()
        unique_terms_values[key].add(value)

for key, values in unique_terms_values.items():
    print(f'{key}:')
    print('\n'.join(values), end='\n\n')
# Out:
# Специализация:
# Frontend / СТО
# Architect / Node.js
# Android / iOS
# Data Scientist / Data Engineering / Python
# CTO / Architect / Data Engineering
# System Analyst / Business Analyst
# Python / JS/Frontend Developer
# Product Analyst
# HR
# Design & UX Frontend
# Go / Java / Python
# Mobile (Android / iOS)
# C++ / JavaScript
# Infrastructure Engineer
# JS / Frontend Developer
# DevOps/Data Engineering
# Data Scientist / Product Analyst
# Data Science / C++
# Data Science / Machine Learning
# DevOps
# С# / Architect
# Java
# Node.js / TypeScript
# QA Auto
# Product Manager
# Project Manager / СТО
# BusinessAnalyst / System Analyst
# PHP / Go / JS
# Frontend Developer
# CTO / Architect / Go / Java / Python
# Symfony / Vue.js
# Backend Developer
# С / С++
# Engineering Management
# Recruiter
# Python / Go / Java
# Product Analyst / Data Scientist
# JS/Frontend Developer
# QA Auto / Python / Java
# Product Designer
# C++/C#
# Golang / PHP / Java
# CTO / Project Manager / Data Engineering
# Android
# С++ / Java
# Architect
# Golang / Python
# PHP/Kotlin/Java
# .NET / React
# JS / Frontend
# Engineer
# Java / Scala / Golang / Python
# Design & UX
# Python / Data Engineering
# C# / СTO / Architect
# Go / Java / PHP / Python / C#
# Golang, Java / Scala, C / C++
# Golang / Python / C++ / Java
# JavaScript
# Data Engineering / Architect
# Support Engineer / Project Manager
# Python / C++
# Java / Scala
# Product Manager/Data Scientist
# Go/С++/Java/Data Science
# C#
# Data Engineering / Product Analyst
# Java / C++ / Python / Go / TypeScript
# Mobile (Android)
# C++ / Python
# Support Engineer / Information Security
# TypeScript / React
# Analyst 1C
# C / C++
# QA
# Python / QA Auto
# Architect / Python / C / C++
# Python / C# / C++
# Product Management
# Kotlin / Java
# Architect / С / С++ / Go / Java
# DevOps / Suppоrt Engineer
# QA Auto / Go
# iOS / Android
# Java / Architect
# iOS
# Android / C / С++ / System Analyst
# CTO / С++
# Agency Channel Analyst
# Backend development
# 1С / Architect
# JS / Node.js
# Architect / Product Manager
# IT HR / Recruiter
# Data Scientist / Python
# QA Auto / QA Manual
# Frontend
# DevOps / Support Engineer
# Support Engineer/DevOps
# Business Analyst / Product Analyst
# Project Manager
# С#
# Python
# Support Engineer Top Management / DevOps
# C/C++
# Suppоrt Engineer / DevOps
# Product Analyst / Data Engineering
# Information Security
# Python / JavaScript / Data Engineering
# Support Engineer/Information Security/Data Engineering
# С++/ Python
# Data Engineering / Java
# Data Scientist
# Golang / C++
# Data Science
# C++
# UI / UX
# React
# Suppоrt Engineering
# Support Engineer
# 1С / Support Engineer
# Systems Analyst / Engineer Analyst
# Go/Java/Python/PHP
# Information Security / Support Engineer
# Golang / PHP
# PHP
# Scala
# Information Security / DevOps
# JavaScript / Node.js / Python
# Support Engineer / 1С
# Data Engineering
# Support Engineer / System Analyst
# 1C
# С / С++ / Python / Golang
# PHP / Golang
# Data Engineering / DevOps
# Go
# React.js / Node.js
# QA Manual / QA Auto
# Support Engineer / Data Engineering
# С++ / Python
# С/С++/C#/Golang/Java/Scala/PHP/Python
# С++
# Business Analyst
# PHP / Data Engineering
# Python / Data Scientist
# Kernel
# JavaScript / Python
# Project Management
# Node.js
# JavaScript / Node.js
# HTML
# DWH Engineering
# QA Auto / DevOps
# Suppоrt Engineer
# CTO / Architect
# Python / Go
# Business Analyst / System Analyst
# DevOps / Data Engineering
# Architect / Data Engineering
# CTO / DevOps
# JS/Frontend
# Data Engineer
# Data Scientist / Data Engineering
# 1C / System Analyst
# 1С
# С# / CTO / Architect
# С# / JS
# C# / .NET
# DevOps / Python
# Java / Go
# Design
# TypeScript
# Data Analyst
# Digitalization
# Go / Python
# Golang
# IT HR
# Project Manager / Product Manager
# Data Scientist / CTO / Architect
# Golang/Python
# C++ / Java / JavaScript
# Data Engineering / Python
# Mobile (iOS)
# C# / JS
# Architect / С++ / Golang / Java / Python
# С / С++ / Go / Python
# Product Analyst / Product Manager / Project Manager
# Аналитик 1С
# Java / Python
# Golang/Java/Python/C#
# Go/PHP
# C/Python/Go/Java
# System Analyst
# Data Analyst / Data Engineering
# Recruitment
# Android / iOS / Java
# Go / Java
# DevOps / Architect
# Product / Project Management
# Support Engineer / DevOps
# Python / Golang
# QA Manual
# 1С/Business Analyst
# Product Design
# Java / Kotlin
#
# Уровень:
# Middle
# Lead
# Middle-to-Senior
# C-level
# Senior
# Junior
#
# Требуемый опыт:
# 7+ лет
# 5+ лет
# 2+ лет
# 8+ лет
# 10+ лет
# 4+ лет
# 6+ лет
# 1+ лет
# 3+ лет
#
# Английский:
# A1 — Beginner / ElementaryA1 — Beginner / Elementary
# B1 — IntermediateB1 — Intermediate
# B2 — Upper-IntermediateB2 — Upper-Intermediate
# C1/C2 — Advanced / FluentC1/C2 — Advanced / Fluent
# A2 — Pre-IntermediateA2 — Pre-Intermediate

# %%
unique_stack_items = set()

for vacancy in vacancies:
    stack = vacancy.get('stack', [])
    unique_stack_items.update(stack)

print('\n'.join(unique_stack_items))
# Out:
# File Server Failover Cluster
# Charles Proxy
# SaltStack/Ansible/Puppet
# Robot Framework
# 1C:УТ
# OpenWRT
# RuPost/Postfix-Dovecot-SOGo/CommuniGate Pro/Exim/Zimbra/Exchange
# UIKit
# Volcano
# Go/Java/Python
# ASP.NЕТ
# Retrofit
# x86 Servers
# Android Studio/XCode
# ZooKeeper
# OpenCV
# Java
# OneLogin
# WPA
# GPU
# GitHub/Bitbucket
# Go/Java/Python/PHP/C#
# Git/TFS
# Jamf
# Ansible/Puppet/Terraform
# Nmap
# PostgreSQL/MySQL/MongoDB
# Git / SVN
# JetBrains IDEA
# Dagster
# Symfony 5.x-6.x
# mmdeploy
# Snowflake
# OpenVPN
# Ubuntu/Gentoo
# Greenplum
# Windows/Linux/MacOS
# Charles/Fiddler/Proxyman
# restic
# JUnit
# Secure SDLC
# Python/Shell
# DBMS
# Zeplin
# Python/R/SQL
# YAML
# C/С++
# Feast
# CMDB
# Pinia
# Selenium/Selenide
# JSON/XML
# DDL
# React
# Tarantool
# Go/Python/Java
# Firewall
# HBase
# PostgreSQL / Oracle / Microsoft SQL Server
# Unix
# Infrastructure
# Transformers
# AstraLinux
# REST / SOAP
# Android Architecture Components
# Keras/PyTorch/TensorFlow
# Enterprise Architect
# Astra Linux/Debian/CentOS
# Hive
# Python/Go/JavaScript
# Charles
# MS SQL 19+
# Argo CD
# ArchiMate/C4
# ELK
# LangChain
# Alias
# Golang/PHP
# Naumen Service Desk
# Greenplum / ClickHouse / Vertica
# HTML5
# BI
# ClickHouse
# GPO
# kubectl
# Jetty
# ГИС
# Juniper
# Plotly
# Selendroid
# Kafka/Rabbit/ActiveMQ/IBM MQ
# GitHub Actions/CircleCI
# STM32 MCU
# TensorRT
# Python/С++
# Confluence/Jira
# pprof
# Django/Flask/FastAPI
# Flask/FastAPI
# Chef
# TCP
# Babel
# Hugging Face Transformers
# Power Point
# Sonar
# MS Windows Server 2019+
# Quarkus/Spring Boot
# LoadRunner
# VMware Horizon
# Pulumi
# JTBD
# Tornado
# T5
# Swagger
# Sass / Less
# Outlook
# Redmine
# CocoaPods
# Service Desk
# Python/JavaScript/Ruby
# AWS EC2
# Redux
# MEM CM
# Figma
# Insomnia
# Rust/Python/Go
# Confluence
# LESS/SASS
# Autotools
# APScheduler
# Postgres RDS
# Chroma
# PKI
# Ansible/Jenkins/Docker Registry/Nexus/Bitbucket
# Graphite
# QEMU
# Cinder
# Linux/MacOS
# MobileIron
# ONNX
# Grafana/Prometheus/CloudWatch
# Bash
# WebSphere
# HTML
# GenAI
# S3
# ISO
# Superset
# Bash / Python
# OSI
# SON/XML
# Jenkins CI
# Gitlab
# Selenium
# Docker / Kubernetes
# CentOS
# EVPN
# SQLAlchemy
# ElasticSearch
# Falcon
# Grafana/Prometheus/VictoriaMetrics
# ALD Pro/FreeIPA/Microsoft Active Directory/Samba DC
# UART
# 1С:PM Управление проектами КОРП
# cgroups
# Jenkins / TeamCity
# Vite/Webpack
# МЭ
# illumos/Solaris
# TICK Stack
# HP Service Manager
# Loki
# IDS/IPS
# JavaScript / TypeScript
# Neutron
# DPI
# Symfony 5
# System Center Configuration Manager
# Gitlab CI/CD
# IDM
# Tornado / Gevent
# SwiftLint
# NagiOS
# Qlik Sense
# IaaS
# EDT
# Redash
# Electron
# К6/JMeter/HP LoadRunner/Gatling
# Generative AI
# FW
# Python 3.8+
# GDPR
# Vercel
# 1С:УТ
# BIND 9
# Spiral framework
# Mosyle
# Angular
# TON
# OpenSearch / ELK
# Kafka/RabbitMQ
# Java/.NET
# Keystone
# ViPNet
# FSLogix
# IBM PA
# Cycle ORM
# С/С++/С#/Golang/Java/Scala/PHP/Python
# C/C++
# NXP
# 1С 8.3
# Prometheus/Grafana
# JUnit/Mockito
# CatBoost
# ORM
# Liquibase
# ELK/EFK
# MySQL 8+
# Kubernetes Cilium/Calico
# Java 11–17/Kotlin
# BuildKit
# Jira
# .NET
# Hadoop / YTsaurus / ClickHouse
# Informatica PC
# Oracle DI
# CVSS
# Redis/Kafka/RabbitMQ
# SLES
# Windows 2008/2012/2016
# Libvirt
# iptables
# PostgreSQL RDS
# Node.js
# Azure DevOps
# 1С:Предприятие 8.3
# HTML/CSS/JS
# Zod
# RAG
# Ansible/HashiCorp
# Ultron
# Rust
# VLAN
# Go/C/C++/Jаvа
# Tableau/DataLens
# Transact-SQL
# Java SE 17 / Java SE 21
# Zephyr Scale
# .NET Core
# Python/Rust/C++
# Debezium
# 1C: ERP
# Go/PHP
# Dockerfile
# PostgreSQL
# Pixo
# IBM DataStage
# Bitbucket Pipelines
# seaborn
# Kubernetes
# LTE/5G
# Apache Airflow
# KVM
# Excel
# RxJava
# Bash/Python
# aiohttp/FastAPI
# NoHAL
# JVM
# REST
# Matplotlib
# HPE Performance Center
# 1С:ERP / 1C:ERP УХ / 1С:УХ / 1С:БП КОРП
# ComStar
# OWASP
# Packer
# ActiveMQ Artemis
# Asyncio
# AutoRoute
# OpenPyxl
# VictoriaMetrics
# WebSockets
# borg
# Docker/Containerd
# CSS/SCSS
# GCD
# Hibernate ORM
# SNMP
# PPT
# Exchange
# Visio
# Maven/Gradle
# ServiceNow
# Pymorphy2
# Roadrunner
# VDI
# Git/Gitlab
# NoSQL
# iOS 15+
# MS Exchange
# DL
# Tailwind CSS
# PHP 8.0
# MDM
# Chrome DevTools
# Python/TypeScript
# 1C:БИТ.Финанс
# Django
# Amplitude
# Charles / Proxyman
# Commvault
# Azure AD
# Testcontainers
# Python / JavaScript / PHP / Java
# BERT
# Angular 16+
# Cloud Native
# Istio
# AirFlow
# Elasticsearch
# TDD
# RedOS
# Artemis
# Nomad
# С++
# DVC
# Zabbix/Grafana/Prometheus
# ОС Linux
# Veracode
# Python/PHP
# AppMetrica/Firebase/Google Analytics/Apple App Analytics/Yandex Metrika/Adjust
# Observium
# Kibana
# Structured Concurrency
# КриптоПро
# CATIA
# Yandex Tracker/Jira/Service Desk
# Logstash
# SonarQube
# GPT
# File Server
# JavaScript/TypeScript
# Ansible
# Wireshark
# Selenium/Playwright
# JIT
# Tableau/Power BI/Superset
# Android Studio
# Webpack
# OpenSearch
# SUSE
# OSA/SCA
# sh/Bash
# OpenGL
# Scylla
# Vuex
# Redis/Redis Cluster/MongoDB
# MongoDB
# TestNG
# BigQuery
# Stylelint
# Haxe
# AWS/GCP/Yandex Cloud/OpenStack
# REST API
# Alertmanager
# Go/Python/Java/C++
# SSDLC
# Playwright/JS
# Python/Java
# MySQL 8
# iostat
# BPMN 2.0 / ЕРС / IDEF0
# Zephyr
# Kotlin/Java
# Draw․io
# CSS
# GNU Make
# 1C:СППР
# Pydantic
# Unity
# REST Assured
# tcpdump
# PLpg/SQL
# GitLab CI/CD
# Kubeflow
# NVMe
# RESTful
# DBeaver
# Prometheus / VictoriaMetrics
# React 18
# С4
# 1С ERP
# Sentry
# NFV
# Coroutines
# 1С:Франчайзи
# SIEM
# 1С: УХА
# Notion
# GitFlow
# MacOS
# PyTest
# AWS EKS
# Unix/Linux
# SCCM
# Podman
# Python/Bash
# RPC
# Prometheus
# Ethernet
# CRM/Campaign
# KVM/OpenNebula/Docker/Kubernetes
# MySQL/PostgreSQL
# Cinema 4D
# RegExp
# OLAP
# YTsaurus
# Jupyter
# WinDBG
# Vue.js
# Glance
# Miro
# ChatGPT
# Terraform
# QLoRa
# ECMAscript
# Python 3.6+
# Microsoft Azure
# Exchange Server
# High Available/High-Load DB
# gRPC
# NATS
# Git/TeamCity
# Camunda
# UML/BPMN
# Samba DC
# SQS
# Allure Report
# Catia
# ERP
# HAL
# Spark
# Tomcat
# Android
# CloudFormation
# OkHttp
# AWS
# NTA
# Trello
# Kubernetes/Docker
# WebRTC
# AppMetrica
# OWASP Top-10
# LEMP
# JMX
# KVM/bhyve/Zones
# strace
# Android SDK
# JSON
# Bash/PowerShell
# Dynatrace
# TypeScript 4.6
# Web API
# 1C:ДО
# Graylog
# Drift
# OpenStack
# Adobe Creative Cloud
# REST APIs
# Linux/Unix
# asyncio
# Fluent Bit
# iOS 15
# C++ 17/20
# Scala
# SSO
# Grafana
# 1С v8.x
# Chi
# PyCharm
# Git / Jira / Confluence
# С# / Python
# Altova
# Docker/Docker Compose
# PRTG
# SOC
# Hadoop / YTSaurus / ClickHouse
# Jira/Confluence
# AI
# OpenOffice
# SCA
# AirWatch
# AV
# Oracle/PL/SQL
# Archimate
# Docker/Podman
# HAProxy
# Databases
# Rsyslog
# TeamCity/Jenkins/Gitlab
# XML
# SAN
# VMware NSX
# ATS
# Java/PHP/Go/Kotlin/Python
# Debian
# Railway
# MQ
# EPC
# Polars
# Linux
# SPI
# GraphQL
# R-Style
# Peewee
# LACP
# Requests
# ARIS
# 1С:Предприятие
# Sysinternals Suite
# Oracle/PostgreSQL
# Мой офис Таблицы
# ELK Stack
# Brocade
# Styled Components
# Cognos TM1
# HTML/CSS
# GRE
# 1С:Управление предприятием
# DAMA DMBOK
# Active Directory
# OVirt
# Blazor
# Windows
# OpenAPI
# URLSession
# 1С:ЗУП
# Lua
# ArtemisMQ
# Sonata Admin
# REST/SOAP/JSON
# .NET 6
# Storybook
# MVI/MVVM
# 1С: Предприятие 8
# PHP 7.4/8.3
# Boost
# ceph
# Google BigQuery
# PHP 8+
# Odoo
# C#
# Python 3
# MyTracker
# T-SQL
# Gradle/Maven
# Prom-Stack
# WebSocket
# Postfix
# Crossplane
# TCP/IP
# spaCy
# Python/MATLAB
# Graylog/Logstash
# MDX
# Spring
# ASР.NЕТ Core
# SOAP/REST
# PowerPoint
# CustDev
# GNU/Linux
# Python/JS/TS/C++/Gо
# Memcached
# 1С:УХ
# TFS
# SOA
# Splunk
# Vite.js
# App.Метрика
# WAF
# vSphere
# AutoCAD
# GitLab
# SoapUI
# Flask/Django
# BPMN/UML
# Django/DRF
# Redash/Superset/Tableau/Power BI/Google Data Studio
# OpenNebula
# Knockout.js
# Proxmox
# Sentry/Kibana
# Kafka / IBM MQ
# SWIFT CSP
# Charles/Fiddler
# Kotlin/PHP/Go/Python/JS/TS/Java
# C
# SCOM
# Terraform/Terragrunt/OpenTofu
# .NET Framework
# Tableau/Power BI/DataLens
# Hugging Face
# C/Python/Go/Java
# Photoshop
# Calico
# Puppet
# LaTeX
# pytest
# Cisco ISE
# PostgreSQL/MySQL/Redis/Kafka/ELK-стек/MQ
# Yandex Cloud/AWS/GCP
# OSI Model
# LTV
# Prometheus / Thanos / VictoriaMetrics / AlertManager / Sentry / Grafana / Coroot
# MS AD/Free IPA/LDAP/ALD Pro
# FQDN
# Dagger 2
# Robotium
# JavaScript/Sharp/Go
# Flexbox
# PL/SQL
# XML/XSD
# TeamCity/Gitlab
# SMTP
# Boot
# OSA
# Azure VM
# 1С:УПП
# NiFi
# Data Lake
# NumPy
# Python/R
# FortiGate
# HTTP
# Meson
# ASP.NET
# YARN
# VMware
# Oozie
# Google Cloud Platform
# Frida
# JUnit 5
# PagerDuty
# Python
# Ansible / Helm
# NLP
# CloudFormation/Terraform
# GCP
# ALD Pro
# 1С:ЗУП 3.1
# Open Source
# MS
# YDB
# VXLAN
# Managed Kubernetes
# Kaspersky KUMA
# 1С:ДО
# HashiCorp Vault
# Jest
# ALT Linux
# RESTful API
# Web3
# Binutils
# MS Windows 2000/XP/Vista/7
# Gensim
# GitHub
# Hibernate
# Selenide
# Apache Kafka
# C++14/17/20
# MS Windows
# Gin
# Golang
# Openshift/Kubernetes
# MS Visio
# Astra
# СТО БР ИББС
# DWH
# С
# Next.js
# Viper
# CoreData
# AliCloud
# Google Cloud
# QML
# Terraform/OpenTofu
# Gitlab/Jenkins
# SLB
# ClickHouse/Athena
# MVVM
# Cypress
# NTP
# Selenoid
# Shell
# Veritas NetBackup
# Check Point
# vLLM
# BI/DWH/ETL
# PowerCLI
# SOAP
# RS422
# С++/Руthоn
# SPA
# Java SE API
# Vertica
# aiohttp
# Cacti
# Yandex Cloud
# .NET 8
# Java 17/21
# Espresso
# Assembler
# DML
# Tableau
# PostgreSQL/MongoDB/Redis/Kafka/RabbitMQ
# Postman/Paw
# PyTorch
# MS Project
# Business Studio
# Numpy
# Xcode
# Go/Java/Python/PHP
# MS SQL Server/PostgreSQL
# Superset/Tableau
# MirrorMaker
# Windows/Linux/macOS
# Platform as a Service (PaaS)
# OpenSearch/Elasticsearch
# Axure
# Markdown
# Riverpod
# C4 model
# .NET 5+
# NGFW
# SAP ERP
# С/С++
# Charles/Proxyman
# QQRT
# Jira/TFS
# Nginx
# Swift 5.9
# GraphQL APIs
# RTOS
# OSPF
# LDIF
# Arenadata DB
# Oracle Linux
# Milvus
# PAM
# Trino
# RHEL/CentOS/Ubuntu/Debian
# JUnit 5/Mockito/WireMock
# CSS / JS
# Fortigate
# PowerShell
# htop
# Jupyter Notebook
# CCNA
# TSDB
# PEFT
# Yandex Tracker
# Julia
# SwiftUI
# Samba
# React/Vue
# OpenAPI/Swagger
# SciPy
# C#/.NET
# Go/Python/Bash
# MS SQL/PostgreSQL
# СКЗИ
# GIL
# Playwright
# OpenSearch DQL
# dbt
# JavaScript
# Archi
# PL/pgSQL
# IDEF0
# Java / C++ / Python / Go / TypeScript
# RDS
# Arenadata
# OPNsense
# Metasploit
# ProtoPie
# VPN
# CI
# JUnit/TestNG
# RS485
# helpdesk
# OpenShift 4
# OpenID
# RHEL
# PySpark
# Prettier
# Power Query
# Scikit-learn
# Claude
# Express
# BI tools
# Helmfile
# ClickHouse/Greenplum/Vertica
# REST/WebSocket
# PHP/Go
# API Gateway
# Zustand
# Go
# Go/Angular/TS
# Adobe Creative Suite
# ESXi
# Cisco ASA
# Spring Framework
# Traefik
# RabbitMQ
# WCF
# PCI DSS
# Figma / Sketch / Photoshop
# Victoria Metrics
# EDR
# Kotlin / Java / C / Objective-C / Swift
# GigaChat
# HTML / CSS
# ESLint
# dblink
# Hadoop
# Postman/SoapUI
# Microsoft Project
# AWS / Microsoft Azure / Google Cloud Platform
# LLM
# SaltStack
# Puppet/Salt/Chef
# SH
# JS/TypeScript
# Provider
# Postman/Insomnia/Bruno
# MS SQL / PostgreSQL
# Amplitude/GA/Mixpanel/Adjust
# MPLS
# Gitlab CI
# AppsFlyer
# MySQL/PostgreSQL/ClickHouse
# Django REST Framework
# C# (.Net) / Java
# RuDesktop
# Clean Architecture
# Zendesk
# Canvas
# Jenkins
# FreeIPA
# NPS
# PostgreSQL/MS SQL
# SQLite
# JSON / XML
# Fiddler
# iOS/Android
# JMS
# ASP.NЕT Core
# Azure
# Fastly
# AWK
# STRIDE
# CJM
# OpenStack/ПК СВ Брест/oVirt/zVirt
# HTTP/gRPC
# SQL/NoSQL
# Rational Rose
# *nix
# STP
# Media3
# JavaScript/React
# QUIK
# SnapKit
# LAMP
# РЕД ОС
# Cucumber
# Grid
# Hue
# GSLB
# Swift
# Jenkins/TeamCity
# HDFS
# WireMock
# Oracle PL/SQL
# SAST
# ZFS
# Ethereum
# C++/Go/Java
# SubGhz / IRDA / NFC / RFID / IButton / USB / BLE / ZigBee / SDCard
# YAXunit
# Oracle SQL
# ISIS
# Snyk
# Telegraf
# Patroni/ClickHouse
# macOS
# Spring Cloud
# RASP
# Amazon Web Services (AWS)
# MySQL
# Google Analytics
# GCC
# ML
# Kotlin
# TypeScript
# C/ C++ / Rust
# CloudFront
# DMP/CDP/OMP
# AWS CloudWatch
# sockets
# GTM
# Java 21
# Hadoop/Hive/Spark
# Ollama
# NAT
# pandas
# Qdrant
# PostgreSQL/MS SQL/Oracle
# scikit-learn
# ITSM
# DNS
# AWS/Oracle
# XML-RPC
# Python/C++
# xPerf
# RedHat
# 1С:Бухгалтерия
# UCCE
# Arenadata QM
# MVC
# Spring Boot
# CVE
# Lottie
# Consul
# MVP
# Apache NiFi
# ZeroMQ
# Distributed Switch
# Nimble
# Postman (Swagger)
# PHP 8
# Apache Superset
# IBM MQ
# Python/Go
# GDB
# YT
# Helm Chart
# REST/GraphQL
# Poetry
# MS SQL Server
# ITIL/ITSM
# Java/Kotlin
# RT-Thread/Azure RTOS ThreadX
# Java Performance
# Bash/Python/Go
# Miro/Figma/Jira/Confluence
# REST API / JSON
# FineBI
# Moira
# RxJava 2
# SOAR
# Prophet
# Palo Alto
# Java Core
# Golang/C/C++
# cURL
# HTTP/SOAP
# Vault
# Veeam
# Gatling
# Celery
# VMware vSphere
# Ceph
# RecSys
# Offensive Security / GIAC
# Docker Swarm
# ActiveMQ/RabbitMQ/Kafka
# Python/Bash/Go
# RESTfu
# GigaChain
# Redis/Memcached
# DataLens
# MobX
# Keycloak
# Helm
# Flutter
# Airflow / Luigi
# ITIL
# React.js
# GitLab/GitFlic
# RoBERTa
# BPMN 2.0
# GitHub Actions/Gitlab CI
# Shell/Python
# RedisDB
# L3VPN
# Material Design
# JSON / XSD
# Java/Spring
# Microsoft SQL Server
# Golang/Java/Python/C#
# IIS
# TypeORM
# Citrix
# Next.js/Remix
# Bitbucket
# USB
# 1С:ERP
# Redshift
# GitLab CI
# MobSF
# Symfony
# QEMU/KVM
# ETL
# Monitoring
# Go / PHP
# Teamcity
# Protobuf
# Windows Server
# KeyCloak
# Python / Java
# RxJS
# Java SE 17+
# Java/Go
# OAuth 2.0/OIDC/SAML
# Kerberos
# Big Data
# AV/EDR
# ASР.NЕТ MVC
# Maven
# DataGrip
# UML
# Astra Linux
# Fore
# Flutter_bloc
# Docker Compose
# Java/Scala
# vSwitch
# PostgreSQL/MySQL
# React Testing Library
# Tailwind CSS/Bootstrap
# C++17/20
# BPMSoft
# OEL
# Word
# 1С:Управление Торговлей 8
# Cisco AnyConnect
# Airflow / Dagster
# BPA
# SSIS
# Nuxt.js/Nuxt
# Figma/FigJam
# cert-manager
# R/Julia
# Network Services
# STM32
# CCNP
# TeamCity/Jenkins
# Gradio
# FastAPI/Flask/Django
# Cisco
# MS Office
# Python/Scala
# CAD
# NestJS
# Microsoft Office
# Software Testing Life Cycle (STLC)
# Adobe Photoshop
# OpenShift/Kubernetes
# Nexus
# Яндекс.Метрика
# Yandex Cloud/GCP/Azure/AWS
# TypeScript + Playwright
# Boost (C++ libraries)
# С# /.NET Core
# Makefile
# Gravity UIKit
# Flask
# Java / Python / Go / С++
# DREAD
# Windows Containers
# 1С
# PHP 8.3+
# Adobe InDesign
# InfluxDB
# RxSwift
# BPMN
# MariaDB
# Go / Python
# Okta
# Greenplum / ClickHouse
# NLTK
# SWIFT
# Git Workflow
# DevTools
# Java/Python/C#/Gо
# PaaS
# VictoriaMetrics/ Prometheus
# XCode
# CS
# Octavia
# Scipy
# Thanos
# NTLM
# Atlassian
# SDN
# Pandas
# CCNA Security
# Fluentd
# Oracle/PostgreSQL/MS SQL
# HDD/SSD
# Blender
# Keepalived
# Locust
# C/C++/C#/Rust
# virsh
# OpenShift
# Entity Framework
# 1С:БП 3.0
# Dart
# 1С:БП КОРП
# Java/Python
# Databricks
# Vector
# FastAPI
# RabbitMQ/Kafka
# UNIX
# FAISS
# IaaS (Infrastructure as a Service)
# Runtime-Mobile-Security
# Astra Linux/Debian/Ubuntu
# DAST
# jQuery
# VMware vSAN
# VanillaJS
# Mockito
# Raw SQL
# PostgreSQL/Redis
# ktlint
# Gemini AI
# 1С:Битрикс
# С++ / Python / С#
# TimescaleDB
# .NET Framework 4.8
# Service Management HP
# Omnissa
# Rsyslog/Logstash/Filebeat/Kafka/Elasticsearch/Kibana
# Terragrunt
# HTTP/HTTPS
# Microsoft Visio
# API
# RDBMS
# BrowserStack
# CI/CD
# Principle
# Vite
# JDBC
# SOAP/REST/MQ
# EQL/KQL
# JupyterHub
# Nova
# Retention
# БИТ.ФИНАНС
# Kafka
# ARM
# Burp Suite
# Datadog
# Oracle/MS SQL
# SQL
# Microsoft PowerPoint
# WebSoft
# DAX
# Jaeger
# Python/C/C++
# VMware VM
# pyodbc
# Zabbix/Nagios
# XSD
# PostgreSQL 14+
# Oracle RDBMS 12+
# NFS/SMB/iSCSI
# Ubuntu
# C++11/14/17/20
# RecSys/NLP
# Qt
# RTL
# AsyncIO
# 1С:ERP УХ
# ChatGPT/Perplexity
# Docker
# MFA
# QEMU/KVM/Libvirt
# ClickHouse/Vertica/Presto/Trino/Hive
# ASOC
# Go/Java
# SNS
# Postman
# JMeter
# User Flows
# Poetry/UV
# Cyber Kill Chain
# MLflow
# Adobe
# Pulsar
# LoRa
# Atlassian Jira
# Drone CI
# autotools/autoconf
# AliCloud ECS
# WAN/LAN
# Zabbix
# EDR/XDR
# Yandex Data Transfer
# Active Directory / OpenLDAP / SambaDC / FreeIPA
# DDD
# OAuth
# BGP/OSPF
# iOS SDK
# SAS
# XCTest
# 1С:Бухгалтерия 8.3
# JPA
# BGP
# STL
# Cycle.js
# Jenkins/Gitlab/TeamCity
# C / Python / Go / Angular
# Gradle
# Quick
# Prisma ORM
# Salt
# MSSQL Server
# Python3
# Git
# Airflow/Nirvana/Prefect
# Prefect
# PHP
# Airflow
# RPA
# TeamCity
# Athena
# Vue Router
# Pydantic v2
# Ruby
# BPMN 2.0 / ЕРC / IDEF0
# Groovy
# Java 11+
# Cortex-M4
# Sass
# Oracle
# NetBox
# Spark/Hadoop
# Teradata
# Impala
# MS Excel
# ETL/ELT
# HPE
# CSS3
# 1C:Предприятие
# Hyper-V
# МойОфис/MS Office
# ActiveMQ
# Bash/Shell/Python/PowerShell
# Zabbix/StatsD/Prometheus/Sentry
# DHCP
# PL/PostgreSQL
# ELK/Zabbix/Grafana/Prometheus
# kubeadm
# XCUITest
# ExoPlayer
# Gitlab/Gitea
# XGBoost
# Go/Python
# GitHub Actions
# Torch
# Junit
# I2C
# DB2
# Apache Spark
# Redis
# PL/Plus
# JavaScript (ES6+)
# Docker/Kubernetes/Ansible/SaltStack/Gitlab
# Bare Metal
# ArgoCD
# Docker/Kubernetes
# IPSec
# Data Pipelines
# Fastlane
# MS SQL
# Power BI
# 1С:Конвертация данных 2.0
# UserNotifications
# MikroTik
# LDAP
# Windows/Linux
# Java 17 / Spring Boot
# MITRE ATT&CK
# Rabbit MQ
# CLI psql
# statsmodels
# SDLC
# AWS/AliCloud
# FTP
# TRON
# SAP PowerDesigner
# Scikit Learn
# Linux/Windows
# MinIO
# DLP
# Creatio
# ESB
# SQLmap
# Linters
# C++
# Rhino
# npm
# Zookeeper
# Seaborn
# Firebase
# TMS
# Envoy
# TestRail
# Grafana/Prometheus/VictoriaMetrics/Zabbix
# Artemis MQ
# IPS/IDS
# vCenter
# MediaCodec API
# CMake
# virt-manager
# Informatica
# ЦОД
# TensorFlow
# Appium
# Laravel
# JMeter / Gatling / k6 / yandex-tank
# WDM
# TypeScript/JavaScript
# REST/SOAP
# Allure
# Java SE 8+/Кotlin
# XML/JSON
# Bamboo
# Pewee
# XGBoost/LightGBM/CatBoost
# AD DS
# Adobe Illustrator
# Nuxt.js
# Security
# Cloudflare
# Linux Kernel
# PromQL
# Kaspresso

# %%
unique_descriptions_keys = set()

for vacancy in vacancies:
    descriptions = vacancy.get('descriptions', {})
    unique_descriptions_keys.update(descriptions.keys())

print('\n'.join(unique_descriptions_keys))
# Out:
# The tasks will include
# Нам важно, что бы у вас было
# Что мы можем тебе дать:
# Обучение и карьера:
# Что вас ждет
# От кандидата ожидаем:
# Что тебе может дать компания
# Key responsibilities include
# Kotlin-разработчик в нашей команде
# What you will do
# Что мы предлагаем для тебя:
# Как построена работа
# Структура собеседований
# Этапы найма
# Финансовые условия:
# Какие задачи вас ждут.
# Он
# Мы ждём
# Что необходимо для максимального результата
# Что важно
# Условия
# В каждом проекте у нас есть основные направления
# About the team
# Для сотрудников компании
# Из важного:
# Формальный список того, что нужно делать
# Ждем от тебя
# Минимальные требования
# Кого мы ищем
# Ключевые навыки, программы, софт:
# Что мы ждем:
# Что мы ожидаем от кандидата
# Что мы ожидаем от Вас
# Требования к кандидатам
# О компании
# ЧЕМ ТЫ БУДЕШЬ ЗАНИМАТЬСЯ:
# Навыки
# Что ждём от кандидата:
# Что в Точке необычного
# Пожелания к опыту
# Что ожидаем от тебя:
# Иви ценит:
# Fullstack-разработчик в команде
# Ты наш человек, если у тебя есть
# Примеры вопросов, на которые мы ищем ответы
# Вот как это выглядит
# Мы ожидаем, что ты:
# Разработчик в команде
# Нам важно, чтобы у вас было
# Наши задачи
# Challenges you will tackle
# Что ждёт тебя в Точке
# What you will be doing
# Чем вы будете заниматься
# Будет здорово, если вы:
# Что у нас интересного
# О Deckhouse
# Необходимые технические навыки:
# Как понять, что ты подойдешь
# Обязанности
# Должностные обязанности
# И еще
# Нам по пути, если у тебя
# Мы ждем от тебя
# Будет плюсом, если вы
# Ну и самое приятное. Со своей стороны Иви обещает с первых дней
# О задачах
# Nice-to-have
# Наши команды
# Работа у нас это
# Пара примеров конкретных задач
# Что мы можем предложить
# Как все устроено в Иви
# What is culture like at Wert
# Expectations
# Системный инженер в нашей команде
# Мы ждем, что ты
# Мы ожидаем от вас
# Особенности проектов и стек
# Кандидат должен
# От тебя мы ожидаем энергию и желание участвовать в решении сложных и интересных задач
# Основные задачи нашей команды:
# Требования к кандидату:
# Что предстоит делать у нас
# Мы ожидаем, что вы
# Вы будете
# Корпоративная жизнь
# Проекты
# Наши пожелания к кандидатам:
# Про проект
# Системный инженер в отдел ИТ-инфраструктуры
# Тебя ждёт:
# Для нас важно
# Мы хотим видеть самостоятельного профессионала с крепким опытом, который
# Преимущества вакансии
# Подробнее о продукте/проекте
# Функциональные обязанности
# Задачи в работе
# Как всё устроено в Иви:
# How we work and what we offer
# Задачи, которые нужно решать
# Чем ты будешь заниматься
# Что нужно делать
# Почему именно Т1:
# Наши условия
# Как откликнуться:
# Кому подойдет
# Useful links
# Ну и самое приятное. Со своей стороны Иви обещает с первых дней:
# Технический стек:
# Что тебя ждет
# Что нужно будет:
# Преимущества работы в Т1:
# Мы от вас ожидаем
# Наши преимущества
# У нас
# Наша миссия
# Мы готовы предложить:
# Что мы делаем
# What We Offer
# Выплаты и бонусы:
# Responsibilities
# ЧЕМ ПРЕДСТОИТ ЗАНИМАТЬСЯ
# Что мы ждем от кандидата:
# Мы ожидаем:
# Этапы трудоустройства
# Стек
# Задачи Java-разработчика
# Что с тебя
# Что ждем от тебя
# Conditions
# Чем необходимо заниматься
# Ключевые задачи:
# О Core команде
# Вместе с нами тебе предстоит строить highload-архитектуру, которая будет способна выдерживать высокие нагрузки.
# Будет плюсом, если:
# Что мы ожидаем от Вас:
# О нашей команде
# Преимущества работы с нами
# Требования:
# Также вы будете:
# What makes this role unique
# Технические требования:
# Working place
# Наши пожелания к кандидату:
# От нас:
# Дальнейшие шаги, если твое резюме подходит
# О команде Платформы и инфраструктуры TATLIN.OBJECT
# Старший аналитик данных
# Будет плюсом
# ЖДЕМ ОТ ТЕБЯ
# О системе
# Этапы интервью
# We are offering
# Требуемые навыки и знания:
# Кто мы
# Тебя ждет:
# Как мы работаем
# Мы ждем, что ты:
# Больше о нашей команде
# Наши ожидания от кандидата:
# Задачи:
# Мы ждём от вас
# Required skills:
# В настоящий момент мы в поиске DevOps-инженера, который имеет
# Что важно для нас:
# Что для нас важно?
# Мы ждём, что вы.
# Основные задачи
# Что ждем от вас:
# Задачи системного инженера
# Дополнительно для тех, кто с нами в петербургском офисе:
# Мы готовы предложить
# Что мы ожидаем
# Делаем всё, чтобы работа была в кайф
# What do we expect from a future team member
# Обучение
# Обязанности и задачи:
# Тебе предстоит:
# Мы ожидаем, что ты
# Что нам важно
# Наши алгоритмы работают в трёх больших направлениях
# Benefits:
# What we offer along the way:
# Работа в 2ГИС
# Будем рады предложить:
# Мы ожидаем, что ты обладаешь:
# For this role, responsibilities are
# Вызовы
# У нас все сложится, если у тебя есть
# Также будет круто, если ты:
# Наши пожелания к твоим навыкам и опыту
# Preferred skills
# Работа должна быть в кайф, поэтому у нас есть
# Задачи на ближайший квартал
# Какие есть команды
# Чем нужно будет заниматься
# Нам важны:
# Чем будем заниматься:
# Задачи на данной позиции
# Структура собеседования
# Какие задачи тебя ждут
# Будет плюсом, если вы.
# Как работает Multitrack
# Nice to have skills
# Зачем тебе к нам
# От разработчика, который хочет попасть в программу, мы ждём
# Пожелания к твоему опыту
# Мы ждем от вас
# У нас:
# Чем нужно заниматься:
# Задачи, которые вам предстоит решать
# Position overview
# Жми откликнуться, если:
# Как все устроено в Иви:
# Что для нас важно в кандидате
# Любопытные факты о наших разработчиках
# От нас
# Что предстоит делать
# Required Skills
# Что нужно, чтобы присоединиться к нам
# Мы
# Наши таргеты
# Кроме того
# Our ways of working
# Функциональные задачи
# Проект
# Что мы ожидаем от вас
# About our office
# Фишки работы у нас
# Challenges that await you
# Наши ожидания
# Что нужно делать:
# Комфорт и свобода
# What we offer
# У нас ты будешь
# Какие сейчас есть вызовы
# Какие преимущества работы
# Мы ждём от Вас
# Role Overview
# Почему Tripster?
# Что мы предлагаем?
# Our benefits
# Как устроен процесс найма
# Your responsibilities
# Our expectations
# Требования
# Профессиональное обучение:
# Работать в Nexign — это значит:
# Почему CUSTIS
# Benefits
# We offer excellent benefits, including but not limited to:
# Learn more
# Наш будущий коллега:
# Почему мы
# Что с Вас
# The expectations for this role are to
# Почему тебе у нас точно понравится
# В X5 Group входят
# Ключевые обязанности
# У нас есть
# Our usual stack looks like this
# Нам важно
# Задачи, которые нужно будет решать
# ОТ ТЕБЯ ПОТРЕБУЕТСЯ:
# You will be truly welcome in our team if
# Чего мы ждем от специалиста?
# You will:
# Что мы готовы предложить
# Будет круто, если ты
# Мы будем рады рассмотреть вашу кандидатуру, если у вас есть
# Наш стек
# Задачи QA-инженера
# Мы ждём от будущих коллег
# Условия и что даёт работа в продуктовых командах X5 Group
# Чем нужно будет заниматься?
# Вызовы, которые перед нами стоят
# Дополнительные очки
# Этапы отбора
# Мы гарантируем
# Как это будет
# Работай с комфортом
# Наш стек:
# Вам предстоит
# Ждём от тебя
# QA-инженер в нашей команде
# Вместе с нами ты будешь:
# Как откликнуться
# Opportunities and tasks
# Что для нас важно
# Чем у нас предстоит заниматься
# Основные обязанности:
# Твои задачи на этой позиции
# КОМАНДА И ПРОЦЕССЫ:
# You would be a good fit if:
# Развитие в профессии
# Sounds like you? Apply.
# Чем у нас нужно заниматься
# What we can offer
# О проекте
# Для нас важно:
# Этапы после отклика:
# Как лиду, тебе предстоит нести ответственность за качество дизайна и эффективность трёх дизайнеров:
# Что нужно иметь и знать
# Мы ожидаем от будущего члена команды:
# Необходимые навыки
# Наши системы:
# Education
# В задачи будет входить:
# Мы ждём, что вы:
# Приятное дополнение:
# Будет здорово, если вы имеете
# Преимущества работы в компании
# Что мы предлагаем:
# Удаленная работа только на территории РФ.
# Что предлагаем:
# What makes you a great fit:
# Навыки и опыт
# Proficiency in:
# Наш будущий коллега
# Join Our Team
# Что мы ждем
# Нам нравится во Flocktory, потому что мы
# Будем рады предложить Вам
# Что мы ждём:
# Полезные ссылки
# Что мы предлагаем
# Социальный пакет
# We will be glad to offer you
# В Nexign тебя ждёт
# Что мы предоставляем
# Бенефиты
# About company and Who is it for?
# Tech Lead
# ЧТО У НАС ЕСТЬ:
# Задачи
# Как у нас всё устроено
# Про команду и рабочий процесс
# Что необходимо делать
# Основные функции
# В команде Иви тебе предстоит
# Дальнейшие шаги если твое резюме подходит
# Будет мэтч, если:
# Почему с нами классно
# Ключевые задачи
# About you
# Процесс интервью
# Твои задачи
# Что именно нужно будет делать:
# Как устроен наш процесс найма
# Requirements
# Работать в NEXIGN — это значит
# Java-разработчик в нашей команде
# Задачи, которые предстоит решать
# У нас классно, потому что у нас есть
# Когда начинается Multitrack
# Что с нас
# КАК У НАС ВСЕ УСТРОЕНО?
# Наши ожидания:
# Бонусы
# Задачи Kotlin-разработчика
# Recruitment process
# Вам предстоит:
# Day-to-day you will:
# Аналитик данных
# Вам предстоит заниматься
# Бенефиты для сотрудников
# Наш кандидат
# Hiring Process
# What will you do
# Этапы собеседования
# Плюсом будет:
# Мы Группа Астра
# Наш технический стэк:
# Это вас заинтересует, если вы
# Проекты, которыми мы занимаемся
# Что хотели бы видеть в кандидате
# Qualifications
# А еще мы заботимся о сотрудниках
# Какие знания и навыки для нас важны
# Что по атмосфере
# Задачи, которые предстоит решать:
# Ты нам подходишь, если:
# Какие будут задачи
# Временная зона команды
# Тебе предстоит
# Что для этого нужно
# Чем привлекательна эта вакансия
# Что делает Golang-команда
# Мы ожидаем, что у вас есть:
# О проекте:
# Что мы ждем от кандидатов
# Вы нам подходите, если
# Interview process
# Со своей стороны Иви обещает с первых дней
# Желательно:
# Плюсом будет, если вы:
# Процесс найма
# Какие задачи вас ждут
# Мы ждём от тебя
# Мы ждём опыт работы с
# Salary and benefits
# Что мы можем предложить взамен
# О продукте
# Мы рассчитываем, что ты
# Мы предлагаем:
# Что ты получишь, работая с нами
# Процесс отбора
# Условия труда:
# Почему рекомендуем
# С кем нужно будет взаимодействовать
# Полезные источники
# Nice to have:
# Your role at Exness
# Мы ждем, что вы
# Ожидания Иви от кандидата
# Что ты получишь
# As a ClickHouse DBA, you will be responsible for
# About the Role
# Что вас ждёт с нами:
# Твои задачи:
# Будущий аналитик данных
# Why join us
# What we expect from you
# Почему у нас круто
# А еще:
# И ещё
# Что для этого от тебя необходимо:
# Key responsibilities:
# Про команду и рабочие процессы
# Ну и самое приятное. Со своей стороны, Иви обещает с первых дней
# Чем предстоит заниматься:
# От тебя мы ожидаем
# Как устроен наш процесс найма:
# Ты будешь
# Почему к нам
# Зачем мы вам
# Minimum requirements
# Вам предстоит развиваться в следующих областях
# Required experience
# Preferred Qualifications
# Наши пожелания к твоим знаниям и опыту
# Примеры будущих задач
# Условия:
# Skills needed
# Required Skills and Experience
# Что предстоит
# Чем можем похвастаться
# Кого ищем:
# Взаимодействие:
# О тебе
# Будем рады пообщаться, если у тебя имеется
# Требования и профессиональные навыки
# Что мы ожидаем от будущего члена команды
# Почему именно Т1
# Как у нас все устроено
# Мы предоставляем:
# В обмен на ваше участие предлагаем следующее
# Ищем аналитика данных данных, который будет
# Чего ждать на собеседовании
# Hiring process
# Мы предлагаем
# Мы ожидаем от будущего члена команды
# Перед тобой будут стоять следующие задачи
# Пара важных вещей
# Что тебя ждёт с нами:
# У нас три этапа онлайн-интервью:
# Почему у нас классно
# Продукт построен на базе ОС Linux, поэтому мы ожидаем от вас
# Будем рады пообщаться, если
# Ты подходишь, если
# Адреса наших офисов
# Еще немного о жизни в Иви
# Key Responsibilities
# О команде
# ТЕХНОЛОГИЧЕСКИЙ СТЕК:
# Почему именно Т1?
# Цифровой продукт «Управление проектами».
# Ключевые навыки
# Ожидания от успешного кандидата
# What we offer along the way
# Иви ожидает от кандидата
# Что мы ждём от кандидата
# We offer
# Что делать
# Для этого тебе понадобится
# А что по плюшкам?
# Нам по пути, если у тебя есть
# Обязанности старшего аналитика данных
# Какие задачи предстоит решать
# Conditions and benefits
# Необходимый опыт и навыки
# Что вы будете делать
# Responsibilites
# Что мы ждем от кандидата
# Про условия
# Что мы предлагаем для тебя
# Мы ожидаем от будущего сотрудника
# Дополнительные инструкции
# Про технологии и наши ожидания
# Ваши будущие задачи
# Работа у нас — это:
# О нас
# Diversity, Equity, and Inclusion at Constructor
# Ожидаем от тебя
# Interview stages
# Your journey after applying:
# Немного о нашем стеке
# Duties and opportunities
# Причины работать с нами
# What you will need to do
# О команде и задачах на проекте
# Tasks
# Пример задач, над которыми сейчас работаем
# Skills and qualifications
# Why Wert
# Основные задачи:
# Преимущества
# От тебя мы ожидаем энергию и желание решать сложные и интересные задачи
# Мы ждем от тебя:
# Наши технологии и практики
# Чего мы ждём от специалиста
# Вы будете:
# Основные обязанности
# Задачи разработчика
# Your journey after applying
# Особенно актуальное
# Успех в этой роли обеспечат
# У тебя точно всё получится, если ты:
# Забота о здоровье:
# Твой скилл
# Ваши задачи
# Your role at Exness:
# Приятное дополнение
# У тебя точно все получится, если ты
# Условия работы:
# What you can expect from us
# Мы ожидаем, что у тебя
# Задачи, с которыми предстоит работать
# Работа в Ozon Банке — это:
# Наша вакансия для вас, если вы:
# Часовой пояс команды
# Experience with:
# От вас нужно
# Что мы ждём от тебя
# Как устроена разработка
# Для решения этих задач требуется
# Мы используем
# Что мы ждём от вас
# В команде Иви тебе предстоит:
# Key responsibilities
# Преимущества работы в Яндексе
# Нам нужен специалист, который
# Ты подойдёшь, если
# От вас требуется
# Будет преимуществом:
# Мы ищем
# Об IT в цифрах:
# Our ideal candidate
# Что нам важно:
# Чем Вам предстоит заниматься
# Для работы необходимо:
# Наши ожидания от будущего члена команды
# Цели и задачи (на любой вкус)
# Мы готовы предложить вам
# We are looking for candidates with the following qualifications
# What the job involves
# Требования к кандидату
# Полезные материалы
# Насыщенную корпоративную жизнь:
# Multitrack вам подойдёт, если
# Почему именно мы:
# Мы ждём, что ты
# Тебе к нам, если:
# Responsibilities:
# У нас с тобой случится мэтч, если у тебя есть
# Что даем:
# Мы ожидаем наличие практического опыта в следующих областях
# Кто мы:
# Мы делаем всё, чтобы работа была в кайф
# Хорошая зарплата
# Наш идеальный кандидат
# Про команду
# Будущие задачи
# Оплата и условия
# Мы ждём, что вы
# Тебя ждет
# Что у нас классного
# Проект:
# Т-Банк это
# Для работы тебе потребуется
# О нашем офисе
# Location
# Чем будешь заниматься у нас
# Почему у нас круто работать
# Для нас важны
# Процессы
# О компании и команде
# Формат работы
# Будущие челленджи:
# About Company
# O продукте
# C нас
# Будет здорово, если вы
# Итак, вам предстоит
# Личностные качества:
# Requirements:
# Предпочтения:
# Полезные материалы на внешних ресурсах
# Вместе с нами тебе предстоит
# Какие знания и навыки для нас важны:
# Что нужно, чтобы к нам присоединиться
# Наши доклады и статьи
# В нашей команде ты
# Пожелания к твоему опыту и знаниям
# Мы ожидаем
# Ожидаем:
# Что делает автор
# Чем предстоит заниматься
# Skills and Experience
# Будущие задачи:
# Дополнительно
# Что с атмосферой
# Задачи DevOps-инженера
# Perks and Benefits
# Подробнее о продукте / проекте
# Будем рады вам предложить
# Преимущества работы в Т1
# Будет плюсом (любой из пунктов):
# About project
# А так же
# Компания предлагает:
# Кого и зачем мы ищем
# Необходимый опыт и знания
# Будет плюсом:
# Наш технологический стек
# Чем тебе предстоит заниматься
# Что предстоит делать?
# Что нужно будет делать
# Что предстоит делать:
# Чем предстоит заниматься?
# Что ждем от кандидата
# Что для нас важно:
# Что будешь делать?
# Компания предлагает
# Что ожидают от разработчика
# What makes you a great fit
# О команде и направлениях
# В X5 Tech мы предлагаем
# Наши условия:
# Кого ищут
# Про продукт
# Обязанности аналитика данных
# Процесс разработки в Хантфлоу
# What we hope to see in you
# We offer excellent benefits, including but not limited to
# И плюшки
# Технологический стек:
# Работа в VK — это
# Обязательно наличие портфолио в резюме.
# Ты будешь заниматься
# Что предлагаем
# Вместе с нами ты будешь
# Почему Golang-разработчику хорошо в 2ГИС
# Ключевые навыки:
# Задачи проекта:
# We Offer:
# Кого ищем
# Тебе предстоит работа со следующими задачами:
# You will
# Что нужно будет делать:
# Ожидания
# Что мы ожидаем:
# Об ИТ в цифрах:
# И самое главное, мы предлагаем
# About Project:
# Team working hours
# Кандидату предстоит:
# Комфортные условия:
# Critical Competencies
# Наша команда активно использует современные технологии и инструменты:
# Наши пожелания к кандидатам
# Мы ожидаем, что вы:
# Our Mission:
# Формат работы:
# Будет плюсом, если вы:
# Ты нам подходишь, если у тебя есть
# Задачи и обязанности
# Ждём от кандидата
# Мы предоставим
# Чем вы будете заниматься:
# Что мы ждём от кандидата:
# Что предлагают
# Time zone:
# Каким мы вас видим
# Работа в VK — это:
# Что ждём от кандидата
# Обязанности:
# Чем вам предстоит заниматься
# Условия работы
# Работа у нас — это
# DevOps-инженер в нашей команде
# Ожидания от кандидата
# От кандидата ожидаем
# Об условиях
# Экология и благотворительность:
# Навыки:
# Ожидания Иви от кандидата:

# %% [markdown]
# Вот какие данные из получившегося массива включим в датасет:
#
# **`title`**</br>
# Оставляем как есть (будет столбец `title`).
#
#
# **`company`**</br>
# Для большинства строк оставляем как есть, для тех где название скрыто делаем 'None' (будет столбец `company`).
#
# **`salary`**</br>
# Делаем два числовых столбца: `salary_from` и `salary_to`. Если указана одна зарплата, пишем ее в оба столбца. Для удобства сразу переведем в рубли, хотя бывает еще в долларах и в евро (по примерному курсу).
#
# **`locations`**</br>
# Делаем один строковый столбец: `locations`. Из каждого элемента массива уберем лишнее (эмодзи, значения в скобках), перечислим через запятую.
#
# **`categories`**</br>
# Категорий мало. Из них составим следующие признаки:
#
# - `type`</br>
# remote (если есть 'Полная удалёнка')</br>
# hybrid (если есть 'Офис или гибрид', 'Офис несколько дней в неделю')</br>
# office (в других случаях)
#
# - `relocation`</br>
# 1 (если есть 'Самостоятельный переезд' / 'Помощь с переездом' и нет 'Можно удалённо из РФ')</br>
# 0 (в других случаях)
#
# - `relocation_help`</br>
# 1 (если есть 'Помощь с переездом')</br>
# 0 (в других случаях)
#
# **`terms`**</br>
# Самих условий мало, а вот данные в них разные. В итоге, сделаем 4 столбца:
#
# - `specialization`</br>
# Оставляем текстом как есть (т.к. очень много значений, это будет текстовое поле).
#
# - `level`</br>
# Оставляем как есть, это отличный категориальный признак (6 вариантов + может быть неизвестно).
#
# - `english_level`</br>
# Оставляем только код (B1, ...), это тоже отличный категориальный признак (5 вариантов  + может быть неизвестно).
#
# - `min_experience`</br>
# Это минимальное число лет опыта, распарсим строки типа '3+ лет' в числа. Если не указано, это не NaN, а 0 (получается, опыт не требуется).
#
# **`stack`**</br>
# Вариантов очень много, так что сделаем тоже текстовое поле (через запятую, назовем `stack`).
#
# **`descriptions`**</br>
# К сожалению, оказалось что заголовки везде разные, и какой-то их порядок гаранировать нельзя. Поэтому в рамках работы просто соберем все в одно текстовое поле с описанием. Но вообще, это можно было бы использовать как-то обработав сами тексты, так что есть простор для дальнейших работ :) Назовем столбец `description`.

# %%
def process_company(company):
  if company and 'Название скрыто' in company:
    return None

  return company

# %%
def process_salary(salary):
    # смотрим, что зарплата есть
    if pd.isna(salary) or salary == '':
        return None, None

    # убираем пробелы и ищем числа
    salary = str(salary).replace(' ', '')
    numbers = re.findall(r'\d+', salary)
    numbers = [int(num) for num in numbers]

    # должно получиться 1 или 2 числа: на всякий случай проверяем
    if len(numbers) not in [1, 2]:
        print(f'error: {salary}')
        return None, None

    # получаем валюту
    if '₽' in salary:
        currency = '₽'
    elif '€' in salary:
        currency = '€'
    elif '$' in salary:
        currency = '$'
    else:
        currency = None

    # переводим в рубли
    if currency == '€':
        numbers = [num * 93 for num in numbers]
    elif currency == '$':
        numbers = [num * 89 for num in numbers]
    elif currency is None:
        return None, None

    # задаем зарплаты от и до
    if len(numbers) == 1:
        salary_from = salary_to = numbers[0]
    else:
        salary_from, salary_to = numbers

    return salary_from, salary_to

# %%
def process_locations(locations):
    # смотрим, что места есть
    if not locations:
        return None

    # убираем лишнее и пишем в строку через запятую
    return ', '.join([re.sub(r"📍\s*|\s*\(.*\)", "", location).strip() for location in locations])

# %%
def process_categories(categories):
    # задаем дефолтные значения
    values = {
        'type': 'office',
        'relocation': 0,
        'relocation_help': 0
    }

    # если категорий вообще нет, возвращаем дефолт
    if not categories:
        return values

    # проверяем категории для типа работы
    if 'Офис или гибрид' in categories or 'Офис несколько дней в неделю' in categories:
      values['type'] = 'hybrid'

    if 'Полная удалёнка' in categories:
      values['type'] = 'remote'

    # проверяем категории для обязательной релокации
    if ('Самостоятельный переезд' in categories or 'Помощь с переездом' in categories) and (not 'Можно удалённо из РФ' in categories):
      values['relocation'] = 1

    # проверяем категории для наличия помощи с релокацией
    if 'Помощь с переездом' in categories:
      values['relocation_help'] = 1

    return values

# %%
def process_terms(terms):
    return {
        'specialization': terms.get('Специализация') if terms.get('Специализация') else None, # если есть оставляем
        'level': terms.get('Уровень') if terms.get('Уровень') else None, # если есть оставляем
        'english_level': terms.get('Английский').split()[0] if terms.get('Английский') else 'Не требуется', # если есть оставляем первое слово (код)
        'min_experience': int(re.findall(r'\d+', terms.get('Требуемый опыт', '0'))[0]) if terms.get('Требуемый опыт') else 0 # если есть парсим, иначе 0
    }

# %% [markdown]
# Преобразуем получившийся массив в датафрейм:

# %%
vacancies_copy = [vacancy.copy() for vacancy in vacancies]

for vacancy in vacancies_copy:
    # компания
    vacancy['company'] = process_company(vacancy.get('company'))

    # зарплата
    salary_from, salary_to = process_salary(vacancy.get('salary', ''))
    vacancy['salary_from'] = salary_from
    vacancy['salary_to'] = salary_to

    # локация
    vacancy['locations'] = process_locations(vacancy.get('locations', []))

    # Обрабатываем категории
    categories = process_categories(vacancy.get('categories', []))
    vacancy.update(categories)

    # условия
    terms = process_terms(vacancy.get('terms', {}))
    vacancy.update(terms)

    # стек
    vacancy['stack'] = ', '.join(vacancy.get('stack', []))

    # описание
    vacancy['description'] = '\n\n'.join(vacancy.get('descriptions', {}).values()) if isinstance(vacancy.get('descriptions'), dict) else ''


get_match_df = pd.DataFrame(vacancies_copy)
get_match_df = get_match_df[[
    'title',
    'company',
    'salary_from',
    'salary_to',
    'locations',
    'type',
    'relocation',
    'relocation_help',
    'specialization',
    'level',
    'english_level',
    'min_experience',
    'stack',
    'description'
]]

get_match_df.head()
# Out:
#                                                title  \
# 0                   Senior DevOps/DevSecOps Engineer
# 1  Разработчик на Python (Непрерывная интеграция ...
# 2  Ведущий продакт-менеджер экосистемы по взаимод...
# 3     Архитектор продукта (1С: Управление проектами)
# 4                                  Affiliate Manager
#
#                      company  salary_from  salary_to  \
# 0                  Collectly     534000.0   712000.0
# 1  Яндекс (Поисковый портал)     220000.0   450000.0
# 2                      Avito     355000.0   466000.0
# 3                   Гринатом     300000.0   300000.0
# 4                    Winline     150000.0   200000.0
#
#                                            locations    type  relocation  \
# 0  Бразилия, Сербия, Аргентина, Черногория, Испан...  remote           0
# 1                                             Москва  hybrid           0
# 2                                             Москва  remote           0
# 3                                             Москва  hybrid           0
# 4                                             Москва  hybrid           0
#
#    relocation_help                                     specialization   level  \
# 0                0                      DevOps / Information Security  Senior
# 1                0                                             Python  Middle
# 2                0                                    Product Manager  Senior
# 3                0                                                 1C  Middle
# 4                0  Product Analyst / Product Manager / Project Ma...  Middle
#
#   english_level  min_experience  \
# 0            B2               0
# 1  Не требуется               3
# 2  Не требуется               0
# 3  Не требуется               3
# 4  Не требуется               2
#
#                                                stack  \
# 0  Ansible, Terraform, CI/CD, AWS/Azure/GCP, Jenk...
# 1                                      Python, CI/CD
# 2
# 3  1С: Предприятие 8, 1С:PM Управление проектами ...
# 4  Google Analytics, Яндекс.Метрика, Excel, Power...
#
#                                          description
# 0  Design, develop, and maintain robust infrastru...
# 1  Стремитесь выбирать хорошие архитектурные реше...
# 2  Разработка и внедрение стратегии развития CRM-...
# 3  Быть единой точкой архитектурных решений за ко...
# 4  Поддерживать и развивать партнерские отношения...

# %%
get_match_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1200 entries, 0 to 1199
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   title            1200 non-null   object
#  1   company          1132 non-null   object
#  2   salary_from      1137 non-null   float64
#  3   salary_to        1137 non-null   float64
#  4   locations        891 non-null    object
#  5   type             1200 non-null   object
#  6   relocation       1200 non-null   int64
#  7   relocation_help  1200 non-null   int64
#  8   specialization   1200 non-null   object
#  9   level            1200 non-null   object
#  10  english_level    1200 non-null   object
#  11  min_experience   1200 non-null   int64
#  12  stack            1200 non-null   object
#  13  description      1200 non-null   object
# dtypes: float64(2), int64(3), object(9)
# memory usage: 131.4+ KB

# %%
get_match_df.isna().sum()
# Out:
# title                0
# company             68
# salary_from         63
# salary_to           63
# locations          309
# type                 0
# relocation           0
# relocation_help      0
# specialization       0
# level                0
# english_level        0
# min_experience       0
# stack                0
# description          0
# dtype: int64

# %%
# создаем новый salary, который будет средним из salary_from и salary_to
get_match_df["salary"] = get_match_df[["salary_from", "salary_to"]].mean(axis=1, skipna=True)
get_match_df.head()
# Out:
#                                                title  \
# 0                   Senior DevOps/DevSecOps Engineer
# 1  Разработчик на Python (Непрерывная интеграция ...
# 2  Ведущий продакт-менеджер экосистемы по взаимод...
# 3     Архитектор продукта (1С: Управление проектами)
# 4                                  Affiliate Manager
#
#                      company  salary_from  salary_to  \
# 0                  Collectly     534000.0   712000.0
# 1  Яндекс (Поисковый портал)     220000.0   450000.0
# 2                      Avito     355000.0   466000.0
# 3                   Гринатом     300000.0   300000.0
# 4                    Winline     150000.0   200000.0
#
#                                            locations    type  relocation  \
# 0  Бразилия, Сербия, Аргентина, Черногория, Испан...  remote           0
# 1                                             Москва  hybrid           0
# 2                                             Москва  remote           0
# 3                                             Москва  hybrid           0
# 4                                             Москва  hybrid           0
#
#    relocation_help                                     specialization   level  \
# 0                0                      DevOps / Information Security  Senior
# 1                0                                             Python  Middle
# 2                0                                    Product Manager  Senior
# 3                0                                                 1C  Middle
# 4                0  Product Analyst / Product Manager / Project Ma...  Middle
#
#   english_level  min_experience  \
# 0            B2               0
# 1  Не требуется               3
# 2  Не требуется               0
# 3  Не требуется               3
# 4  Не требуется               2
#
#                                                stack  \
# 0  Ansible, Terraform, CI/CD, AWS/Azure/GCP, Jenk...
# 1                                      Python, CI/CD
# 2
# 3  1С: Предприятие 8, 1С:PM Управление проектами ...
# 4  Google Analytics, Яндекс.Метрика, Excel, Power...
#
#                                          description    salary
# 0  Design, develop, and maintain robust infrastru...  623000.0
# 1  Стремитесь выбирать хорошие архитектурные реше...  335000.0
# 2  Разработка и внедрение стратегии развития CRM-...  410500.0
# 3  Быть единой точкой архитектурных решений за ко...  300000.0
# 4  Поддерживать и развивать партнерские отношения...  175000.0

# %%
from google.colab import files
get_match_df.to_csv('get_match_df.csv', index=False)
files.download('get_match_df.csv')
