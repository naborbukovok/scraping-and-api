# %% [markdown]
# # Современные методы анализа данных и машинного обучения, БИ
#
# ## НИУ ВШЭ, 2024-25 учебный год

# %% [markdown]
# ## Групповой проект №2. DE: Scraping & API

# %% [markdown]
# ## Общая информация

# %% [markdown]
# __Дата выдачи:__ 21.02.2025
#
# __Защита проекта:__ 05.03.2025

# %% [markdown]
# ## Формат выполнения

# %% [markdown]
# Групповой проект представляет собой творческое инициативное групповое задание, которое выполняется студентами в командах от 3 до 6 человек. В то же время, следует помнить, что чем больше в команде людей, тем выше предъявляются требования в целом к команде, а также к выполняему ею проекту. Команды разрешается формировать из студентов разных групп.
#
# При оценивании результатов выполнения проекта командой, в обязательном порядке проверяется и учитывается в оценке вклад ***каждого участника*** в общую работу команды. Вследствие этого, крайне важно ответственно подойти к выбору сокомандников, распределению обязанностей внутри команды, а также пресечению наличия "мертвых душ" в команде.
#
# При необходимости, команда большинством голосов имеет право исключить человека из команды *до защиты проекта*, сообщив об этом преподавателю, в случае если такой человек никак не проявлялся в ходе выполнения проекта и являлся как раз таки той самой "мертвой душой". Помните про эту возможность, поскольку наличие "мертвых душ" может негативно повлиять на качество и оценку для всего проекта и, как следствие, в целом для всей команды!
#
# Запись составов команд осуществляется по ссылке в таблице:
#
# https://docs.google.com/spreadsheets/d/1aUFah0NgORUzjMoA6QxKt7OyVN5djf1Vvq3vB1bbx8k/edit?usp=sharing

# %% [markdown]
# ## Оценивание и штрафы

# %% [markdown]
# Групповой проект оценивается исходя из устной защиты (презентации) командой выполненного ими проекта перед комиссией. Комиссия составляется из преподавателей курса, ассистентов курса, а также приглашенных экспертов из индустрии.
#
# В рамках каждой защиты комиссия выставляет два типа оценок.
#
# Первая оценка — это оценка для всего проекта в целом. Она ставится комиссией, исходя из глубины проработки командой предметной области, сложности применяемых в проекте инструментов, а также прочих аспектов, связанных с содержанием выполняемого в проекте ТЗ. При выставлении этой оценки комиссия ориентируется на критерии, более подробно представленные ниже в разделе "Критерии оценки проекта".
#
# Вторая оценка — это индивидуальная оценка каждого участника команды. Именно эта оценка выставляется впоследствии в ведомость. Индивидуальная оценка участника команды определяется комиссией, исходя из того, насколько участник ориентируется в выполненном командой проекте, как он отвечает на адресованные персонально ему вопросы комиссии, насколько в принципе прослеживается его роль в проекте, а также исходя из других аспектов, связанных с участием конкретного человека в деятельности команды. Индивидуальная оценка не может превосходить оценку команды за проект в целом (первую оценку), однако, в случае когда участник спокойно и корректно отвечает на все адресованные ему вопросы, свободно ориентируется в материале и содержании выполненного проекта, а также когда его роль в работе команды не вызывает сомнений, — в таком случае, индивидуальная оценка участника становится равной оценке для всего проекта (т.е. в идеальном случае — вторая оценка равна первой оценке). Кроме того, в исключительных случаях, при демонстрации участником на защите превосходящих ожидания уровней понимания, участия и вовлечения в рамках проекта, комиссия может своим решением повысить индивидуальную оценку для этого участника на 0,5 или 1 балл относительно общей оценки за проект (первой оценки).
#
# Во избежание субъективности и/или предвзятости оценки тех или иных членов комиссии в отношении тех или иных команд, а также каких-либо иных проявлений неравных условий — распределение команд между комиссиями осуществляется абсолютно рандомно с использованием средств библиотеки Numpy :)) — в качестве рэндом сида выступает дата, в которую производится распределение, например, `np.random.seed(21022025)`.
#
# Обратите, пожалуйста, внимание на то, что бОльшая часть комиссий осуществляет приём проектов в очной форме, однако могут присутствовать и 1-2 комиссии, которые будут работать дистанционно с использованием средств видеосвязи. В случае попадания команды путем случайного распределения в комиссию, работающую в очной форме, *не допускается* какое-либо изменение формата проведения для команды на онлайн-режим, равно как и любые другие перемещения команд между комиссиями (смены комиссий), для сохранения честности и непредвзятости случайного распределения.
#
# Явка студента на защиту проекта является обязательной; вклад студента без его присутствия не оценивается и автоматически является равным нулю. Для дистанционных комиссий, дополнительным требованием является обязательное наличие включенной камеры в течение всего времени нахождения в конференции

# %% [markdown]
# ## Описание задания

# %% [markdown]
# В современном мире данных эффективный сбор и интеграция информации из различных источников являются фундаментом для принятия обоснованных решений и успешного ведения бизнеса. Компании, стремясь к конкурентоспособности, активно используют технологии веб-скрапинга и взаимодействия с API для автоматизации процесса сбора данных, обеспечения их актуальности и полноты.
#
# В данном проекте вы на реальных данных попрактикуетесь в том, как осуществляется веб-скрапинг различных сайтов для извлечения необходимой информации, а также в работе с API популярных сервисов для получения структурированных данных. Вы научитесь применять современные инструменты и библиотеки, отражающие различные этапы DE, обрабатывать и очищать полученную информацию, а также интегрировать данные из различных источников для последующего использования их в аналитических и бизнес-задачах.

# %% [markdown]
# ### Постановка задачи

# %% [markdown]
# В рамках этого проекта вы сами найдете датасет, с которым будете работать. Точнее, не найдете, а... соберёте его самостоятельно на основе источников!
#
# Итак, начните с того, что выберите два сайта/портала со схожей тематикой (например, NYT и Bloomberg). Их тематика должна позволять в дальнейшем объединить данные в единую таблицу. Один из этих двух сайтов нужно будет обработать с помощью средств Web-Scraping'a и Data Parsing'a; другой же — используя API.
#
# Определившись с источниками, непосредственно проделайте скачивание данных путём скрейпинга и методами API соответственно и затем объедините всё в финальный датасет. Обязательным требованием к датасету является также наличие в нём как минимум одного столбца с текстовыми данными: описание, состав, комментарии о чём-либо, текст заметки/новости, или что-то ещё.
#
# Кроме того, разумеется, следует помнить, что полученный датасет должен, конечно, быть осмысленным с бизнес-точки зрения и потенциально позволять решать какую-то конкретную бизнес-задачу. Это как минимум означает, что каждому объекту, имеющему своё признаковое пространство — в том числе с текстовым признаком, — должно также соответствовать значение некоторой целевой переменной, которая является релевантной в рамках выбранной вами предметной области.

# %% [markdown]
# Примеры задач, которые мы можем предложить вам в качестве источника для вдохновения — пожалуйста, ни в коем случае не воспринимайте это как исчерпывающий список — это действительно всего лишь примеры:
#
# * Сайт новостей: текстовый столбец — сама новость; признаки — различные характеристики новости: автор, дата публикации, тип новости и т.д.; целевая переменная — количество просмотров новости (можно поделить на число дней с момента даты публикации, чтобы получить «среднее число просмотров в день», что ещё нагляднее)
#
# * Сайт с товарами/книгами/фильмами: текстовый столбец — описание товара/книги/фильма; признаки — различные характеристики объекта: цена, год производства/выпуска, компания-производитель и т.д.; целевая переменная — средний рейтинг объекта
#
# * Блоги: текстовый столбец — тексты заметок; признаки — различные характеристики заметки: автор, время публикации, количество прикрепленных изображений и т.д.; целевая переменная — число просмотров
#
# * И любые другие ваши идеи, которые подходят под описанный выше формат

# %% [markdown]
# После сбора данных и объединения их в общий датасет, необходимо очистить его от мусора (в том числе, например, с помощью регулярных выражений); посчитать различные статистики по собранным данным (в случае если столбец текстовый, то, например, посчитать частотности слов, выявляя наиболее частотные слова, и т.д.); а также в целом провести EDA в контексте той бизнес-задачи, которую мы потенциально хотим решить по полученному датасету. В конце сделать выводы из проделанной работы.

# %% [markdown]
# ### Этапы проекта

# %% [markdown]
# Ниже для вашего удобства еще раз в краткой форме представляем примерные этапы реализации проекта:
#
# - Выбор источников данных, в соответствии с требованиями, описанными выше
# - Формулировка бизнес-задачи, которую могла бы хотеть решить компания/платформа, на основе собираемых данных
# - Обоснование сформулированной бизнес-задачи
# - Извлечение данных путём работы с API
# - Извлечение данных путём скрапинга и парсинга
# - Первичная обработка данных (EDA)
# - Получение и агрегация результатов, финальные выводы

# %% [markdown]
# ### Общие требования к проекту

# %% [markdown]
# В качестве результата выполнения группового проекта ваша команда должна получить презентацию, а также репозиторий с кодом на GitHub. Демонстрация репозитория и защита презентации перед комиссией осуществляется в фиксированную дату.
#
# Оформление презентации остаётся полностью на ваше усмотрение, но помните, что результат должен быть релевантен для демонстрации бизнес-заказчику — комиссию, принимающую вашу работу, правильнее всего воспринимать именно в таком качестве. Например, вставлять в презентацию строчки кода или злоупотреблять скринами блокнота не рекомендуется.
#
# С точки зрения концепции выполнения проекта — вам необходимо принять на себя роль дата-инженеров: продумать идеологию получения и извлечения данных с платформы — и дата-аналитиков: соотнести бизнес-задачу с формулировками на языке данных и извлечь полезные инсайты из проделанной работы. А в конце, конечно, — презентовать всю эту красоту в понятном виде потенциальному заказчику.
#
# Разумеется, чем сложнее и чем нетривиальнее будет ваша задача, а также чем глубже и чем осмысленнее будут выводы, извлечённые в рамках этой задачи, — тем выше окажется качество вашего проекта и тем выше он будет оценён!

# %% [markdown]
# ### Полезные замечания и советы

# %% [markdown]
# - Графики и визуализации — это очень хорошо — все любят графики
# - Следите за тем, чтобы все графики на слайдах можно было прочитать даже без ваших комментариев
# - Не нужно делать просто текстовые слайды
# - Стройте свой проект, исходя из того, что ваша цель представить полезную информацию для бизнеса
# - Любой хороший Data Scientist должен уметь работать в команде, поэтому распределение ваших усилий в проекте остается за вами

# %% [markdown]
# ### Технические требования

# %% [markdown]
# Ниже чуть более детализированно будут представлены минимальные технические требования по всем основным этапам и составным частям выполняемого вами группового проекта.

# %% [markdown]
# #### Обязательный сбор данных через API

# %% [markdown]
# * Необходимо реализовать сбор данных через API для как минимум одного веб-сайта
# * При формировании датасета должно осуществляться **не менее 5** различных запросов к API
# * Данный этап является обязательным, что означает, что без его полного выполнения ***нельзя получить оценку за проект выше 1***

# %% [markdown]
# #### Обязательный сбор данных посредством скрапинга

# %% [markdown]
# * Необходимо реализовать сбор и парсинг данных через библиотеки `requests` / `bs4` и другие рассмотренные в рамках семинара для как минимум одного веб-сайта, отличного от веб-сайта из предыдущего пункта
# * Получившийся датасет должен содержать **не менее 10 000** записей
# * Данный этап является обязательным, что означает, что без его полного выполнения ***нельзя получить оценку за проект выше 1***

# %% [markdown]
# #### Разведочный анализ данных (EDA)

# %% [markdown]
# * Изучить особенности данных в рамках объединённого датасета:
#   * Есть ли пропущенные значения? Сколько? Какова их доля от общего числа объектов для каждого конкретного признака? И, в целом, насколько ваш датасет “разрежен” в контексте пропущенных значений? Выдвинуть и (желательно) проверить гипотезу, что могут означать пропущенные значения? Осмысленно и аргументированно обработать пропуски.
#   * Есть ли ошибочные  (например, отрицательный возраст или пятиметровый рост человека; 3-й класс в задаче бинарной классификации) значения (признаки, целевая переменная) в данных? Обработать их.
#   * Есть ли выбросы в данных? По возможности обработать их.
# * Изучить поведение каждого признака в отдельности, его связь с целевой переменной, а также попарные корреляции (в том числе и в особенности с таргетом). Визуализировать попарные распределения признаков и корреляции наиболее значимых.
# * Построить подходящие сводные таблицы и прочие диаграммы.
# * Если проведенный вами анализ позволяет сделать какие-либо выводы, постараться сформулировать их максимально глубоко и развернуто. Упомянуть, как можно задействовать в дальнейшем приобретенные вами на этом этапе знания в решаемой задаче.
# * Осуществить и другие осмысленные действия в рамках процесса EDA.

# %% [markdown]
# #### GitHub и требования при использовании СКВ

# %% [markdown]
# *   Для выполнения задания вы должны создать проект на GitHub (один репозиторий на всю команду!)
# *   Необходимо добавить в репозиторий `.gitignore` и не грузить в репозиторий лишние файлы
# *   Необходимо добавить в репозиторий `README.md` с подробным описанием проекта. В этот файл также необходимо добавить подробное описание данных — описание признаков, их тип, количество объектов каждого класса (в задачах классификации), информацию о пропущенных значениях (в т.ч о типичных филлерах, если это не `nan`). Также добавляйте другие релевантные вашей задачи описательные характеристики данных. После чтения этого файла у человека со стороны не должно остаться никаких вопросов про данные
# *   В репозитории проекта размещаются ноутбуки / скрипты со сбором данных
# *   Коммиты делаются осмысленно, с понятными внешнему наблюдателю комментариями — что было сделано по факту
# *   При разработке необходимо соблюдать [гитфлоу](https://www.umgum.com/gitlab-workflow)

# %% [markdown]
# #### Артефакты по окончании работы над проектом

# %% [markdown]
# * Ноутбуки / скрипты со сбором и извлечением данных
# * Ноутбуки c осуществлением EDA
# * Файл `.gitignore`
# * Заполненный файл `README.md` в репозитории проекта на гитхабе со ссылкой на данные и их подробным описанием, с выводами о проведенном EDA

# %% [markdown]
# #### Логирование

# %% [markdown]
# * Для получения высоких баллов добавьте в ваш проект логирование. Потренируйтесь включать и выключать его через файл настроек, а также задавать уровень логирования через этот же файл (не в приложении)
# * Запустите ваш код, чтобы сохранился файл с логами
# * Про логи можно почитать [тут](https://habr.com/ru/companies/wunderfund/articles/683880/) и [тут](https://tproger.ru/articles/shpargalka-po-logirovaniju-na-python)

# %% [markdown]
# #### Библиотека Selenium

# %% [markdown]
# * Для получения высоких баллов используйте библиотеку Selenium при сборе данных
# * Реализуйте имитацию работы пользователя через Selenium
# * Про данную библиотеку можно почитать [тут](https://habr.com/ru/companies/selectel/articles/754674/) и [тут](https://happypython.ru/2022/11/27/selenium-chromedriver-find-elements/)

# %% [markdown]
# ## Критерии оценки проекта

# %% [markdown]
# Оценка за групповой проект в целом — то есть первая из двух оценок — выставляется по 10 балльной шкале, исходя из 3 критериев. Также комиссия на своё усмотрение может добавить (но не снизить) некоторое количество бонусных баллов за рамками данных критериев.
#
# Каждый из критериев будет перечислен и рассмотрен ниже.

# %% [markdown]
# ### Критерий 1. Выбор задачи и EDA (до 3,5 баллов)
#
# Данный критерий оценивает, насколько обоснованной и осмысленной получилась решаемая бизнес-задача; насколько полно был осуществлен переход от бизнес-задачи к пайплайну подготовки данных (насколько в реальности формируемый датасет соответствует исходной постановке задачи с точки зрения интересов компании и насколько может помочь в решении такой задачи); а также насколько корректными, объёмными и прикладными для бизнеса получились выявленные в ходе исследования инсайты.

# %% [markdown]
# ### Критерий 2. GitHub (до 1 балла)
#
# Данный критерий оценивает, насколько корректным и квалифицированным было применение средств системы контроля версий в проекте; насколько были выполнены представленные в задании требования по всем необходимым файлам и условиям в рамках работы с GitHub; а также насколько эффективно данная система в действительности использовалась командой для распараллеливания задач по проекту.

# %% [markdown]
# ### Критерий 3. Инструменты извлечения данных (до 5,5 баллов)
#
# Данный критерий оценивает техническую реализацию процесса сбора данных автоматизированным образом с сайтов и порталов. В рамках этого критерия будет рассматриваться спектр различных технических инструментов, внедрённых в проект; корректность, эффективность и правильность их применения; а также сложность и новизна алгоритмов, подходов и библиотек, применяемых к данным.
#
# *__Важно:__ в случае оценки __1 балл и ниже__ за этот критерий — оценка за весь проект становится равна оценке за этот критерий.*
#
# *По данному критерию можно получить __больше 1 балла__ только при условии применения как средств Data Scraping (автоматического считывания HTML-кода страниц с последующей его обработкой), так и средств API (получению данных с использованием официальных протоколов компании/портала). При этом средства Scraping и API следует применять к разным компаниям/порталам, но представленным в рамках одной и той же предметной области (бизнес-задачи).*
#
# *По данному критерию можно получить **3 балла и выше** только при условии использования в проекте логирования __ИЛИ__ библиотеки Selenium.*
#
# *По данному критерию можно получить **4 балла и выше** только при условии использования в проекте логирования __И__ библиотеки Selenium.*
#
# *По данному критерию можно получить **5 баллов и выше** только при условии использования в проекте логирования, библиотеки Selenium и, кроме этого, обоснованного применения дополнительных инструментов/подходов/библиотек, не упомянутых ранее в этом ноутбуке и не рассматривавшихся в рамках соответствующего семинара.*

# %% [markdown]
# # Выбор источников данных, в соответствии с требованиями, описанными выше
# Мы выбрали сайты hh.py и getmatch. Это сайты по поиску работы и они отлично подходят под вышеописанные требования. Они позволяют собирать данные о вакансиях, требованиях к кандидатам, а также о зарплатах, что является необходимым для решения поставленной задачи. Для сбора данных с сайта HH.py будет использован API, а с getmatch мы будем собирать данные с помощью Скраппинга.
#
# Важно отметить, что был выбран сайт getmatch для анализа IT-индустрии. При сборе данных с hh.py также брали IT-профессии.

# %% [markdown]
# # Формулировка бизнес-задачи, которую могла бы хотеть решить компания/платформа, на основе собираемых данных
# Бизнес-задача, которую можно решить, основываясь на собранных данных, заключается в **предсказании ожидаемой заработной платы по различным критериям**(профессия, уровень образования, опыт работы, город, условия работы и тд)

# %% [markdown]
# # Обоснование сформулированной бизнес-задачи
# Такой инструмент может быть полезен как для соискателей, чтобы они могли оценить, какая зарплата ожидается на конкретной должности в соответсвии с их опытом, навыками и тд, так и для работодателей или hr-ов, чтобы понять рыночные ставки по вакансии перед поиском нового сотрудника, а также более точно формулировать требования к кандидатам и устанавливать конкурентоспособные предложения по зарплате. Или понимать, как динамично меняются зарплаты на рынке труда, чтобы привлечь хороших специалистов.

# %% [markdown]
# ### Scraping (GetMatch)

# %%
import pandas as pd
import re
import requests
from bs4 import BeautifulSoup

# %% [markdown]
# Ссылка страницы в списке вакансий имеет вид ```https://getmatch.ru/vacancies?p={page}```, при этом если ввести слишком большой номер страницы, она отображается корректно, просто без вакансий. Поэтому, чтобы собрать все ссылки, будем идти по страницам до тех пор, пока на них есть вакансии.

# %%
def get_page_vacancies_urls(page):
    page_url = f'https://getmatch.ru/vacancies?p={page}'

    page = requests.get(page_url)
    if page.status_code != 200:
        return

    page_vacancies_urls = []

    soup = BeautifulSoup(page.content, 'html.parser')

    for link in soup.find_all('a'):
        if '?s=offers' in link.get('href') and link.get('href').startswith('/vacancies'):
            page_vacancies_urls.append(link.get('href'))

    return page_vacancies_urls

# %%
vacancies_urls = []
page = 1

while True:
    page_vacancies_urls = get_page_vacancies_urls(page)

    if not page_vacancies_urls:
        break

    vacancies_urls.extend(page_vacancies_urls)
    page += 1

print(vacancies_urls)

# %% [markdown]
# Проверим, что собрали. Действительно, на момент выполнения кода на сайте было 1203 вакансий и 2 рекламные страницы (которые имеют такую же ссылку, как вакансии). Итого 1205.

# %%
len(vacancies_urls)

# %% [markdown]
# Изучим полученную разметку на примере одной ссылки. Напишем функцию для сбора информации по конкретной вакансии.

# %%
vacancy = requests.get(f'https://getmatch.ru{vacancies_urls[6]}')
soup = BeautifulSoup(vacancy.content, 'html.parser')
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html dir="ltr" lang="ru">
#  <head>
#   <link crossorigin="" href="https://fonts.gstatic.com" rel="preconnect"/>
#   <meta charset="utf-8"/>
#   <title>
#    Вакансия Affiliate Manager, работа в Winline, в Москве — getmatch
#   </title>
#   <base href="/"/>
#   <meta content="width=device-width, initial-scale=1, maximum-scale=1" name="viewport"/>
#   <meta content="#ffffff" name="theme-color"/>
#   <link href="/uploads/favicons/favicon.svg" rel="icon"/>
#   <link color="#205AED" href="/uploads/favicons/mask-icon.svg" rel="mask-icon"/>
#   <link href="/uploads/favicons/apple-touch-icon.png" rel="apple-touch-icon"/>
#   <link href="/uploads/favicons/manifest.json" rel="manifest"/>
#   <link href="/uploads/favicons/favicon.ico" rel="shortcut icon"/>
#   <style type="text/css">
#    @font-face{font-family:'Montserrat';font-style:normal;font-weight:300;font-display:swap;src:url(https://fonts.gstatic.com/s/montserrat/v29/JTUSjIg1_i6t8kCHKm459WRhyyTh89ZNpQ.woff2) format('woff2');unicode-range:U+0460-052F, U+1C80-1C8A, U+20B4, U+2DE0-2DFF, U+A640-A69F, U+FE2E-FE2F;}@font-face{font-family:'Montserrat';font-style:normal;font-weight:300;font-display:swap;src:url(https://fonts.gstatic.com/s/montserrat/v29/JTUSjIg1_i6t8kCHKm459W1hyyTh89ZNpQ.woff2) format('woff2');unicode-range:U+0301, U+0400-045F, U+0490-0491, U+04B0-04B1, U+2116;}@font-face{font-family:'Montserrat';font-style:normal;font-weight:300;font-display:swap;src:url(https://fonts.gstatic.com/s/montserrat/v29/JTUSjIg1_i6t8kCHKm459WZhyyTh89ZNpQ.woff2) format('woff2');unicode-range:U+0102-0103, U+0110-0111, U+0128-0129, U+0168-0169, U+01A0-01A1, U+01AF-01B0, U+0300-0301, U+0303-0304, U+0308-0309, U+0323, U+0329, U+1EA0-1EF9, U+20AB;}@font-face{font-family:'Montserrat';font-style:normal;font-weight:300;font-display:swap;src:url(https://fonts.gstatic.com/s/montserrat/v29/JTUSjIg1_i6t8kCHKm459WdhyyTh89ZNpQ.woff2) format('woff2');unicode-range:U+0100-02BA, U+02BD-02C5, U+02C7-02CC, U+02CE-02D7, U+02DD-02FF, U+0304, U+0308, U+0329, U+1D00-1DBF, U+1E00-1E9F, U+1EF2-1EFF, U+2020, U+20A0-20AB, U+20AD-20C0, U+2113, U+2C60-2C7F, U+A720-A7FF;}@font-face{font-family:'Montserrat';font-style:normal;font-weight:300;font-display:swap;src:url(https://fonts.gstatic.com/s/montserrat/v29/JTUSjIg1_i6t8kCHKm459WlhyyTh89Y.woff2) format('woff2');unicode-range:U+0000-00FF, U+0131, U+0152-0153, U+02BB-02BC, U+02C6, U+02DA, U+02DC, U+0304, U+0308, U+0329, U+2000-206F, U+20AC, U+2122, U+2191, U+2193, U+2212, U+2215, U+FEFF, U+FFFD;}@font-face{font-family:'Montserrat';font-style:normal;font-weight:400;font-display:swap;src:url(https://fonts.gstatic.com/s/montserrat/v29/JTUSjIg1_i6t8kCHKm459WRhyyTh89ZNpQ.woff2) format('woff2');unicode-range:U+0460-052F, U+1C80-1C8A, U+20B4, U+2DE0-2DFF, U+A640-A69F, U+FE2E-FE2F;}@font-face{font-family:'Montserrat';font-style:normal;font-weight:400;font-display:swap;src:url(https://fonts.gstatic.com/s/montserrat/v29/JTUSjIg1_i6t8kCHKm459W1hyyTh89ZNpQ.woff2) format('woff2');unicode-range:U+0301, U+0400-045F, U+0490-0491, U+04B0-04B1, U+2116;}@font-face{font-family:'Montserrat';font-style:normal;font-weight:400;font-display:swap;src:url(https://fonts.gstatic.com/s/montserrat/v29/JTUSjIg1_i6t8kCHKm459WZhyyTh89ZNpQ.woff2) format('woff2');unicode-range:U+0102-0103, U+0110-0111, U+0128-0129, U+0168-0169, U+01A0-01A1, U+01AF-01B0, U+0300-0301, U+0303-0304, U+0308-0309, U+0323, U+0329, U+1EA0-1EF9, U+20AB;}@font-face{font-family:'Montserrat';font-style:normal;font-weight:400;font-display:swap;src:url(https://fonts.gstatic.com/s/montserrat/v29/JTUSjIg1_i6t8kCHKm459WdhyyTh89ZNpQ.woff2) format('woff2');unicode-range:U+0100-02BA, U+02BD-02C5, U+02C7-02CC, U+02CE-02D7, U+02DD-02FF, U+0304, U+0308, U+0329, U+1D00-1DBF, U+1E00-1E9F, U+1EF2-1EFF, U+2020, U+20A0-20AB, U+20AD-20C0, U+2113, U+2C60-2C7F, U+A720-A7FF;}@font-face{font-family:'Montserrat';font-style:normal;font-weight:400;font-display:swap;src:url(https://fonts.gstatic.com/s/montserrat/v29/JTUSjIg1_i6t8kCHKm459WlhyyTh89Y.woff2) format('woff2');unicode-range:U+0000-00FF, U+0131, U+0152-0153, U+02BB-02BC, U+02C6, U+02DA, U+02DC, U+0304, U+0308, U+0329, U+2000-206F, U+20AC, U+2122, U+2191, U+2193, U+2212, U+2215, U+FEFF, U+FFFD;}@font-face{font-family:'Montserrat';font-style:normal;font-weight:500;font-display:swap;src:url(https://fonts.gstatic.com/s/montserrat/v29/JTUSjIg1_i6t8kCHKm459WRhyyTh89ZNpQ.woff2) format('woff2');unicode-range:U+0460-052F, U+1C80-1C8A, U+20B4, U+2DE0-2DFF, U+A640-A69F, U+FE2E-FE2F;}@font-face{font-family:'Montserrat';font-style:normal;font-weight:500;font-display:swap;src:url(https://fonts.gstatic.com/s/montserrat/v29/JTUSjIg1_i6t8kCHKm459W1hyyTh89ZNpQ.woff2) format('woff2');unicode-range:U+0301, U+0400-045F, U+0490-0491, U+04B0-04B1, U+2116;}@font-face{font-family:'Montserrat';font-st ...
#   </style>
#   <style type="text/css">
#    @font-face{font-family:'Inter';font-style:normal;font-weight:400;font-display:swap;src:url(https://fonts.gstatic.com/s/inter/v18/UcC73FwrK3iLTeHuS_nVMrMxCp50SjIa2JL7W0Q5n-wU.woff2) format('woff2');unicode-range:U+0460-052F, U+1C80-1C8A, U+20B4, U+2DE0-2DFF, U+A640-A69F, U+FE2E-FE2F;}@font-face{font-family:'Inter';font-style:normal;font-weight:400;font-display:swap;src:url(https://fonts.gstatic.com/s/inter/v18/UcC73FwrK3iLTeHuS_nVMrMxCp50SjIa0ZL7W0Q5n-wU.woff2) format('woff2');unicode-range:U+0301, U+0400-045F, U+0490-0491, U+04B0-04B1, U+2116;}@font-face{font-family:'Inter';font-style:normal;font-weight:400;font-display:swap;src:url(https://fonts.gstatic.com/s/inter/v18/UcC73FwrK3iLTeHuS_nVMrMxCp50SjIa2ZL7W0Q5n-wU.woff2) format('woff2');unicode-range:U+1F00-1FFF;}@font-face{font-family:'Inter';font-style:normal;font-weight:400;font-display:swap;src:url(https://fonts.gstatic.com/s/inter/v18/UcC73FwrK3iLTeHuS_nVMrMxCp50SjIa1pL7W0Q5n-wU.woff2) format('woff2');unicode-range:U+0370-0377, U+037A-037F, U+0384-038A, U+038C, U+038E-03A1, U+03A3-03FF;}@font-face{font-family:'Inter';font-style:normal;font-weight:400;font-display:swap;src:url(https://fonts.gstatic.com/s/inter/v18/UcC73FwrK3iLTeHuS_nVMrMxCp50SjIa2pL7W0Q5n-wU.woff2) format('woff2');unicode-range:U+0102-0103, U+0110-0111, U+0128-0129, U+0168-0169, U+01A0-01A1, U+01AF-01B0, U+0300-0301, U+0303-0304, U+0308-0309, U+0323, U+0329, U+1EA0-1EF9, U+20AB;}@font-face{font-family:'Inter';font-style:normal;font-weight:400;font-display:swap;src:url(https://fonts.gstatic.com/s/inter/v18/UcC73FwrK3iLTeHuS_nVMrMxCp50SjIa25L7W0Q5n-wU.woff2) format('woff2');unicode-range:U+0100-02BA, U+02BD-02C5, U+02C7-02CC, U+02CE-02D7, U+02DD-02FF, U+0304, U+0308, U+0329, U+1D00-1DBF, U+1E00-1E9F, U+1EF2-1EFF, U+2020, U+20A0-20AB, U+20AD-20C0, U+2113, U+2C60-2C7F, U+A720-A7FF;}@font-face{font-family:'Inter';font-style:normal;font-weight:400;font-display:swap;src:url(https://fonts.gstatic.com/s/inter/v18/UcC73FwrK3iLTeHuS_nVMrMxCp50SjIa1ZL7W0Q5nw.woff2) format('woff2');unicode-range:U+0000-00FF, U+0131, U+0152-0153, U+02BB-02BC, U+02C6, U+02DA, U+02DC, U+0304, U+0308, U+0329, U+2000-206F, U+20AC, U+2122, U+2191, U+2193, U+2212, U+2215, U+FEFF, U+FFFD;}@font-face{font-family:'Inter';font-style:normal;font-weight:500;font-display:swap;src:url(https://fonts.gstatic.com/s/inter/v18/UcC73FwrK3iLTeHuS_nVMrMxCp50SjIa2JL7W0Q5n-wU.woff2) format('woff2');unicode-range:U+0460-052F, U+1C80-1C8A, U+20B4, U+2DE0-2DFF, U+A640-A69F, U+FE2E-FE2F;}@font-face{font-family:'Inter';font-style:normal;font-weight:500;font-display:swap;src:url(https://fonts.gstatic.com/s/inter/v18/UcC73FwrK3iLTeHuS_nVMrMxCp50SjIa0ZL7W0Q5n-wU.woff2) format('woff2');unicode-range:U+0301, U+0400-045F, U+0490-0491, U+04B0-04B1, U+2116;}@font-face{font-family:'Inter';font-style:normal;font-weight:500;font-display:swap;src:url(https://fonts.gstatic.com/s/inter/v18/UcC73FwrK3iLTeHuS_nVMrMxCp50SjIa2ZL7W0Q5n-wU.woff2) format('woff2');unicode-range:U+1F00-1FFF;}@font-face{font-family:'Inter';font-style:normal;font-weight:500;font-display:swap;src:url(https://fonts.gstatic.com/s/inter/v18/UcC73FwrK3iLTeHuS_nVMrMxCp50SjIa1pL7W0Q5n-wU.woff2) format('woff2');unicode-range:U+0370-0377, U+037A-037F, U+0384-038A, U+038C, U+038E-03A1, U+03A3-03FF;}@font-face{font-family:'Inter';font-style:normal;font-weight:500;font-display:swap;src:url(https://fonts.gstatic.com/s/inter/v18/UcC73FwrK3iLTeHuS_nVMrMxCp50SjIa2pL7W0Q5n-wU.woff2) format('woff2');unicode-range:U+0102-0103, U+0110-0111, U+0128-0129, U+0168-0169, U+01A0-01A1, U+01AF-01B0, U+0300-0301, U+0303-0304, U+0308-0309, U+0323, U+0329, U+1EA0-1EF9, U+20AB;}@font-face{font-family:'Inter';font-style:normal;font-weight:500;font-display:swap;src:url(https://fonts.gstatic.com/s/inter/v18/UcC73FwrK3iLTeHuS_nVMrMxCp50SjIa25L7W0Q5n-wU.woff2) format('woff2');unicode-range:U+0100-02BA, U+02BD-02C5, U+02C7-02CC, U+02CE-02D7, U+02DD-02FF, U+0304, U+0308, U+0329, U+1D00-1DBF, U+1E00-1E9F, U+1EF2-1EFF, U+2020, U+20A0-20AB, U+2 ...
#   </style>
#   <link crossorigin="anonymous" href="https://cdn.jsdelivr.net/npm/bootstrap@4.3.1/dist/css/bootstrap.min.css" integrity="sha384-ggOyR0iXCbMQv3Xipma34MD+dH/1fQ784/j6cY/iJTQUOhcWr7x9JvoRxT2MZw1T" rel="stylesheet"/>
#   <!-- Yandex Captcha -->
#   <script defer="" src="https://captcha-api.yandex.ru/captcha.js?render=onload&amp;onload=onloadFunction">
#   </script>
#   <script>
#    function onloadFunction() {
#         if (!window.smartCaptcha) {
#           return;
#         }
#         const event = document.createEvent('Event');
#         event.initEvent('captchaLoaded', true, true);
#         document.dispatchEvent(event);
#       }
#   </script>
#   <!-- Global site tag (gtag.js) - Google Analytics -->
#   <script async="" src="https://www.googletagmanager.com/gtag/js?id=UA-73568666-2">
#   </script>
#   <script>
#    window.dataLayer = window.dataLayer || [];
#       function gtag() {
#         dataLayer.push(arguments);
#       }
#       gtag('js', new Date());
#
#       gtag('config', 'UA-73568666-2', { send_page_view: false });
#   </script>
#   <script type="text/javascript">
#    (function (m, e, t, r, i, k, a) {
#         m[i] =
#           m[i] ||
#           function () {
#             (m[i].a = m[i].a || []).push(arguments);
#           };
#         m[i].l = 1 * new Date();
#         (k = e.createElement(t)),
#           (a = e.getElementsByTagName(t)[0]),
#           (k.async = 1),
#           (k.src = r),
#           a.parentNode.insertBefore(k, a);
#       })(
#         window,
#         document,
#         'script',
#         'https://mc.yandex.ru/metrika/tag.js',
#         'ym'
#       );
#   </script>
#   <noscript>
#    <div>
#     <img alt="" src="https://mc.yandex.ru/watch/64867504" style="position: absolute; left: -9999px"/>
#    </div>
#   </noscript>
#   <link href="/static-ssr/styles.51f39d6c7513b973.css" rel="stylesheet"/>
#   <style ng-app-id="serverApp">
#    h1,.fs-header-1{font-family:Montserrat;font-style:normal;font-weight:700;font-size:36px;line-height:44px;letter-spacing:normal}h2,.fs-header-2{font-family:Montserrat;font-style:normal;font-weight:700;font-size:24px;line-height:32px;letter-spacing:normal}h3,.fs-header-3{font-family:Montserrat;font-style:normal;font-weight:700;font-size:18px;line-height:24px;letter-spacing:normal}h4,.fs-header-4{font-family:Montserrat;font-style:normal;font-weight:600;font-size:15px;line-height:20px;letter-spacing:normal}h5,.fs-header-5{font-family:Montserrat;font-style:normal;font-weight:600;font-size:14px;line-height:20px;letter-spacing:normal}h6,.fs-subheader{font-family:Inter;font-style:normal;font-weight:500;font-size:14px;line-height:18px;letter-spacing:-.24px}.fs-body-1{font-family:Inter;font-style:normal;font-weight:400;font-size:15px;line-height:24px;letter-spacing:-.24px}.fs-body-2{font-family:Inter;font-style:normal;font-weight:400;font-size:14px;line-height:18px;letter-spacing:normal}.fs-label{font-family:Inter;font-style:normal;font-weight:500;font-size:11px;line-height:13px;letter-spacing:1px;text-transform:uppercase}a,.fs-link{color:#205aed;text-decoration:none;outline:none}a:hover,.fs-link:hover{color:#205aed;text-decoration:underline}a:focus,a:active,.fs-link:focus,.fs-link:active{color:#8000ff}a.no-decoration,.fs-link.no-decoration,a.no-decoration:hover,.fs-link.no-decoration:hover{text-decoration:none}.muted{color:#6c7377}.text-w-600{font-weight:600}.g-btn{display:inline-block;min-width:120px;height:40px;padding:10px 24px;border-radius:6px;border:none;outline:none;cursor:pointer;font-family:Montserrat;font-style:normal;font-weight:600;font-size:15px;line-height:20px;letter-spacing:-.24px;text-align:center;transition:background-color .2s ease-in-out,color .2s ease-in-out}.g-btn:focus{outline:none}.g-btn+.g-btn{margin-left:12px}.g-btn .icon{display:inline-block;width:20px;height:20px;margin-right:8px;margin-top:-2px;transition:filter .2s ease-in-out}.g-btn .icon-16{width:16px;height:16px}.g-btn-xs{height:32px;padding:6px 16px;font-family:Montserrat;font-style:normal;font-weight:600;font-size:14px;line-height:20px;letter-spacing:normal}.g-btn-sm{height:36px;padding:8px 12px;font-family:Montserrat;font-style:normal;font-weight:600;font-size:14px;line-height:20px;letter-spacing:-.24px}.g-btn-sm .icon{width:18px;height:18px}.g-btn-lg{height:48px;padding:14px 24px;min-width:149px}.g-btn-lg .icon{width:24px;height:24px}.g-btn-primary{background-color:#0c2231;color:#fff!important}.g-btn-primary .icon:not(.no-filter){filter:brightness(0) invert(100%)}.g-btn-primary:hover{background-color:#ffe953;color:#0c2231!important;text-decoration:none!important}.g-btn-primary:hover .icon:not(.no-filter){filter:brightness(0) saturate(100%) invert(10%) sepia(13%) saturate(2706%) hue-rotate(161deg) brightness(98%) contrast(96%)}.g-btn-primary:active{background-color:#ffe953;color:#6c7377!important;outline:none}.g-btn-primary:active .icon:not(.no-filter){filter:brightness(0) saturate(100%) invert(46%) sepia(9%) saturate(283%) hue-rotate(158deg) brightness(95%) contrast(90%)}.g-btn-primary[disabled]{cursor:not-allowed;background-color:#eff2f3;color:#9ca2a6!important}.g-btn-primary[disabled] .icon:not(.no-filter){filter:brightness(0) saturate(100%) invert(74%) sepia(7%) saturate(224%) hue-rotate(161deg) brightness(87%) contrast(88%)}.g-btn-primary[disabled]:hover{color:#9ca2a6!important}.g-btn-primary[disabled]:hover .icon:not(.no-filter){filter:brightness(0) saturate(100%) invert(74%) sepia(7%) saturate(224%) hue-rotate(161deg) brightness(87%) contrast(88%)}.g-btn-secondary{background-color:#eff2f3;color:#0c2231!important}.g-btn-secondary .icon:not(.no-filter){filter:brightness(0) saturate(100%) invert(10%) sepia(13%) saturate(2706%) hue-rotate(161deg) brightness(98%) contrast(96%)}.g-btn-secondary:hover{background-color:#e3e4e5;color:#0c2231!important;text-decoration:none!important}.g-btn-secondary:hover .icon:not(.no-filter){filter:brightness(0) sa ...
#   </style>
#   <style ng-app-id="serverApp">
#    .page-container[_ngcontent-serverApp-c1263125476]{min-height:calc(100vh - 418px)}.page-container--anonymous[_ngcontent-serverApp-c1263125476]{min-height:calc(100vh - 390px)}.page-container--no-footer[_ngcontent-serverApp-c1263125476]{min-height:unset}@media (max-width: 768px){.page-container[_ngcontent-serverApp-c1263125476]{min-height:100vh}.page-container--no-footer[_ngcontent-serverApp-c1263125476]{min-height:unset}}
#   </style>
#   <style ng-app-id="serverApp">
#    .b-header[_ngcontent-serverApp-c708908426]{background:#ffffff;height:91px}@media (min-width: 769px){.b-header[_ngcontent-serverApp-c708908426]{height:92px;border-bottom:1px solid #e3e4e5}}.b-header[_ngcontent-serverApp-c708908426]   .container[_ngcontent-serverApp-c708908426]{display:flex;align-items:center;flex-direction:row;height:100%}.b-header__logotype[_ngcontent-serverApp-c708908426]{display:block;width:134px;height:28px;background:url(/static/img/getmatch-logo.svg) no-repeat 0 0;background-size:contain;border:none;outline:none;margin-right:51px}@media (max-width: 768px){.b-header__logotype[_ngcontent-serverApp-c708908426]{margin-right:auto}}.b-header__navigation[_ngcontent-serverApp-c708908426]{display:flex;flex-wrap:nowrap;margin-right:auto;height:20px}.b-header__navigation-link[_ngcontent-serverApp-c708908426]{font-family:Montserrat;font-style:normal;font-weight:500;font-size:14px;line-height:18px;letter-spacing:normal;white-space:nowrap;color:#0c2231;margin-left:20px;position:relative}.b-header__navigation-link[_ngcontent-serverApp-c708908426]:hover, .b-header__navigation-link[_ngcontent-serverApp-c708908426]:active, .b-header__navigation-link[_ngcontent-serverApp-c708908426]:focus{text-decoration:none;color:#0c2231}.b-header__navigation-link[_ngcontent-serverApp-c708908426]:first-of-type{margin-left:0}.b-header__navigation-link[_ngcontent-serverApp-c708908426]:before{content:" ";position:absolute;width:0;border-bottom:1px solid #0c2231;top:55px;left:50%;transform:translate(-50%);transition:width .2s}.b-header__navigation-link--active[_ngcontent-serverApp-c708908426]:before{width:100%}@media (max-width: 768px){.b-header__navigation[_ngcontent-serverApp-c708908426]{display:none}}.b-header__buttons[_ngcontent-serverApp-c708908426]{white-space:nowrap}.b-header__buttons-digest[_ngcontent-serverApp-c708908426], .b-header__buttons-vacancy[_ngcontent-serverApp-c708908426]{padding:11px 16px;letter-spacing:-.408px;line-height:18px}.b-header__buttons-digest[_ngcontent-serverApp-c708908426]:hover, .b-header__buttons-vacancy[_ngcontent-serverApp-c708908426]:hover{background-color:#0c2231;color:#fff!important}.b-header__buttons-telegram[_ngcontent-serverApp-c708908426]   img[_ngcontent-serverApp-c708908426]{margin-top:-4px}.b-header__buttons-invite[_ngcontent-serverApp-c708908426]{margin-left:20px}.b-header__buttons-invite__button[_ngcontent-serverApp-c708908426]{font-family:Montserrat;font-style:normal;font-weight:600;font-size:15px;line-height:18px;letter-spacing:-.408px;text-align:center;color:#0c2231;background-color:transparent;transition:color .2s;cursor:pointer;text-transform:none;overflow:visible;border-radius:0;border:none;outline:none;margin-bottom:5px}.b-header__buttons-invite__button[_ngcontent-serverApp-c708908426]:hover{color:#6c7377}@media (max-width: 992px){.b-header__buttons-invite[_ngcontent-serverApp-c708908426], .b-header__buttons-telegram[_ngcontent-serverApp-c708908426], .b-header__buttons-vacancy--desktop[_ngcontent-serverApp-c708908426], .b-header__buttons-login[_ngcontent-serverApp-c708908426]{display:none}}.b-header__buttons-vacancy--mobile[_ngcontent-serverApp-c708908426]{display:none;padding:8px 12px;font-size:14px;line-height:20px;letter-spacing:-.408px}@media (max-width: 768px){.b-header__buttons-vacancy--mobile[_ngcontent-serverApp-c708908426]{display:inline-block}.b-header__buttons-digest[_ngcontent-serverApp-c708908426]{padding:8px 12px;font-size:14px;line-height:20px;letter-spacing:-.408px;height:36px}}.b-header__user-block-candidate[_ngcontent-serverApp-c708908426]{margin-left:28px;display:flex;align-items:center;height:40px}.b-header__user-block-candidate__avatar[_ngcontent-serverApp-c708908426]{display:inline-block;width:40px;height:40px;background:#0c2231;color:#fff;border-radius:500px;text-align:center;font-family:Montserrat;font-style:normal;font-weight:600;font-size:15px;line-height:40px;letter-spacing:-.41px;text-transform:uppercase;overflow:hidden}.b-header__user-block-candidate__avat ...
#   </style>
#   <style ng-app-id="serverApp">
#    @charset "UTF-8";.b-vacancy[_ngcontent-serverApp-c3083313915]{padding-top:28px}.b-vacancy--recruiter[_ngcontent-serverApp-c3083313915]{padding-top:60px}@media (max-width: 768px){.b-vacancy--recruiter[_ngcontent-serverApp-c3083313915]{padding-top:24px}}.b-vacancy__seo-links[_ngcontent-serverApp-c3083313915]{margin:40px 0}@media (max-width: 768px){.b-vacancy__seo-links[_ngcontent-serverApp-c3083313915]{margin:24px 0}}.b-vacancy__breadcrumbs[_ngcontent-serverApp-c3083313915]{margin-top:24px}.b-vacancy[_ngcontent-serverApp-c3083313915]   .row[_ngcontent-serverApp-c3083313915]{margin:0 -20px}.b-vacancy[_ngcontent-serverApp-c3083313915]   .col[_ngcontent-serverApp-c3083313915], .b-vacancy[_ngcontent-serverApp-c3083313915]   .col-md-10[_ngcontent-serverApp-c3083313915], .b-vacancy[_ngcontent-serverApp-c3083313915]   .col-12[_ngcontent-serverApp-c3083313915], .b-vacancy[_ngcontent-serverApp-c3083313915]   .col-md-8[_ngcontent-serverApp-c3083313915], .b-vacancy[_ngcontent-serverApp-c3083313915]   .col-sm-12[_ngcontent-serverApp-c3083313915], .b-vacancy[_ngcontent-serverApp-c3083313915]   .col-3[_ngcontent-serverApp-c3083313915], .b-vacancy[_ngcontent-serverApp-c3083313915]   .col-md-9[_ngcontent-serverApp-c3083313915]{padding:0 20px}.b-vacancy-v2[_ngcontent-serverApp-c3083313915]{font-family:Inter,sans-serif;font-weight:400;font-size:15px;line-height:24px;letter-spacing:-.24px;margin-top:-12px}.b-vacancy-v2[_ngcontent-serverApp-c3083313915]   .b-header[_ngcontent-serverApp-c3083313915]   h1[_ngcontent-serverApp-c3083313915]{font-family:Montserrat;font-size:36px;line-height:44px;font-weight:600;margin:24px 0 0;padding:0;color:#0c2231}.b-vacancy-v2[_ngcontent-serverApp-c3083313915]   .b-header[_ngcontent-serverApp-c3083313915]   h2[_ngcontent-serverApp-c3083313915]{font-family:Montserrat;font-size:24px;line-height:32px;font-weight:600;margin:4px 0 0;padding:0;color:#0c2231}.b-vacancy-v2[_ngcontent-serverApp-c3083313915]   .b-header[_ngcontent-serverApp-c3083313915]   h3[_ngcontent-serverApp-c3083313915]{font-family:Montserrat;font-weight:600;font-size:18px;line-height:24px;margin:16px 0 0;padding:0;color:#0c2231}.b-vacancy-v2[_ngcontent-serverApp-c3083313915]   .b-header[_ngcontent-serverApp-c3083313915]   h3[_ngcontent-serverApp-c3083313915]   img[_ngcontent-serverApp-c3083313915]{filter:brightness(0) saturate(100%) invert(46%) sepia(9%) saturate(283%) hue-rotate(158deg) brightness(95%) contrast(90%)}.b-vacancy-v2[_ngcontent-serverApp-c3083313915]   .b-back[_ngcontent-serverApp-c3083313915]{font-family:Inter;font-style:normal;font-weight:500;font-size:14px;line-height:18px;letter-spacing:-.24px}.b-vacancy-v2[_ngcontent-serverApp-c3083313915]   .b-back[_ngcontent-serverApp-c3083313915]   img[_ngcontent-serverApp-c3083313915]{display:inline-block}.b-vacancy-v2[_ngcontent-serverApp-c3083313915]   .b-location[_ngcontent-serverApp-c3083313915]{margin:28px 0 0}@media (max-width: 768px){.b-vacancy-v2[_ngcontent-serverApp-c3083313915]   .b-location[_ngcontent-serverApp-c3083313915]{margin:24px 0 0}}.b-vacancy-v2[_ngcontent-serverApp-c3083313915]   .b-specs[_ngcontent-serverApp-c3083313915]{margin:24px 0 0}@media (max-width: 768px){.b-vacancy-v2[_ngcontent-serverApp-c3083313915]   .b-specs[_ngcontent-serverApp-c3083313915]{margin:20px 0 0}}.b-vacancy-v2[_ngcontent-serverApp-c3083313915]   .b-specs[_ngcontent-serverApp-c3083313915]   .b-term[_ngcontent-serverApp-c3083313915]{max-width:125px;font-size:14px;line-height:18px;color:#6c7377}.b-vacancy-v2[_ngcontent-serverApp-c3083313915]   .b-specs[_ngcontent-serverApp-c3083313915]   .b-value[_ngcontent-serverApp-c3083313915]{font-size:14px;line-height:18px}.b-vacancy-v2[_ngcontent-serverApp-c3083313915]   .b-specs[_ngcontent-serverApp-c3083313915]   .row[_ngcontent-serverApp-c3083313915]{margin-top:12px}.b-vacancy-v2[_ngcontent-serverApp-c3083313915]   .b-apply-block[_ngcontent-serverApp-c3083313915]{padding:0;margin-top:36px;gap:8px}@media (min-width: 768px){.b-vacancy-v2[_ngcontent-serverApp-c30 ...
#   </style>
#   <style ng-app-id="serverApp">
#    .b-footer[_ngcontent-serverApp-c1446189509]{background:#ffffff;border-top:#e3e4e5 1px solid;padding-top:24px}.b-footer[_ngcontent-serverApp-c1446189509]   .b-logotype[_ngcontent-serverApp-c1446189509]{margin:0;display:block;border:none;outline:none;width:134px;height:28px}@media (max-width: 768px){.b-footer[_ngcontent-serverApp-c1446189509]   .b-logotype[_ngcontent-serverApp-c1446189509]{margin-right:auto}}.b-footer[_ngcontent-serverApp-c1446189509]   li[_ngcontent-serverApp-c1446189509]{line-height:21px}.b-footer[_ngcontent-serverApp-c1446189509]   li[_ngcontent-serverApp-c1446189509]   a[_ngcontent-serverApp-c1446189509]{font-size:14px;line-height:18px;letter-spacing:-.24px;font-family:Inter;font-style:normal;font-weight:500}.b-footer-logo[_ngcontent-serverApp-c1446189509]{margin-bottom:24px}.b-footer-logo[_ngcontent-serverApp-c1446189509]   img[_ngcontent-serverApp-c1446189509]{max-height:100%}.b-footer-content[_ngcontent-serverApp-c1446189509]{display:flex;justify-content:space-between;flex-direction:row;flex-wrap:nowrap;margin-bottom:24px}.b-footer-left[_ngcontent-serverApp-c1446189509]{display:flex;flex-direction:row}.b-footer-links[_ngcontent-serverApp-c1446189509]{list-style:none;padding:0}.b-footer-links[_ngcontent-serverApp-c1446189509]   li[_ngcontent-serverApp-c1446189509]{margin-bottom:16px}.b-footer-links[_ngcontent-serverApp-c1446189509]   li[_ngcontent-serverApp-c1446189509]:last-of-type{margin:0}.b-footer-links[_ngcontent-serverApp-c1446189509]   a[_ngcontent-serverApp-c1446189509]:hover{color:#205aed}.b-footer-links[_ngcontent-serverApp-c1446189509]:nth-child(2){margin-left:48px}.b-footer-right[_ngcontent-serverApp-c1446189509]{max-width:220px}.b-footer-right[_ngcontent-serverApp-c1446189509]   h6[_ngcontent-serverApp-c1446189509]{font-size:14px;line-height:18px;letter-spacing:-.24px;font-family:Inter;font-style:normal;font-weight:600;margin-bottom:8px;color:#0c2231}.b-footer-right[_ngcontent-serverApp-c1446189509]   p[_ngcontent-serverApp-c1446189509]{font-size:14px;line-height:18px;letter-spacing:-.24px;font-family:Inter;font-style:normal;font-weight:500;margin-bottom:8px;color:#0c2231}.b-footer-contacts[_ngcontent-serverApp-c1446189509]{list-style:none;padding:0}.b-footer-contacts[_ngcontent-serverApp-c1446189509]   li[_ngcontent-serverApp-c1446189509]{margin-bottom:8px}.b-footer-contacts[_ngcontent-serverApp-c1446189509]   li[_ngcontent-serverApp-c1446189509]   a[_ngcontent-serverApp-c1446189509]{display:flex;align-items:center}.b-footer-contacts[_ngcontent-serverApp-c1446189509]   li[_ngcontent-serverApp-c1446189509]   a[_ngcontent-serverApp-c1446189509]   img[_ngcontent-serverApp-c1446189509]{max-width:20px;filter:brightness(0) saturate(100%) invert(23%) sepia(92%) saturate(3258%) hue-rotate(222deg) brightness(96%) contrast(93%)}.b-footer-contacts[_ngcontent-serverApp-c1446189509]   li[_ngcontent-serverApp-c1446189509]   a[_ngcontent-serverApp-c1446189509]   span[_ngcontent-serverApp-c1446189509]{margin-left:8px}.b-footer-contacts[_ngcontent-serverApp-c1446189509]   li[_ngcontent-serverApp-c1446189509]   a[_ngcontent-serverApp-c1446189509]:hover{color:#205aed}.b-footer-social[_ngcontent-serverApp-c1446189509]{margin-top:16px;display:flex;flex-direction:row;flex-wrap:nowrap;gap:8px}.b-footer-social-item[_ngcontent-serverApp-c1446189509]{display:flex;justify-content:center;align-items:center;border:#9ca2a6 1px solid;background:none;height:30px;width:30px;border-radius:6px;transition:border .2s ease-in-out,background .2s ease-in-out}.b-footer-social-item[_ngcontent-serverApp-c1446189509]   img[_ngcontent-serverApp-c1446189509]{filter:brightness(0) saturate(100%) invert(74%) sepia(7%) saturate(224%) hue-rotate(161deg) brightness(87%) contrast(88%)}.b-footer-social-item[_ngcontent-serverApp-c1446189509]:hover{border:#ffe953 1px solid;background:#ffe953}.b-footer-social-item[_ngcontent-serverApp-c1446189509]:hover   img[_ngcontent-serverApp-c1446189509]{filter:brightness(0) saturate(100%) invert(10%) sepia ...
#   </style>
#   <style ng-app-id="serverApp">
#    .b-mobile-menu[_ngcontent-serverApp-c1098070990]{position:fixed;top:0;left:0;width:100%;height:100%;transition:left .2s;z-index:2147483010}.b-mobile-menu.hidden[_ngcontent-serverApp-c1098070990]{left:-100%}.b-mobile-menu-content-wrapper[_ngcontent-serverApp-c1098070990]{background:#ffffff;min-height:100%;position:relative}.b-mobile-menu-close[_ngcontent-serverApp-c1098070990]{width:45px;height:45px;position:absolute;top:0;right:0;padding:19px 15px 15px;z-index:50}.b-mobile-menu-close[_ngcontent-serverApp-c1098070990]   img[_ngcontent-serverApp-c1098070990]{width:15px;height:15px;object-fit:contain}.b-mobile-menu-content[_ngcontent-serverApp-c1098070990]{display:flex;flex-direction:column;padding:20px;position:absolute;align-content:space-between;min-height:100%;width:100%}.b-mobile-menu-content[_ngcontent-serverApp-c1098070990]   .b-logotype[_ngcontent-serverApp-c1098070990]{margin:0}.b-mobile-menu[_ngcontent-serverApp-c1098070990]   .b-logotype[_ngcontent-serverApp-c1098070990]{display:block;border:none;outline:none;width:134px;height:28px}.b-mobile-menu[_ngcontent-serverApp-c1098070990]   .b-logotype[_ngcontent-serverApp-c1098070990]   img[_ngcontent-serverApp-c1098070990]{width:134px;height:28px}@media (max-width: 768px){.b-mobile-menu[_ngcontent-serverApp-c1098070990]   .b-logotype[_ngcontent-serverApp-c1098070990]{margin-right:auto}}.b-mobile-menu[_ngcontent-serverApp-c1098070990]   ul[_ngcontent-serverApp-c1098070990]{list-style:none;padding:0;margin:36px 0 0;flex:500}.b-mobile-menu[_ngcontent-serverApp-c1098070990]   ul[_ngcontent-serverApp-c1098070990]   li[_ngcontent-serverApp-c1098070990]{list-style:none;margin:0;padding:20px 0}.b-mobile-menu[_ngcontent-serverApp-c1098070990]   ul[_ngcontent-serverApp-c1098070990]   li[_ngcontent-serverApp-c1098070990]   a[_ngcontent-serverApp-c1098070990]{font-family:Montserrat;font-style:normal;font-weight:500;font-size:15px;line-height:18.29px;letter-spacing:-.24px;padding:0;text-decoration:none;color:#0c2231;border-radius:100px;transition:background .5s}.b-mobile-menu[_ngcontent-serverApp-c1098070990]   ul[_ngcontent-serverApp-c1098070990]   li[_ngcontent-serverApp-c1098070990]   a[_ngcontent-serverApp-c1098070990]:focus, .b-mobile-menu[_ngcontent-serverApp-c1098070990]   ul[_ngcontent-serverApp-c1098070990]   li[_ngcontent-serverApp-c1098070990]   a[_ngcontent-serverApp-c1098070990]:active{background:none}.b-mobile-menu[_ngcontent-serverApp-c1098070990]   ul[_ngcontent-serverApp-c1098070990]   li[_ngcontent-serverApp-c1098070990]   a[_ngcontent-serverApp-c1098070990]:hover{background:none}.b-mobile-menu-footer[_ngcontent-serverApp-c1098070990]{flex:1}.b-mobile-menu-backdrop[_ngcontent-serverApp-c1098070990]{position:fixed;inset:0;background:rgba(0,0,0,.35);backdrop-filter:blur(4px);-o-backdrop-filter:blur(4px);-ms-backdrop-filter:blur(4px);-moz-backdrop-filter:blur(4px);-webkit-backdrop-filter:blur(4px);z-index:2147483009;display:flex;flex-direction:column;justify-content:space-between;transition:opacity .35s;opacity:1}.b-mobile-menu-backdrop.hidden[_ngcontent-serverApp-c1098070990]{opacity:0;left:-999999999px;right:999999999px}
#   </style>
#   <style ng-app-id="serverApp">
#    .b-similar-vacancies__header[_ngcontent-serverApp-c3647274225]{font-size:24px;line-height:32px;letter-spacing:normal;font-family:Montserrat;font-style:normal;font-weight:700;color:#0c2231}.b-similar-vacancies__list[_ngcontent-serverApp-c3647274225]{margin-top:36px}@media (max-width: 768px){.b-similar-vacancies__list[_ngcontent-serverApp-c3647274225]{margin-top:36px}}.b-similar-vacancies__more-link[_ngcontent-serverApp-c3647274225]{font-size:15px;line-height:20px;letter-spacing:normal;display:inline-block;font-weight:600;color:#205aed}.b-similar-vacancies__more-link[_ngcontent-serverApp-c3647274225]:hover{text-decoration:underline}.b-similar-vacancies__more-link[_ngcontent-serverApp-c3647274225]   img[_ngcontent-serverApp-c3647274225]{display:inline-block}
#   </style>
#   <link href="https://getmatch.ru/vacancies/26158-affiliate-manager" rel="canonical"/>
#   <meta content="getmatch.ru" name="og:site_name"/>
#   <meta content="Вакансия Affiliate Manager, работа в Winline, в Москве — getmatch" name="og:title"/>
#   <meta content="Вакансия Affiliate Manager, работа в компании Winline, Москва (офис или гибрид). Зарплата: 150 000 — 200 000 ₽/мес на руки. Дата публикации: 05.03.2025." name="og:description"/>
#   <meta content="Вакансия Affiliate Manager, работа в компании Winline, Москва (офис или гибрид). Зарплата: 150 000 — 200 000 ₽/мес на руки. Дата публикации: 05.03.2025." name="description"/>
#   <meta content="summary_large_image" name="twitter:card"/>
#   <meta content="https://getmatch.ru/uploads/telegram_pictures/da76057e-e921-4eb9-a6e2-8c5d044c40ce.png" name="twitter:image"/>
#   <meta content="https://getmatch.ru/uploads/telegram_pictures/da76057e-e921-4eb9-a6e2-8c5d044c40ce.png" name="og:image"/>
#   <meta content="1562" name="og:image:width"/>
#   <meta content="921" name="og:image:height"/>
#   <script class="structured-data-breadcrumbs" type="application/ld+json">
#    {"@context":"https://schema.org","@type":"BreadcrumbList","itemListElement":[{"@type":"ListItem","position":1,"item":{"@id":"https://getmatch.ru/vacancies","name":"Все вакансии"}},{"@type":"ListItem","position":2,"item":{"@id":"https://getmatch.ru/vacancies/product_analyst","name":"Product Analyst"}},{"@type":"ListItem","position":3,"item":{"@id":"https://getmatch.ru/vacancies/product_analyst/moscow","name":"Москва"}},{"@type":"ListItem","position":4,"item":{"@id":"https://getmatch.ru/vacancies/product_analyst/moscow/middle","name":"Middle"}}]}
#   </script>
#   <script class="structured-data-job-posting" type="application/ld+json">
#    {"@context":"https://schema.org/","@type":"JobPosting","title":"Affiliate Manager","hiringOrganization":{"@type":"Organization","name":"Winline","logo":"https://getmatch.ru/uploads/companies_logos/8a5c52e8-043a-4d01-9e44-10550b36361f.png"},"baseSalary":{"@type":"MonetaryAmount","currency":"RUB","value":{"@type":"QuantitativeValue","unitText":"MONTH","minValue":150000,"maxValue":200000}},"employmentType":"FULL_TIME","salaryCurrency":"RUB","datePosted":"2025-03-05","description":"Вакансия Affiliate Manager, работа в компании Winline, Москва (офис или гибрид). Зарплата: 150 000 — 200 000 ₽/мес на руки. Дата публикации: 05.03.2025.","jobLocation":[{"@type":"Place","address":{"@type":"PostalAddress","addressCountry":"RU","addressLocality":"Москва, Россия"}}]}
#   </script>
#   <style ng-app-id="serverApp">
#    [_nghost-serverApp-c3967332199]{display:block}.b-seo-links[_ngcontent-serverApp-c3967332199]{display:flex;flex-direction:column}.b-seo-links__column[_ngcontent-serverApp-c3967332199]{display:flex;flex-direction:column;margin-bottom:24px;flex-shrink:0}.b-seo-links__column[_ngcontent-serverApp-c3967332199]:last-of-type{margin:0}.b-seo-links__title[_ngcontent-serverApp-c3967332199]{font-family:Montserrat;font-style:normal;font-weight:700;font-size:18px;line-height:24px;letter-spacing:normal;color:#0c2231;margin-bottom:8px}.b-seo-links__item[_ngcontent-serverApp-c3967332199]{font-family:Inter;font-style:normal;font-weight:400;font-size:14px;line-height:18px;letter-spacing:normal;color:#205aed;margin-bottom:8px;width:-moz-fit-content;width:fit-content}.b-seo-links__item[_ngcontent-serverApp-c3967332199]:last-of-type{margin:0}@media (min-width: 768px){.b-seo-links[_ngcontent-serverApp-c3967332199]{flex-direction:row}.b-seo-links__column[_ngcontent-serverApp-c3967332199]{margin:0 32px 0 0;max-width:205px}.b-seo-links__item[_ngcontent-serverApp-c3967332199]{margin-bottom:4px}}@media (min-width: 1024px){.b-seo-links__column[_ngcontent-serverApp-c3967332199]{margin:0 72px 0 0;max-width:285px}}
#   </style>
#   <style ng-app-id="serverApp">
#    @charset "UTF-8";[_nghost-serverApp-c2668210061]{display:block;line-height:18px}.b-breadcrumbs[_ngcontent-serverApp-c2668210061]{display:block;line-height:18px}.b-breadcrumbs__item[_ngcontent-serverApp-c2668210061]{display:inline-block;padding:0 8px 0 0}.b-breadcrumbs__item[_ngcontent-serverApp-c2668210061]:before{content:"\2022";font-family:Inter;font-style:normal;font-weight:400;font-size:14px;line-height:18px;letter-spacing:normal;color:#9ca2a6;padding:0 8px 0 0}.b-breadcrumbs__item[_ngcontent-serverApp-c2668210061]:nth-child(1):before{display:none}.b-breadcrumbs__item-link[_ngcontent-serverApp-c2668210061]{color:#205aed;font-family:Inter;font-style:normal;font-weight:400;font-size:14px;line-height:18px;letter-spacing:normal}
#   </style>
#   <style ng-app-id="serverApp">
#    .b-vacancy-locations[_ngcontent-serverApp-c2595184480]{display:flex;flex-wrap:wrap;gap:4px}.b-vacancy-locations--first[_ngcontent-serverApp-c2595184480]{padding-left:8px}.b-vacancy-locations[_ngcontent-serverApp-c2595184480]   .g-label[_ngcontent-serverApp-c2595184480]{white-space:nowrap;overflow:hidden;text-overflow:ellipsis}.b-odo[_ngcontent-serverApp-c2595184480]   .g-label[_ngcontent-serverApp-c2595184480]{color:#0c2231;background-color:#fff}
#   </style>
#   <style ng-app-id="serverApp">
#    .b-share[_ngcontent-serverApp-c391075571]{position:relative}.b-share__button[_ngcontent-serverApp-c391075571]{display:inline-block}.b-share__button[_ngcontent-serverApp-c391075571]:after{display:none}.b-share[_ngcontent-serverApp-c391075571]   .dropdown-menu[_ngcontent-serverApp-c391075571]{z-index:1000;float:none;min-width:0;padding:0;margin:0;background:none;border:none;border-radius:0;box-shadow:none}.b-share[_ngcontent-serverApp-c391075571]   .dropdown-menu[x-placement^=top][_ngcontent-serverApp-c391075571]   .b-share__dropdown[_ngcontent-serverApp-c391075571]{margin-bottom:12px}.b-share[_ngcontent-serverApp-c391075571]   .dropdown-menu[x-placement^=bottom][_ngcontent-serverApp-c391075571]   .b-share__dropdown[_ngcontent-serverApp-c391075571]{margin-top:12px}.b-share__dropdown[_ngcontent-serverApp-c391075571]{background:#ffffff;padding:24px 24px 32px;max-width:420px;box-shadow:0 8px 20px #0000001a;border-radius:12px;border:1px solid #e3e4e5}.b-share__dropdown-title[_ngcontent-serverApp-c391075571]{color:#0c2231;margin-bottom:16px}.b-share__dropdown-buttons[_ngcontent-serverApp-c391075571]{display:flex;margin:0 0 8px}.b-share__dropdown-buttons-item[_ngcontent-serverApp-c391075571]{padding:10px;flex:1;margin:0 8px 0 0;width:181px}.b-share__dropdown-buttons-item[_ngcontent-serverApp-c391075571]:last-of-type{margin:0}.b-share__dropdown-link[_ngcontent-serverApp-c391075571]{display:flex;flex-wrap:nowrap;margin-top:16px}.b-share__dropdown-link-input[_ngcontent-serverApp-c391075571]{background:#eff2f3;border:none;outline:none;box-sizing:border-box;border-radius:6px;width:100%;padding:9px 12px;cursor:pointer;transition:background-color .2s;white-space:nowrap;overflow:hidden;text-overflow:ellipsis;font-family:Inter;font-style:normal;font-weight:400;font-size:15px;line-height:24px;letter-spacing:-.24px;color:#0c2231}.b-share__dropdown-link-input[_ngcontent-serverApp-c391075571]:hover{background-color:#e3e4e5}.b-share__dropdown-link[_ngcontent-serverApp-c391075571]   .g-btn-icon[_ngcontent-serverApp-c391075571]{padding:10px;margin-left:8px}.b-share__dropdown-link[_ngcontent-serverApp-c391075571]   .g-btn-icon[_ngcontent-serverApp-c391075571]   .icon[_ngcontent-serverApp-c391075571]{width:20px;height:20px}
#   </style>
#   <style ng-app-id="serverApp">
#    .b-similar-vacancy[_ngcontent-serverApp-c3944807383]{padding-bottom:20px;margin-bottom:20px}.b-similar-vacancy[_ngcontent-serverApp-c3944807383]   a[_ngcontent-serverApp-c3944807383]{text-decoration:none}.b-similar-vacancy__title[_ngcontent-serverApp-c3944807383]   h3[_ngcontent-serverApp-c3944807383]{font-size:15px;line-height:20px;letter-spacing:normal;margin:0;display:inline-block;color:#205aed}.b-similar-vacancy__title[_ngcontent-serverApp-c3944807383]   h3[_ngcontent-serverApp-c3944807383]:hover{text-decoration:underline}.b-similar-vacancy__logo[_ngcontent-serverApp-c3944807383]{display:flex;height:42px;max-height:42px;max-width:80px;align-items:center}.b-similar-vacancy__logo[_ngcontent-serverApp-c3944807383]   img[_ngcontent-serverApp-c3944807383]{max-width:100%;max-height:100%;margin-left:auto;margin-right:auto}@media (max-width: 768px){.b-similar-vacancy__logo[_ngcontent-serverApp-c3944807383]{max-height:60px}}.b-similar-vacancy__salary[_ngcontent-serverApp-c3944807383], .b-similar-vacancy__location[_ngcontent-serverApp-c3944807383]{font-family:Inter;font-style:normal;font-weight:400;font-size:14px;line-height:18px;letter-spacing:normal;color:#0c2231;margin-top:4px}.b-similar-vacancy--delimiter[_ngcontent-serverApp-c3944807383]{border-bottom:solid 1px #e3e4e5}
#   </style>
#  </head>
#  <body>
#   <div class="zeropixel">
#    <!-- Rating Mail.ru counter -->
#    <script type="text/javascript">
#     var _tmr = window._tmr || (window._tmr = []);
#         (function (d, w, id) {
#           if (d.getElementById(id)) return;
#           var ts = d.createElement('script');
#           ts.type = 'text/javascript';
#           ts.async = true;
#           ts.id = id;
#           ts.src = 'https://top-fwz1.mail.ru/js/code.js';
#           var f = function () {
#             var s = d.getElementsByTagName('script')[0];
#             s.parentNode.insertBefore(ts, s);
#           };
#           if (w.opera == '[object Opera]') {
#             d.addEventListener('DOMContentLoaded', f, false);
#           } else {
#             f();
#           }
#         })(document, window, 'topmailru-code');
#    </script>
#    <noscript>
#     <div>
#      <img alt="Top.Mail.Ru" src="https://top-fwz1.mail.ru/counter?id=3253566;js=na" style="border: 0; position: absolute; left: -9999px"/>
#     </div>
#    </noscript>
#    <!-- /Rating Mail.ru counter -->
#    <!--LiveInternet counter-->
#    <script>
#     new Image().src =
#           'https://counter.yadro.ru/hit?r' +
#           escape(document.referrer) +
#           (typeof screen == 'undefined'
#             ? ''
#             : ';s' +
#               screen.width +
#               '*' +
#               screen.height +
#               '*' +
#               (screen.colorDepth ? screen.colorDepth : screen.pixelDepth)) +
#           ';u' +
#           escape(document.URL) +
#           ';h' +
#           escape(document.title.substring(0, 150)) +
#           ';' +
#           Math.random();
#    </script>
#    <!--/LiveInternet-->
#    <!-- Top100 (Kraken) Counter -->
#    <script>
#     (function (w, d, c) {
#           (w[c] = w[c] || []).push(function () {
#             var options = {
#               project: 7670794,
#               manualControl: true,
#             };
#             try {
#               w.top100Counter = new top100(options);
#             } catch (e) {}
#           });
#           var n = d.getElementsByTagName('script')[0],
#             s = d.createElement('script'),
#             f = function () {
#               n.parentNode.insertBefore(s, n);
#             };
#           s.type = 'text/javascript';
#           s.async = true;
#           s.src =
#             (d.location.protocol == 'https:' ? 'https:' : 'http:') +
#             '//st.top100.ru/top100/top100.js';
#
#           if (w.opera == '[object Opera]') {
#             d.addEventListener('DOMContentLoaded', f, false);
#           } else {
#             f();
#           }
#         })(window, document, '_top100q');
#    </script>
#    <noscript>
#     <img alt="Топ-100" src="//counter.rambler.ru/top100.cnt?pid=7670794"/>
#    </noscript>
#    <!-- END Top100 (Kraken) Counter -->
#   </div>
#   <app-root ng-server-context="ssr" ng-version="16.2.9">
#    <router-outlet>
#    </router-outlet>
#    <app-container _nghost-serverapp-c1263125476="">
#     <app-header _ngcontent-serverapp-c1263125476="" _nghost-serverapp-c708908426="">
#      <header _ngcontent-serverapp-c708908426="" class="b-header b-header--anonymous">
#       <div _ngcontent-serverapp-c708908426="" class="container">
#        <a _ngcontent-serverapp-c708908426="" class="b-header__logotype" href="/">
#        </a>
#        <nav _ngcontent-serverapp-c708908426="" class="b-header__navigation">
#         <a _ngcontent-serverapp-c708908426="" class="b-header__navigation-link b-header__navigation-link--active" href="/vacancies?s=menu" routerlink="/vacancies">
#          Вакансии
#         </a>
#         <!-- -->
#         <!-- -->
#         <!-- -->
#         <a _ngcontent-serverapp-c708908426="" class="b-header__navigation-link" href="/salaries?s=menu" routerlink="/salaries">
#          Зарплаты
#         </a>
#        </nav>
#        <div _ngcontent-serverapp-c708908426="" class="b-header__buttons">
#         <!-- -->
#         <!-- -->
#         <!-- -->
#         <!-- -->
#         <button _ngcontent-serverapp-c708908426="" class="g-btn g-btn-primary b-header__buttons-telegram">
#          <img _ngcontent-serverapp-c708908426="" class="icon" src="/static/img/icons/icon-telegram-white.svg"/>
#          <span _ngcontent-serverapp-c708908426="">
#           Добавить в Telegram
#          </span>
#         </button>
#         <!-- -->
#         <button _ngcontent-serverapp-c708908426="" class="g-btn g-btn-secondary b-header__buttons-login" id="loginButton">
#          Вход
#         </button>
#         <!-- -->
#        </div>
#        <!-- -->
#        <!-- -->
#        <div _ngcontent-serverapp-c708908426="" class="b-header__mobile-menu">
#         <img _ngcontent-serverapp-c708908426="" src="/static/img/icons/icon-menu-black.svg"/>
#        </div>
#        <app-menu-mobile-candidate _ngcontent-serverapp-c708908426="" _nghost-serverapp-c1098070990="">
#         <!-- -->
#        </app-menu-mobile-candidate>
#        <!-- -->
#        <!-- -->
#        <!-- -->
#        <!-- -->
#       </div>
#      </header>
#     </app-header>
#     <!-- -->
#     <!-- -->
#     <!-- -->
#     <div _ngcontent-serverapp-c1263125476="" class="page-container page-container--anonymous">
#      <router-outlet _ngcontent-serverapp-c1263125476="">
#      </router-outlet>
#      <app-vacancy _nghost-serverapp-c3083313915="">
#       <div _ngcontent-serverapp-c3083313915="" class="b-vacancy">
#        <!-- -->
#        <!-- -->
#        <section _ngcontent-serverapp-c3083313915="" class="container b-vacancy-v2">
#         <!-- -->
#         <!-- -->
#         <!-- -->
#         <!-- -->
#         <!-- -->
#         <div _ngcontent-serverapp-c3083313915="" class="row">
#          <div _ngcontent-serverapp-c3083313915="" class="col-12 d-md-none">
#           <div _ngcontent-serverapp-c3083313915="" class="b-company-logotype-container">
#            <div _ngcontent-serverapp-c3083313915="" class="b-company-logotype">
#             <img _ngcontent-serverapp-c3083313915="" alt="Winline" src="/uploads/companies_logos/8a5c52e8-043a-4d01-9e44-10550b36361f.png"/>
#            </div>
#           </div>
#           <!-- -->
#          </div>
#          <div _ngcontent-serverapp-c3083313915="" class="col-md-8 col-sm-12">
#           <section _ngcontent-serverapp-c3083313915="" class="b-header">
#            <app-breadcrumbs _ngcontent-serverapp-c3083313915="" _nghost-serverapp-c2668210061="" class="b-vacancy__breadcrumbs" source="vacancy_breadcrumbs">
#             <div _ngcontent-serverapp-c2668210061="" class="b-breadcrumbs">
#              <span _ngcontent-serverapp-c2668210061="" class="b-breadcrumbs__item">
#               <a _ngcontent-serverapp-c2668210061="" class="b-breadcrumbs__item-link" href="/vacancies?s=vacancy_breadcrumbs">
#                Все вакансии
#               </a>
#               <!-- -->
#               <!-- -->
#              </span>
#              <span _ngcontent-serverapp-c2668210061="" class="b-breadcrumbs__item">
#               <a _ngcontent-serverapp-c2668210061="" class="b-breadcrumbs__item-link" href="/vacancies/product_analyst?s=vacancy_breadcrumbs">
#                Product Analyst
#               </a>
#               <!-- -->
#               <!-- -->
#              </span>
#              <span _ngcontent-serverapp-c2668210061="" class="b-breadcrumbs__item">
#               <a _ngcontent-serverapp-c2668210061="" class="b-breadcrumbs__item-link" href="/vacancies/product_analyst/moscow?s=vacancy_breadcrumbs">
#                Москва
#               </a>
#               <!-- -->
#               <!-- -->
#              </span>
#              <span _ngcontent-serverapp-c2668210061="" class="b-breadcrumbs__item">
#               <a _ngcontent-serverapp-c2668210061="" class="b-breadcrumbs__item-link" href="/vacancies/product_analyst/moscow/middle?s=vacancy_breadcrumbs">
#                Middle
#               </a>
#               <!-- -->
#               <!-- -->
#              </span>
#              <!-- -->
#             </div>
#            </app-breadcrumbs>
#            <!-- -->
#            <h1 _ngcontent-serverapp-c3083313915="">
#             Affiliate Manager
#            </h1>
#            <h2 _ngcontent-serverapp-c3083313915="">
#             в
#             <a _ngcontent-serverapp-c3083313915="" href="/companies/bxlV9dQ5-winline?s=vacancy" target="_blank">
#              Winline
#             </a>
# ...
#           <div _ngcontent-serverapp-c3967332199="" class="b-seo-links">
#            <div _ngcontent-serverapp-c3967332199="" class="b-seo-links__column">
#             <h3 _ngcontent-serverapp-c3967332199="" class="b-seo-links__title">
#              Больше вакансий
#             </h3>
#             <a _ngcontent-serverapp-c3967332199="" class="b-seo-links__item" href="/vacancies/product_analyst/regions/senior?s=vacancy_seo_links_more_vacancies">
#              Senior Product Analyst`ов в регионах РФ
#             </a>
#             <a _ngcontent-serverapp-c3967332199="" class="b-seo-links__item" href="/vacancies/product_analyst/remote?s=vacancy_seo_links_more_vacancies">
#              Product Analyst`ов удалённо
#             </a>
#             <a _ngcontent-serverapp-c3967332199="" class="b-seo-links__item" href="/vacancies/product_management/russia?s=vacancy_seo_links_more_vacancies">
#              Product Manager’ов в России
#             </a>
#             <a _ngcontent-serverapp-c3967332199="" class="b-seo-links__item" href="/vacancies/product_analyst/spb/senior?s=vacancy_seo_links_more_vacancies">
#              Senior Product Analyst`ов в Санкт-Петербурге
#             </a>
#             <a _ngcontent-serverapp-c3967332199="" class="b-seo-links__item" href="/vacancies/project_management/senior?s=vacancy_seo_links_more_vacancies">
#              Senior Project Manager`ов
#             </a>
#             <a _ngcontent-serverapp-c3967332199="" class="b-seo-links__item" href="/vacancies/product_analyst/moscow/middle?s=vacancy_seo_links_more_vacancies">
#              Middle Product Analyst`ов в Москве
#             </a>
#             <!-- -->
#            </div>
#            <div _ngcontent-serverapp-c3967332199="" class="b-seo-links__column">
#             <h3 _ngcontent-serverapp-c3967332199="" class="b-seo-links__title">
#              Похожие вакансии
#             </h3>
#             <a _ngcontent-serverapp-c3967332199="" class="b-seo-links__item" href="/vacancies/spb?s=vacancy_seo_links_similar_vacancies">
#              В Санкт-Петербурге
#             </a>
#             <a _ngcontent-serverapp-c3967332199="" class="b-seo-links__item" href="/vacancies/product_management/senior?s=vacancy_seo_links_similar_vacancies">
#              Senior Product Manager’ов
#             </a>
#             <a _ngcontent-serverapp-c3967332199="" class="b-seo-links__item" href="/vacancies/product_analyst/remote/lead?s=vacancy_seo_links_similar_vacancies">
#              Lead Product Analyst`ов удалённо
#             </a>
#             <a _ngcontent-serverapp-c3967332199="" class="b-seo-links__item" href="/vacancies/product_analyst/spb?s=vacancy_seo_links_similar_vacancies">
#              Product Analyst`ов в Санкт-Петербурге
#             </a>
#             <a _ngcontent-serverapp-c3967332199="" class="b-seo-links__item" href="/vacancies/product_management/russia/senior?s=vacancy_seo_links_similar_vacancies">
#              Senior Product Manager’ов в России
#             </a>
#             <a _ngcontent-serverapp-c3967332199="" class="b-seo-links__item" href="/vacancies/product_management/moscow/lead?s=vacancy_seo_links_similar_vacancies">
#              Lead Product Manager’ов в Москве
#             </a>
#             <!-- -->
#            </div>
#            <div _ngcontent-serverapp-c3967332199="" class="b-seo-links__column">
#             <h3 _ngcontent-serverapp-c3967332199="" class="b-seo-links__title">
#              Зарплаты
#             </h3>
#             <a _ngcontent-serverapp-c3967332199="" class="b-seo-links__item" href="/salaries/%5Bobject%20Object%5D?s=vacancy_seo_links_salaries">
#              Project Manager`ов
#             </a>
#             <a _ngcontent-serverapp-c3967332199="" class="b-seo-links__item" href="/salaries/%5Bobject%20Object%5D?s=vacancy_seo_links_salaries">
#              Project Manager`ов
#             </a>
#             <a _ngcontent-serverapp-c3967332199="" class="b-seo-links__item" href="/salaries/%5Bobject%20Object%5D?s=vacancy_seo_links_salaries">
#              Product Manager’ов
#             </a>
#             <a _ngcontent-serverapp-c3967332199="" class="b-seo-links__item" href="/salaries/%5Bobject%20Object%5D?s=vacancy_seo_links_salaries">
#              Product Analyst`ов
#             </a>
#             <a _ngcontent-serverapp-c3967332199="" class="b-seo-links__item" href="/salaries/%5Bobject%20Object%5D?s=vacancy_seo_links_salaries">
#              Product Analyst`ов
#             </a>
#             <a _ngcontent-serverapp-c3967332199="" class="b-seo-links__item" href="/salaries/%5Bobject%20Object%5D?s=vacancy_seo_links_salaries">
#              Product Manager’ов
#             </a>
#             <!-- -->
#            </div>
#           </div>
#          </app-seo-links>
#         </div>
#        </section>
#        <!-- -->
#       </div>
#      </app-vacancy>
#      <!-- -->
#     </div>
#     <app-footer _ngcontent-serverapp-c1263125476="" _nghost-serverapp-c1446189509="">
#      <footer _ngcontent-serverapp-c1446189509="" class="b-footer">
#       <div _ngcontent-serverapp-c1446189509="" class="container">
#        <div _ngcontent-serverapp-c1446189509="" class="b-footer-logo">
#         <!-- -->
#         <a _ngcontent-serverapp-c1446189509="" aria-label="Главная" class="b-logotype" href="/?s=footer">
#          <img _ngcontent-serverapp-c1446189509="" src="/static/img/getmatch-logo.svg"/>
#         </a>
#         <!-- -->
#        </div>
#        <div _ngcontent-serverapp-c1446189509="" class="b-footer-content">
#         <div _ngcontent-serverapp-c1446189509="" class="b-footer-left">
#          <ul _ngcontent-serverapp-c1446189509="" class="b-footer-links">
#           <li _ngcontent-serverapp-c1446189509="">
#            <a _ngcontent-serverapp-c1446189509="" href="https://t.me/g_jobbot?start=u_footer__YV9fMTUw" rel="noopener noreferrer nofollow" target="_blank">
#             Телеграм-бот с вакансиями 🤖
#            </a>
#           </li>
#           <li _ngcontent-serverapp-c1446189509="">
#            <a _ngcontent-serverapp-c1446189509="" href="/vacancies?s=footer">
#             Вакансии
#            </a>
#           </li>
#           <li _ngcontent-serverapp-c1446189509="">
#            <a _ngcontent-serverapp-c1446189509="" href="/salaries?s=footer">
#             Зарплаты
#            </a>
#           </li>
#           <li _ngcontent-serverapp-c1446189509="">
#            <a _ngcontent-serverapp-c1446189509="" href="/catalog?s=footer">
#             Каталог
#            </a>
#           </li>
#           <!-- -->
#           <!-- -->
#           <!-- -->
#          </ul>
#          <ul _ngcontent-serverapp-c1446189509="" class="b-footer-links">
#           <!-- -->
#           <li _ngcontent-serverapp-c1446189509="">
#            <a _ngcontent-serverapp-c1446189509="" href="https://getmatch.ru/companies?s=footer" rel="noopener" target="_blank">
#             Работодателям
#            </a>
#           </li>
#           <li _ngcontent-serverapp-c1446189509="">
#            <a _ngcontent-serverapp-c1446189509="" href="https://getmatch.ru/demo/vacancies?s=footer" rel="noopener" target="_blank">
#             Разместить вакансию
#            </a>
#           </li>
#           <li _ngcontent-serverapp-c1446189509="">
#            <a _ngcontent-serverapp-c1446189509="" href="javascript:void(0)">
#             Зарегистрироваться
#            </a>
#           </li>
#           <!-- -->
#           <li _ngcontent-serverapp-c1446189509="">
#            <a _ngcontent-serverapp-c1446189509="" href="javascript:void(0)">
#             Войти
#            </a>
#           </li>
#           <!-- -->
#          </ul>
#          <!-- -->
#         </div>
#         <div _ngcontent-serverapp-c1446189509="" class="b-footer-right">
#          <h6 _ngcontent-serverapp-c1446189509="">
#           Нужна помощь?
#          </h6>
#          <p _ngcontent-serverapp-c1446189509="">
#           Мы на связи по будням с 10:00 до 19:00
#          </p>
#          <ul _ngcontent-serverapp-c1446189509="" class="b-footer-contacts">
#           <li _ngcontent-serverapp-c1446189509="">
#            <a _ngcontent-serverapp-c1446189509="" href="mailto:hello@getmatch.ru" rel="noopener noreferrer nofollow" target="_blank">
#             <img _ngcontent-serverapp-c1446189509="" alt="Иконка почты" src="/static/img/icons/icon-mail-outline-black.svg"/>
#             <span _ngcontent-serverapp-c1446189509="">
#              hello@getmatch.ru
#             </span>
#            </a>
#           </li>
#           <!-- -->
#           <!-- -->
#          </ul>
#          <div _ngcontent-serverapp-c1446189509="" class="b-footer-social">
#           <a _ngcontent-serverapp-c1446189509="" href="https://habr.com/ru/company/getmatch/" rel="noopener noreferrer nofollow" target="_blank">
#            <div _ngcontent-serverapp-c1446189509="" class="b-footer-social-item">
#             <img _ngcontent-serverapp-c1446189509="" alt="habr" src="/static/img/icons/icon-habr-black.svg"/>
#            </div>
#           </a>
#           <a _ngcontent-serverapp-c1446189509="" href="https://www.linkedin.com/company/2253808" rel="noopener noreferrer nofollow" target="_blank">
#            <div _ngcontent-serverapp-c1446189509="" class="b-footer-social-item">
#             <img _ngcontent-serverapp-c1446189509="" alt="lin" src="/static/img/icons/icon-lin-black.svg"/>
#            </div>
#           </a>
#           <a _ngcontent-serverapp-c1446189509="" href="https://twitter.com/getmatch_team" rel="noopener noreferrer nofollow" target="_blank">
#            <div _ngcontent-serverapp-c1446189509="" class="b-footer-social-item">
#             <img _ngcontent-serverapp-c1446189509="" alt="tw" src="/static/img/icons/icon-tw-black.svg"/>
#            </div>
#           </a>
#           <a _ngcontent-serverapp-c1446189509="" href="https://vk.com/getmatch" rel="noopener noreferrer nofollow" target="_blank">
#            <div _ngcontent-serverapp-c1446189509="" class="b-footer-social-item">
#             <img _ngcontent-serverapp-c1446189509="" alt="vk" src="/static/img/icons/icon-vk-black.svg"/>
#            </div>
#           </a>
#           <a _ngcontent-serverapp-c1446189509="" href="https://t.me/g_jobchannel" rel="noopener noreferrer nofollow" target="_blank">
#            <div _ngcontent-serverapp-c1446189509="" class="b-footer-social-item">
#             <img _ngcontent-serverapp-c1446189509="" alt="tg" src="/static/img/icons/icon-tg-black.svg" width="14"/>
#            </div>
#           </a>
#          </div>
#         </div>
#        </div>
#       </div>
#       <div _ngcontent-serverapp-c1446189509="" class="b-footer-bottom">
#        <div _ngcontent-serverapp-c1446189509="" class="container">
#         <p _ngcontent-serverapp-c1446189509="">
#          © 2025 getmatch.ru
#         </p>
#         <div _ngcontent-serverapp-c1446189509="" class="b-footer-bottom-tos">
#          <a _ngcontent-serverapp-c1446189509="" href="https://getmatch.ru/docs/terms-of-service/" target="_blank">
#           Пользовательское соглашение
#          </a>
#          <a _ngcontent-serverapp-c1446189509="" href="https://getmatch.ru/docs/privacy-policy/" target="_blank">
#           Политика обработки персональных данных
#          </a>
#         </div>
#        </div>
#       </div>
#      </footer>
#     </app-footer>
#     <!-- -->
#    </app-container>
#    <!-- -->
#   </app-root>
#   <script crossorigin="anonymous" src="https://code.jquery.com/jquery-3.5.1.min.js">
#   </script>
#   <script crossorigin="anonymous" integrity="sha384-Q6E9RHvbIyZFJoft+2mJbHaEWldlvI9IOYy5n3zV9zzTtmI3UksdQRVvoxMfooAo" src="https://cdn.jsdelivr.net/npm/popper.js@1.16.0/dist/umd/popper.min.js">
#   </script>
#   <script crossorigin="anonymous" integrity="sha384-OgVRvuATP1z7JjHLkuOU7Xw704+h835Lr+6QL9UvYjZE3Ipu6Tp75j7Bh/kR0JKI" src="https://stackpath.bootstrapcdn.com/bootstrap/4.5.0/js/bootstrap.min.js">
#   </script>
#   <script src="/static-ssr/runtime.4c364a204d546d23.js" type="module">
#   </script>
#   <script src="/static-ssr/polyfills.30a98df15192b4b1.js" type="module">
#   </script>
#   <script src="/static-ssr/main.2c0a4405ea7cbb64.js" type="module">
#   </script>
#   <script id="serverApp-state" type="application/json">
#    {"isAnonymous":true,"role":"anonymous","user":null,"G.json.https://getmatch.ru/api/specializations?":{"body":[{"id":13,"name":"JS/Frontend Developer","slug":"js_frontend","morphs":{"form_first":"Frontend-разработчика","form_second":"frontend-разработчикам","plural":"JavaScript разработчики","form_first_plural":"Frontend разработчиков","form5":"Frontend-разработчиков"},"seo_morphs":{"form1":"Frontend разработчик","form2":"Frontend developer","form3":"Фронтенд разработчиком","form4":"Frontend разработчика","form5":"JavaScript"},"category":{"id":5,"slug":"frontend","name":"Frontend"}},{"id":11,"name":"QA Auto","slug":"qa_auto","morphs":{"form_first":"automation QA-инженера","form_second":"automation QA-инженерам","plural":"automation QA-инженеры","form_first_plural":"automation QA тестировщиков","form5":"Automation QA-тестировщиков"},"seo_morphs":{"form1":"QA / Auto","form2":"Automation QA-инженером","form3":"Automation QA-тестировщиком","form4":"QA / Auto","form5":"QA Auto"},"category":{"id":1,"slug":"qa","name":"QA"}},{"id":1,"name":"DevOps","slug":"dev_ops","morphs":{"form_first":"DevOps’а","form_second":"DevOps’ам","plural":"DevOps’ы","form_first_plural":"девопсов","form5":"DevOps’ов"},"seo_morphs":{"form1":"DevOps инженер","form2":"DevOps инженером","form3":"Девопсом","form4":"DevOps инженера","form5":"DevOps"},"category":{"id":10,"slug":"administration_sre","name":"Administration & SRE"}},{"id":25,"name":"Data Engineering","slug":"data_engineering","morphs":{"form_first":"Data Engineer","form_second":"дата-инженерам","plural":"дата инженеры","form_first_plural":"дата инженеров","form5":"Data Engineer’ов"},"seo_morphs":{"form1":"Data Engineer","form2":"дата инженером","form3":"Data Engineer'ом","form4":"Data Engineer'а","form5":"Data Engineer"},"category":{"id":14,"slug":"data_ml","name":"Data & ML"}},{"id":22,"name":"IT HR / Recruiter","slug":"tech_recruitment","morphs":{"form_first":"HR менеджера","form_second":"IT-рекрутерам","plural":"IT-рекрутеры","form_first_plural":"HR managers","form5":"IT-рекрутеров"},"seo_morphs":{"form1":"IT HR","form2":"Рекрутером","form3":"IT HR","form4":"IT HR","form5":"Recruiter"},"category":{"id":15,"slug":"hr_recruitment","name":"HR / Recruitment"}},{"id":12,"name":"Python","slug":"python","morphs":{"form_first":"Python-разработчика","form_second":"Python-разработчикам","plural":"Python-разработчики","form_first_plural":"разработчиков на Питоне","form5":"Python-разработчиков"},"seo_morphs":{"form1":"Python разработчик","form2":"Python developer","form3":"Python разработчиком","form4":"Python разработчика","form5":"Python"},"category":{"id":4,"slug":"backend","name":"Backend"}},{"id":15,"name":"PHP","slug":"php","morphs":{"form_first":"PHP-разработчика","form_second":"PHP-разработчикам","plural":"PHP-разработчики","form_first_plural":"PHP-разработчиков","form5":"PHP-разработчиков"},"seo_morphs":{"form1":"PHP разработчик","form2":"PHP developer","form3":"PHP разработчиком","form4":"PHP разработчика","form5":"PHP"},"category":{"id":4,"slug":"backend","name":"Backend"}},{"id":18,"name":"Java / Scala ","slug":"java_scala","morphs":{"form_first":"Java-разработчика","form_second":"Java-разработчикам","plural":"Java-разработчики","form_first_plural":"Джава разработчиков","form5":"Java-разработчиков"},"seo_morphs":{"form1":"Java разработчик","form2":"Java developer","form3":"Java разработчиком","form4":"Java разработчика","form5":"Java"},"category":{"id":4,"slug":"backend","name":"Backend"}},{"id":4,"name":"C#","slug":"c_sharp","morphs":{"form_first":"С# разработчика","form_second":"С# разработчикам","plural":"С# разработчики","form_first_plural":"С# разработчиков","form5":"С# разработчиков"},"seo_morphs":{"form1":"С# разработчик","form2":"С# developer","form3":"С# разработчиком","form4":"С# разработчика","form5":"С#"},"category":{"id":4,"slug":"backend","name":"Backend"}},{"id":17,"name":"C / C++","slug":"c_cpp","morphs":{"form_first":"C++ разработчика","form_second":"C++ разработчикам","plural": ...
#   </script>
#  </body>
# </html>

# %%
def get_info(soup):
    info = {}

    # название вакансии и компании
    info['title'] = soup.find('h1').text.strip()
    info['company'] = soup.find('h2').find('a').text.strip()

    # зарплата
    salary_container = soup.find(lambda tag: tag.name == 'h3' and any(char in tag.get_text() for char in ['₽', '$', '€']))

    if salary_container:
      info['salary'] = salary_container.text.strip()

    # места и типы работы
    place_container = soup.find('div', {'class': 'b-vacancy-locations'})

    if place_container:
      locations = place_container.find_all('span', {'class': 'g-label-secondary'})

      if locations:
        info['locations'] = [item.text.strip() for item in locations]

      categories = place_container.find_all('span', {'class': 'g-label-zanah'})

      if categories:
          info['categories'] = [item.text.strip() for item in categories]

    # основные условия
    terms_container = soup.find('div', {'class': 'b-specs'})

    if terms_container:
      term_titles = terms_container.find_all('div', {'class': 'b-term'})

      if term_titles:
        terms = {}

        for term_title in term_titles:
          term_value = term_title.find_next('div', {'class': 'b-value'})

          if term_value:
            terms[term_title.text.strip()] = term_value.text.strip()

        info['terms'] = terms

    # стек технологий
    stack_container = soup.find('div', {'class': 'b-vacancy-stack-container'})

    if stack_container:
      stack = stack_container.find_all('span')
      info['stack'] = [item.text.strip() for item in stack]

    # описание
    description_container = soup.find('section', {'class': 'b-vacancy-description'})

    if description_container:
      description_titles = description_container.find_all('h2') + description_container.find_all('h3')

      if description_titles:
        descriptions = {}

        for description_title in description_titles:
          description_list = description_title.find_next('ul')

          if not description_list:
            continue

          description_bullets = description_list.find_all('li')


          if description_bullets:
            description_value = ''

            for description_bullet in description_bullets:
              description_value += description_bullet.text.strip() + ' '

            if len(description_value) != 0:
              description_value = description_value[:-1]
              descriptions[description_title.text.strip()] = description_value

        info['descriptions'] = descriptions

    return info

# %% [markdown]
# Посмотрим, как выглядит получившийся словарь. Все соответсвует ожиданиям :)

# %%
get_info(soup)
# Out:
# {'title': 'Affiliate Manager',
#  'company': 'Winline',
#  'salary': '150 000 —\u200d 200 000 ₽/мес на руки',
#  'locations': ['📍 Москва (м. Шелепиха)'],
#  'categories': ['Офис несколько дней в неделю'],
#  'terms': {'Специализация': 'Product Analyst / Product Manager / Project Manager',
#   'Уровень': 'Middle',
#   'Требуемый опыт': '2+ лет'},
#  'stack': ['Google Analytics', 'Яндекс.Метрика', 'Excel', 'PowerPoint'],
#  'descriptions': {'Обязанности': 'Поддерживать и развивать партнерские отношения с текущими веб-мастерами. Искать новых целевых клиентов. Вести отчетность и анализировать текущий трафик. Контролировать размещение промо-материалов на сайтах СМИ. Проводить сверку и еженедельный контроль партнеров на предмет фрода. Оперативно коммуницировать с партнерами в чатах и по почте. Отслеживать тренды рынка и мониторить конкурентов для оперативного реагирования и изменений.',
#   'Требования': 'Опыт работы в Affiliate-маркетинге на позиции менеджер (от 2 лет). Понимание видов трафика и принципов их работы, как performance, так и brand. Опыт подключения и поиска новых источников трафика. Умение анализировать трафик, понимание принципов работы антифрод-систем. Понимание и принцип работы веб-трафика. Уверенное знание Excel и PowerPoint. Уверенный опыт работы с Google Analytics и Яндекс.Метрикой. Сильные аналитические способности. Развитые коммуникативные навыки, умение презентовать проекты и защищать результаты. Умение работать в команде и проактивность — быть драйвером процессов, а не просто реагировать на запросы.',
#   'Условия': 'Оформление по ТК. График работы: 5/2 в офисе с 11:00 до 19:00. Адрес офиса: Москва, Причальный проезд, 2А. Полный офис без гибрида и удаленки.'}}

# %%
get_match_df = pd.read_csv('get_match_df (1).csv')
get_match_df.drop(columns=["salary_from", "salary_to"], inplace=True)
get_match_df = get_match_df.dropna(subset=["salary"])
get_match_df
# Out:
#                                                   title  \
# 0                      Senior DevOps/DevSecOps Engineer
# 1     Разработчик на Python (Непрерывная интеграция ...
# 2     Ведущий продакт-менеджер экосистемы по взаимод...
# 3        Архитектор продукта (1С: Управление проектами)
# 4                                     Affiliate Manager
# ...                                                 ...
# 1194                                            C++ SWE
# 1195         Менеджер продукта (Международное развитие)
# 1196                                    Аналитик 1С ERP
# 1197                                        Аналитик 1С
# 1199                               Senior C++ Developer
#
#                         company  \
# 0                     Collectly
# 1     Яндекс (Поисковый портал)
# 2                         Avito
# 3                      Гринатом
# 4                       Winline
# ...                         ...
# 1194     Spectral::Technologies
# 1195                      GGSel
# 1196                   Гринатом
# 1197            Sportmaster Lab
# 1199                 MetaQuotes
#
#                                               locations    type  relocation  \
# 0     Бразилия, Сербия, Аргентина, Черногория, Испан...  remote           0
# 1                                                Москва  hybrid           0
# 2                                                Москва  remote           0
# 3                                                Москва  hybrid           0
# 4                                                Москва  hybrid           0
# ...                                                 ...     ...         ...
# 1194                                             Москва  hybrid           0
# 1195                                                NaN  remote           0
# 1196                                                NaN  office           0
# 1197  Москва, Санкт-Петербург, Липецк, Краснодар, Во...  office           0
# 1199                   Москва, Санкт-Петербург, Лимасол  office           1
#
#       relocation_help                                     specialization  \
# 0                   0                      DevOps / Information Security
# 1                   0                                             Python
# 2                   0                                    Product Manager
# 3                   0                                                 1C
# 4                   0  Product Analyst / Product Manager / Project Ma...
# ...               ...                                                ...
# 1194                0                                            С / С++
# 1195                0                                    Product Manager
# 1196                0                                                 1С
# 1197                0                                                 1C
# 1199                1                                                C++
#
#                  level english_level  min_experience  \
# 0               Senior            B2               0
# 1               Middle  Не требуется               3
# 2               Senior  Не требуется               0
# 3               Middle  Не требуется               3
# 4               Middle  Не требуется               2
# ...                ...           ...             ...
# 1194            Middle  Не требуется               2
# 1195            Middle            B2               2
# 1196  Middle-to-Senior  Не требуется               1
# 1197            Middle  Не требуется               3
# 1199            Senior  Не требуется               0
#
#                                                   stack  \
# 0     Ansible, Terraform, CI/CD, AWS/Azure/GCP, Jenk...
# 1                                         Python, CI/CD
# 2                                                   NaN
# 3     1С: Предприятие 8, 1С:PM Управление проектами ...
# 4     Google Analytics, Яндекс.Метрика, Excel, Power...
# ...                                                 ...
# 1194                                         C++, Linux
# 1195                                                NaN
# 1196                                             1С ERP
# 1197  1С:Управление Торговлей 8, 1С:УПП, 1С:ERP, BPM...
# 1199                                                C++
#
#                                             description     salary
# 0     Design, develop, and maintain robust infrastru... 623,000.00
# 1     Стремитесь выбирать хорошие архитектурные реше... 335,000.00
# 2     Разработка и внедрение стратегии развития CRM-... 410,500.00
# 3     Быть единой точкой архитектурных решений за ко... 300,000.00
# 4     Поддерживать и развивать партнерские отношения... 175,000.00
# ...                                                 ...        ...
# 1194  С++ 20 для части системы, принимающей торговые... 350,000.00
# 1195  Поиск Product Market Fit и определение стратег... 200,000.00
# 1196  Проведение обследования, сбор и анализ требова... 200,000.00
# 1197  Сбор, формализация, систематизация и анализ би... 200,000.00
# 1199  Развитие собственного языка MQL5 (входит в рей... 465,000.00
#
# [1137 rows x 13 columns]

# %%
get_match_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1137 entries, 0 to 1199
# Data columns (total 13 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   title            1137 non-null   object
#  1   company          1069 non-null   object
#  2   locations        836 non-null    object
#  3   type             1137 non-null   object
#  4   relocation       1137 non-null   int64
#  5   relocation_help  1137 non-null   int64
#  6   specialization   1137 non-null   object
#  7   level            1137 non-null   object
#  8   english_level    1137 non-null   object
#  9   min_experience   1137 non-null   int64
#  10  stack            1006 non-null   object
#  11  description      1012 non-null   object
#  12  salary           1137 non-null   float64
# dtypes: float64(1), int64(3), object(9)
# memory usage: 124.4+ KB

# %%
plt.figure(figsize=(16, 5))
sns.boxplot(x=get_match_df["salary"])
plt.xlabel("Зарплата (RUB)")
plt.title("Распределение зарплат")
plt.grid(axis="x")

# %%
get_match_df['salary'].describe()
# Out:
# count       1,137.00
# mean      311,184.93
# std       135,044.43
# min        45,000.00
# 25%       225,000.00
# 50%       300,000.00
# 75%       375,000.00
# max     1,023,500.00
# Name: salary, dtype: float64

# %%
# Вычисление границ IQR
Q1, Q3 = get_match_df['salary'].quantile([0.25, 0.75])
IQR = Q3 - Q1
нижняя_граница, верхняя_граница = Q1 - 1.5 * IQR, Q3 + 1.5 * IQR

# Отсеивание выбросов
get_match_df = get_match_df[(get_match_df['salary'] >= нижняя_граница) & (get_match_df['salary'] <= верхняя_граница)]
get_match_df
# Out:
#                                                   title  \
# 1     Разработчик на Python (Непрерывная интеграция ...
# 2     Ведущий продакт-менеджер экосистемы по взаимод...
# 3        Архитектор продукта (1С: Управление проектами)
# 4                                     Affiliate Manager
# 5                   Backend Developer (Support Systems)
# ...                                                 ...
# 1194                                            C++ SWE
# 1195         Менеджер продукта (Международное развитие)
# 1196                                    Аналитик 1С ERP
# 1197                                        Аналитик 1С
# 1199                               Senior C++ Developer
#
#                         company  \
# 1     Яндекс (Поисковый портал)
# 2                         Avito
# 3                      Гринатом
# 4                       Winline
# 5                         Avito
# ...                         ...
# 1194     Spectral::Technologies
# 1195                      GGSel
# 1196                   Гринатом
# 1197            Sportmaster Lab
# 1199                 MetaQuotes
#
#                                               locations    type  relocation  \
# 1                                                Москва  hybrid           0
# 2                                                Москва  remote           0
# 3                                                Москва  hybrid           0
# 4                                                Москва  hybrid           0
# 5                                                   NaN  remote           0
# ...                                                 ...     ...         ...
# 1194                                             Москва  hybrid           0
# 1195                                                NaN  remote           0
# 1196                                                NaN  office           0
# 1197  Москва, Санкт-Петербург, Липецк, Краснодар, Во...  office           0
# 1199                   Москва, Санкт-Петербург, Лимасол  office           1
#
#       relocation_help                                     specialization  \
# 1                   0                                             Python
# 2                   0                                    Product Manager
# 3                   0                                                 1C
# 4                   0  Product Analyst / Product Manager / Project Ma...
# 5                   0                                             Golang
# ...               ...                                                ...
# 1194                0                                            С / С++
# 1195                0                                    Product Manager
# 1196                0                                                 1С
# 1197                0                                                 1C
# 1199                1                                                C++
#
#                  level english_level  min_experience  \
# 1               Middle  Не требуется               3
# 2               Senior  Не требуется               0
# 3               Middle  Не требуется               3
# 4               Middle  Не требуется               2
# 5               Senior  Не требуется               0
# ...                ...           ...             ...
# 1194            Middle  Не требуется               2
# 1195            Middle            B2               2
# 1196  Middle-to-Senior  Не требуется               1
# 1197            Middle  Не требуется               3
# 1199            Senior  Не требуется               0
#
#                                                   stack  \
# 1                                         Python, CI/CD
# 2                                                   NaN
# 3     1С: Предприятие 8, 1С:PM Управление проектами ...
# 4     Google Analytics, Яндекс.Метрика, Excel, Power...
# 5                             Golang, PostgreSQL, Redis
# ...                                                 ...
# 1194                                         C++, Linux
# 1195                                                NaN
# 1196                                             1С ERP
# 1197  1С:Управление Торговлей 8, 1С:УПП, 1С:ERP, BPM...
# 1199                                                C++
#
#                                             description     salary
# 1     Стремитесь выбирать хорошие архитектурные реше... 335,000.00
# 2     Разработка и внедрение стратегии развития CRM-... 410,500.00
# 3     Быть единой точкой архитектурных решений за ко... 300,000.00
# 4     Поддерживать и развивать партнерские отношения... 175,000.00
# 5     Задача юнита Support Systems — создание и подд... 385,000.00
# ...                                                 ...        ...
# 1194  С++ 20 для части системы, принимающей торговые... 350,000.00
# 1195  Поиск Product Market Fit и определение стратег... 200,000.00
# 1196  Проведение обследования, сбор и анализ требова... 200,000.00
# 1197  Сбор, формализация, систематизация и анализ би... 200,000.00
# 1199  Развитие собственного языка MQL5 (входит в рей... 465,000.00
#
# [1098 rows x 13 columns]

# %%
plt.figure(figsize=(16, 3))
sns.boxplot(x=get_match_df["salary"])
plt.xlabel("Зарплата (RUB)")
plt.title("Распределение зарплат")
plt.grid(axis="x")

# %%
get_match_df['salary'].describe()
# Out:
# count     1,098.00
# mean    295,828.32
# std     107,351.25
# min      45,000.00
# 25%     220,000.00
# 50%     300,000.00
# 75%     356,000.00
# max     600,000.00
# Name: salary, dtype: float64

# %%
plt.figure(figsize=(10, 5))
sns.scatterplot(x="english_level", y="salary", data=get_match_df)
plt.xlabel("Уровень английского")
plt.ylabel("Медианная зарплата (RUB)")
plt.title("Влияние уровня английского на зарплату")
plt.xticks(rotation=45)
plt.grid(axis="y")

# %% [markdown]
# # API HH py

# %%
data_hh = pd.read_csv('hh_ru_df.csv')
data_hh.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19121 entries, 0 to 19120
# Data columns (total 46 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   id                         19121 non-null  int64
#  1   premium                    19121 non-null  bool
#  2   name                       19121 non-null  object
#  3   department                 884 non-null    object
#  4   has_test                   19121 non-null  bool
#  5   response_letter_required   19121 non-null  bool
#  6   area                       19121 non-null  object
#  7   salary                     19121 non-null  object
#  8   type                       19121 non-null  object
#  9   address                    13214 non-null  object
#  10  response_url               0 non-null      float64
#  11  sort_point_distance        0 non-null      float64
#  12  published_at               19121 non-null  object
#  13  created_at                 19121 non-null  object
#  14  archived                   19121 non-null  bool
#  15  apply_alternate_url        19121 non-null  object
#  16  show_logo_in_search        3638 non-null   object
#  17  insider_interview          65 non-null     object
#  18  url                        19121 non-null  object
#  19  alternate_url              19121 non-null  object
#  20  relations                  19121 non-null  object
#  21  employer                   19121 non-null  object
#  22  snippet                    19121 non-null  object
#  23  contacts                   0 non-null      float64
#  24  schedule                   19121 non-null  object
#  25  working_days               19121 non-null  object
#  26  working_time_intervals     19121 non-null  object
#  27  working_time_modes         19121 non-null  object
#  28  accept_temporary           19121 non-null  bool
#  29  fly_in_fly_out_duration    19121 non-null  object
#  30  work_format                19121 non-null  object
#  31  working_hours              19121 non-null  object
#  32  work_schedule_by_days      19121 non-null  object
#  33  night_shifts               19121 non-null  bool
#  34  professional_roles         19121 non-null  object
#  35  accept_incomplete_resumes  19121 non-null  bool
#  36  experience                 19121 non-null  object
#  37  employment                 19121 non-null  object
#  38  employment_form            19121 non-null  object
#  39  internship                 19121 non-null  bool
#  40  adv_response_url           0 non-null      float64
#  41  is_adv_vacancy             19121 non-null  bool
#  42  adv_context                0 non-null      float64
#  43  branding                   3696 non-null   object
#  44  video_vacancy              15 non-null     object
#  45  brand_snippet              6 non-null      object
# dtypes: bool(9), float64(5), int64(1), object(31)
# memory usage: 5.6+ MB
# <ipython-input-231-5a3b72c4a558>:1: DtypeWarning: Columns (45) have mixed types. Specify dtype option on import or set low_memory=False.
#   data_hh = pd.read_csv('hh_ru_df.csv')

# %%
# Удаляем ненужные столбцы
columns_to_drop = [
    'id',
    'premium',
    'published_at',
    'created_at',
    'department',
    'archived',
    'is_adv_vacancy',
    "response_url",
    "sort_point_distance",
    "insider_interview",
    "contacts",
    "adv_response_url",
    "adv_context",
    'branding',
    'fly_in_fly_out_duration',
    'accept_incomplete_resumes',
    'accept_temporary',
    'contacts',
    'insider_interview',
    'url',
    'show_logo_in_search',
    'alternate_url',
    'has_test',
    'apply_alternate_url',
    'working_days',
    'relations',
    'working_time_modes',
    'response_letter_required',
    'internship',
    'night_shifts',
    'working_time_intervals',
    'address',
    'snippet',
    'video_vacancy',
    'brand_snippet'
]

data_hh_cleaned = data_hh.drop(columns=columns_to_drop)
data_hh_cleaned.head()
# Out:
#                       name                                               area  \
# 0          Junior аналитик  {'id': '2', 'name': 'Санкт-Петербург', 'url': ...
# 1              BI-аналитик  {'id': '1', 'name': 'Москва', 'url': 'https://...
# 2  Младший аналитик данных  {'id': '2', 'name': 'Санкт-Петербург', 'url': ...
# 3  Аналитик данных в Excel  {'id': '1', 'name': 'Москва', 'url': 'https://...
# 4      Аналитик баз данных  {'id': '88', 'name': 'Казань', 'url': 'https:/...
#
#                                               salary  \
# 0  {'from': 80000, 'to': None, 'currency': 'RUR',...
# 1  {'from': 400000, 'to': None, 'currency': 'RUR'...
# 2  {'from': 30000, 'to': 40000, 'currency': 'RUR'...
# 3  {'from': 50000, 'to': None, 'currency': 'RUR',...
# 4  {'from': 45000, 'to': 80000, 'currency': 'RUR'...
#
#                                  type  \
# 0  {'id': 'open', 'name': 'Открытая'}
# 1  {'id': 'open', 'name': 'Открытая'}
# 2  {'id': 'open', 'name': 'Открытая'}
# 3  {'id': 'open', 'name': 'Открытая'}
# 4  {'id': 'open', 'name': 'Открытая'}
#
#                                             employer  \
# 0  {'id': '2484910', 'name': 'Агентство судебного...
# 1  {'id': '2066667', 'name': 'Топассистент', 'url...
# 2  {'id': '4138182', 'name': 'Topface Media', 'ur...
# 3  {'id': '738608', 'name': 'Genesis', 'url': 'ht...
# 4  {'id': '2420094', 'name': 'RentHouse', 'url': ...
#
#                                        schedule  \
# 0      {'id': 'fullDay', 'name': 'Полный день'}
# 1      {'id': 'fullDay', 'name': 'Полный день'}
# 2      {'id': 'fullDay', 'name': 'Полный день'}
# 3  {'id': 'remote', 'name': 'Удаленная работа'}
# 4  {'id': 'remote', 'name': 'Удаленная работа'}
#
#                                          work_format  \
# 0               [{'id': 'HYBRID', 'name': 'Гибрид'}]
# 1                                                 []
# 2  [{'id': 'ON_SITE', 'name': 'На\xa0месте работо...
# 3             [{'id': 'REMOTE', 'name': 'Удалённо'}]
# 4             [{'id': 'REMOTE', 'name': 'Удалённо'}]
#
#                                        working_hours  \
# 0          [{'id': 'HOURS_8', 'name': '8\xa0часов'}]
# 1          [{'id': 'HOURS_8', 'name': '8\xa0часов'}]
# 2          [{'id': 'HOURS_8', 'name': '8\xa0часов'}]
# 3                [{'id': 'OTHER', 'name': 'Другое'}]
# 4  [{'id': 'HOURS_4', 'name': '4\xa0часа'}, {'id'...
#
#                                work_schedule_by_days  \
# 0         [{'id': 'FIVE_ON_TWO_OFF', 'name': '5/2'}]
# 1         [{'id': 'FIVE_ON_TWO_OFF', 'name': '5/2'}]
# 2         [{'id': 'FIVE_ON_TWO_OFF', 'name': '5/2'}]
# 3                [{'id': 'OTHER', 'name': 'Другое'}]
# 4  [{'id': 'FIVE_ON_TWO_OFF', 'name': '5/2'}, {'i...
#
#                                   professional_roles  \
# 0  [{'id': '156', 'name': 'BI-аналитик, аналитик ...
# 1  [{'id': '156', 'name': 'BI-аналитик, аналитик ...
# 2  [{'id': '156', 'name': 'BI-аналитик, аналитик ...
# 3  [{'id': '156', 'name': 'BI-аналитик, аналитик ...
# 4  [{'id': '156', 'name': 'BI-аналитик, аналитик ...
#
#                                           experience  \
# 0        {'id': 'noExperience', 'name': 'Нет опыта'}
# 1    {'id': 'between3And6', 'name': 'От 3 до 6 лет'}
# 2        {'id': 'noExperience', 'name': 'Нет опыта'}
# 3  {'id': 'between1And3', 'name': 'От 1 года до 3...
# 4  {'id': 'between1And3', 'name': 'От 1 года до 3...
#
#                                       employment  \
# 0     {'id': 'full', 'name': 'Полная занятость'}
# 1     {'id': 'full', 'name': 'Полная занятость'}
# 2     {'id': 'full', 'name': 'Полная занятость'}
# 3  {'id': 'part', 'name': 'Частичная занятость'}
# 4  {'id': 'part', 'name': 'Частичная занятость'}
#
#                        employment_form
# 0     {'id': 'FULL', 'name': 'Полная'}
# 1     {'id': 'FULL', 'name': 'Полная'}
# 2     {'id': 'FULL', 'name': 'Полная'}
# 3  {'id': 'PART', 'name': 'Частичная'}
# 4  {'id': 'PART', 'name': 'Частичная'}

# %%
data_hh_cleaned['area'] = data_hh_cleaned['area'].apply(lambda x: x.split("'name': '")[1].split("'")[0] if isinstance(x, str) and "'name': '" in x else None)
data_hh_cleaned['type'] = data_hh_cleaned['type'].apply(lambda x: x.split("'name': '")[1].split("'")[0] if isinstance(x, str) and "'name': '" in x else None)
data_hh_cleaned['schedule'] = data_hh_cleaned['schedule'].apply(lambda x: x.split("'name': '")[1].split("'")[0] if isinstance(x, str) and "'name': '" in x else None)
data_hh_cleaned['work_format'] = data_hh_cleaned['work_format'].apply(lambda x: x.split("'name': '")[1].split("'")[0] if isinstance(x, str) and "'name': '" in x else None)
data_hh_cleaned['working_hours'] = data_hh_cleaned['working_hours'].apply(lambda x: x.split("'name': '")[1].split("'")[0] if isinstance(x, str) and "'name': '" in x else None)
data_hh_cleaned['work_schedule_by_days'] = data_hh_cleaned['work_schedule_by_days'].apply(lambda x: x.split("'name': '")[1].split("'")[0] if isinstance(x, str) and "'name': '" in x else None)
data_hh_cleaned['experience'] = data_hh_cleaned['experience'].apply(lambda x: x.split("'name': '")[1].split("'")[0] if isinstance(x, str) and "'name': '" in x else None)
data_hh_cleaned['employment'] = data_hh_cleaned['employment'].apply(lambda x: x.split("'name': '")[1].split("'")[0] if isinstance(x, str) and "'name': '" in x else None)
data_hh_cleaned['employment_form'] = data_hh_cleaned['employment_form'].apply(lambda x: x.split("'name': '")[1].split("'")[0] if isinstance(x, str) and "'name': '" in x else None)
data_hh_cleaned['professional_roles'] = data_hh_cleaned['professional_roles'].apply(
    lambda x: ", ".join([part.split("'name': '")[1].split("'")[0] for part in x.split("}, {") if "'name': '" in part])
    if isinstance(x, str) and "'name': '" in x else None
)
data_hh_cleaned['employer'] = data_hh_cleaned['employer'].apply(
    lambda x: x.split("'name': '")[1].split("'")[0] if isinstance(x, str) and "'name': '" in x else None
)

data_hh_cleaned
# Out:
#                                                   name             area  \
# 0                                      Junior аналитик  Санкт-Петербург
# 1                                          BI-аналитик           Москва
# 2                              Младший аналитик данных  Санкт-Петербург
# 3                              Аналитик данных в Excel           Москва
# 4                                  Аналитик баз данных           Казань
# ...                                                ...              ...
# 19116                Автор работ по промышленной химии            Томск
# 19117                Автор работ по промышленной химии        Волгоград
# 19118                             Технический писатель           Москва
# 19119  Автор студенческих работ (технический писатель)           Москва
# 19120  Автор студенческих работ (технический писатель)           Казань
#
#                                                   salary      type  \
# 0      {'from': 80000, 'to': None, 'currency': 'RUR',...  Открытая
# 1      {'from': 400000, 'to': None, 'currency': 'RUR'...  Открытая
# 2      {'from': 30000, 'to': 40000, 'currency': 'RUR'...  Открытая
# 3      {'from': 50000, 'to': None, 'currency': 'RUR',...  Открытая
# 4      {'from': 45000, 'to': 80000, 'currency': 'RUR'...  Открытая
# ...                                                  ...       ...
# 19116  {'from': None, 'to': 90000, 'currency': 'RUR',...  Открытая
# 19117  {'from': None, 'to': 90000, 'currency': 'RUR',...  Открытая
# 19118  {'from': 60000, 'to': None, 'currency': 'RUR',...  Открытая
# 19119  {'from': 70000, 'to': 150000, 'currency': 'RUR...  Открытая
# 19120  {'from': 70000, 'to': 150000, 'currency': 'RUR...  Открытая
#
#                                        employer          schedule  \
# 0                 Агентство судебного взыскания       Полный день
# 1                                  Топассистент       Полный день
# 2                                 Topface Media       Полный день
# 3                                       Genesis  Удаленная работа
# 4                                     RentHouse  Удаленная работа
# ...                                         ...               ...
# 19116                                  Homework  Удаленная работа
# 19117                                  Homework  Удаленная работа
# 19118  Научно-Производственное предприятие СГЭП       Полный день
# 19119                                  Студворк  Удаленная работа
# 19120                                  Студворк  Удаленная работа
#
#                     work_format working_hours work_schedule_by_days  \
# 0                        Гибрид    8\xa0часов                   5/2
# 1                          None    8\xa0часов                   5/2
# 2      На\xa0месте работодателя    8\xa0часов                   5/2
# 3                      Удалённо        Другое                Другое
# 4                      Удалённо     4\xa0часа                   5/2
# ...                         ...           ...                   ...
# 19116                  Удалённо     4\xa0часа                   5/2
# 19117                  Удалённо     4\xa0часа                   5/2
# 19118  На\xa0месте работодателя    8\xa0часов                   5/2
# 19119                  Удалённо    8\xa0часов                   5/2
# 19120                  Удалённо    8\xa0часов                   5/2
#
#                  professional_roles          experience           employment  \
# 0      BI-аналитик, аналитик данных           Нет опыта     Полная занятость
# 1      BI-аналитик, аналитик данных       От 3 до 6 лет     Полная занятость
# 2      BI-аналитик, аналитик данных           Нет опыта     Полная занятость
# 3      BI-аналитик, аналитик данных  От 1 года до 3 лет  Частичная занятость
# 4      BI-аналитик, аналитик данных  От 1 года до 3 лет  Частичная занятость
# ...                             ...                 ...                  ...
# 19116          Технический писатель  От 1 года до 3 лет  Частичная занятость
# 19117          Технический писатель  От 1 года до 3 лет  Частичная занятость
# 19118          Технический писатель  От 1 года до 3 лет     Полная занятость
# 19119          Технический писатель  От 1 года до 3 лет     Полная занятость
# 19120          Технический писатель  От 1 года до 3 лет     Полная занятость
#
#       employment_form
# 0              Полная
# 1              Полная
# 2              Полная
# 3           Частичная
# 4           Частичная
# ...               ...
# 19116       Частичная
# 19117       Частичная
# 19118          Полная
# 19119          Полная
# 19120          Полная
#
# [19121 rows x 13 columns]

# %%
# Функция для вычисления среднего значения зарплаты в столбце Salary
def extract_salary_avg(salary):
    if isinstance(salary, str) and "'from':" in salary:
        from_value = salary.split("'from': ")[1].split(",")[0] if "'from':" in salary else None
        to_value = salary.split("'to': ")[1].split(",")[0] if "'to':" in salary else None

        # Преобразуем в числа, если возможно
        from_value = int(from_value) if from_value and from_value != "None" else None
        to_value = int(to_value) if to_value and to_value != "None" else None

        # Если есть и "от", и "до", берём среднее
        if from_value is not None and to_value is not None:
            return (from_value + to_value) / 2
        # Если есть только "от", берём его
        elif from_value is not None:
            return from_value
        # Если есть только "до", берём его
        elif to_value is not None:
            return to_value

    return None  # Если данных нет

data_hh_cleaned['salary'] = data_hh_cleaned['salary'].apply(extract_salary_avg)
data_hh_cleaned
# Out:
#                                                   name             area  \
# 0                                      Junior аналитик  Санкт-Петербург
# 1                                          BI-аналитик           Москва
# 2                              Младший аналитик данных  Санкт-Петербург
# 3                              Аналитик данных в Excel           Москва
# 4                                  Аналитик баз данных           Казань
# ...                                                ...              ...
# 19116                Автор работ по промышленной химии            Томск
# 19117                Автор работ по промышленной химии        Волгоград
# 19118                             Технический писатель           Москва
# 19119  Автор студенческих работ (технический писатель)           Москва
# 19120  Автор студенческих работ (технический писатель)           Казань
#
#           salary      type                                  employer  \
# 0      80,000.00  Открытая             Агентство судебного взыскания
# 1     400,000.00  Открытая                              Топассистент
# 2      35,000.00  Открытая                             Topface Media
# 3      50,000.00  Открытая                                   Genesis
# 4      62,500.00  Открытая                                 RentHouse
# ...          ...       ...                                       ...
# 19116  90,000.00  Открытая                                  Homework
# 19117  90,000.00  Открытая                                  Homework
# 19118  60,000.00  Открытая  Научно-Производственное предприятие СГЭП
# 19119 110,000.00  Открытая                                  Студворк
# 19120 110,000.00  Открытая                                  Студворк
#
#                schedule               work_format working_hours  \
# 0           Полный день                    Гибрид    8\xa0часов
# 1           Полный день                      None    8\xa0часов
# 2           Полный день  На\xa0месте работодателя    8\xa0часов
# 3      Удаленная работа                  Удалённо        Другое
# 4      Удаленная работа                  Удалённо     4\xa0часа
# ...                 ...                       ...           ...
# 19116  Удаленная работа                  Удалённо     4\xa0часа
# 19117  Удаленная работа                  Удалённо     4\xa0часа
# 19118       Полный день  На\xa0месте работодателя    8\xa0часов
# 19119  Удаленная работа                  Удалённо    8\xa0часов
# 19120  Удаленная работа                  Удалённо    8\xa0часов
#
#       work_schedule_by_days            professional_roles          experience  \
# 0                       5/2  BI-аналитик, аналитик данных           Нет опыта
# 1                       5/2  BI-аналитик, аналитик данных       От 3 до 6 лет
# 2                       5/2  BI-аналитик, аналитик данных           Нет опыта
# 3                    Другое  BI-аналитик, аналитик данных  От 1 года до 3 лет
# 4                       5/2  BI-аналитик, аналитик данных  От 1 года до 3 лет
# ...                     ...                           ...                 ...
# 19116                   5/2          Технический писатель  От 1 года до 3 лет
# 19117                   5/2          Технический писатель  От 1 года до 3 лет
# 19118                   5/2          Технический писатель  От 1 года до 3 лет
# 19119                   5/2          Технический писатель  От 1 года до 3 лет
# 19120                   5/2          Технический писатель  От 1 года до 3 лет
#
#                 employment employment_form
# 0         Полная занятость          Полная
# 1         Полная занятость          Полная
# 2         Полная занятость          Полная
# 3      Частичная занятость       Частичная
# 4      Частичная занятость       Частичная
# ...                    ...             ...
# 19116  Частичная занятость       Частичная
# 19117  Частичная занятость       Частичная
# 19118     Полная занятость          Полная
# 19119     Полная занятость          Полная
# 19120     Полная занятость          Полная
#
# [19121 rows x 13 columns]

# %%
data_hh_cleaned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19121 entries, 0 to 19120
# Data columns (total 13 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   name                   19121 non-null  object
#  1   area                   19121 non-null  object
#  2   salary                 19121 non-null  float64
#  3   type                   19121 non-null  object
#  4   employer               19117 non-null  object
#  5   schedule               19121 non-null  object
#  6   work_format            13564 non-null  object
#  7   working_hours          19119 non-null  object
#  8   work_schedule_by_days  19121 non-null  object
#  9   professional_roles     19121 non-null  object
#  10  experience             19121 non-null  object
#  11  employment             19121 non-null  object
#  12  employment_form        19121 non-null  object
# dtypes: float64(1), object(12)
# memory usage: 1.9+ MB

# %%
data_hh_cleaned['work_format'].value_counts()
# Out:
# work_format
# На\xa0месте работодателя    8297
# Удалённо                    4126
# Гибрид                       880
# Разъездной                   261
# Name: count, dtype: int64

# %%
data_hh_cleaned['employer'].nunique()
# Out:
# 11002

# %%
# @title salary
plt.figure(figsize=(16, 5))
sns.boxplot(x=data_hh_cleaned["salary"])
plt.xlabel("Зарплата (RUB)")
plt.title("Распределение зарплат")
plt.grid(axis="x")

# %%
data_hh_cleaned["salary"].describe().apply(lambda x: f'{x:,.0f}')
# Out:
# count        19,121
# mean        121,751
# std         215,914
# min              12
# 25%          65,000
# 50%         100,000
# 75%         150,000
# max      27,600,000
# Name: salary, dtype: object

# %%
data_hh_cleaned[data_hh_cleaned["salary"] == 27600000]
# Out:
#                          name    area        salary      type    employer  \
# 2767  Старший бизнес-аналитик  Москва 27,600,000.00  Открытая  DAILY MAIL
#
#          schedule work_format working_hours work_schedule_by_days  \
# 2767  Полный день        None    8\xa0часов                   5/2
#
#      professional_roles     experience        employment employment_form
# 2767    Бизнес-аналитик  От 3 до 6 лет  Полная занятость          Полная

# %%
# Вычисление границ IQR
Q1, Q3 = data_hh_cleaned['salary'].quantile([0.25, 0.75])
IQR = Q3 - Q1
нижняя_граница, верхняя_граница = Q1 - 1.5 * IQR, Q3 + 1.5 * IQR

# Отсеивание выбросов
data_hh_cleaned = data_hh_cleaned[(data_hh_cleaned['salary'] >= нижняя_граница) & (data_hh_cleaned['salary'] <= верхняя_граница)]
data_hh_cleaned
# Out:
#                                                   name             area  \
# 0                                      Junior аналитик  Санкт-Петербург
# 2                              Младший аналитик данных  Санкт-Петербург
# 3                              Аналитик данных в Excel           Москва
# 4                                  Аналитик баз данных           Казань
# 5                       Специалист по работе с данными           Москва
# ...                                                ...              ...
# 19116                Автор работ по промышленной химии            Томск
# 19117                Автор работ по промышленной химии        Волгоград
# 19118                             Технический писатель           Москва
# 19119  Автор студенческих работ (технический писатель)           Москва
# 19120  Автор студенческих работ (технический писатель)           Казань
#
#           salary      type                                           employer  \
# 0      80,000.00  Открытая                      Агентство судебного взыскания
# 2      35,000.00  Открытая                                      Topface Media
# 3      50,000.00  Открытая                                            Genesis
# 4      62,500.00  Открытая                                          RentHouse
# 5     100,000.00  Открытая  АНО Университет Национальной Технологической И...
# ...          ...       ...                                                ...
# 19116  90,000.00  Открытая                                           Homework
# 19117  90,000.00  Открытая                                           Homework
# 19118  60,000.00  Открытая           Научно-Производственное предприятие СГЭП
# 19119 110,000.00  Открытая                                           Студворк
# 19120 110,000.00  Открытая                                           Студворк
#
#                schedule               work_format working_hours  \
# 0           Полный день                    Гибрид    8\xa0часов
# 2           Полный день  На\xa0месте работодателя    8\xa0часов
# 3      Удаленная работа                  Удалённо        Другое
# 4      Удаленная работа                  Удалённо     4\xa0часа
# 5      Удаленная работа                  Удалённо    8\xa0часов
# ...                 ...                       ...           ...
# 19116  Удаленная работа                  Удалённо     4\xa0часа
# 19117  Удаленная работа                  Удалённо     4\xa0часа
# 19118       Полный день  На\xa0месте работодателя    8\xa0часов
# 19119  Удаленная работа                  Удалённо    8\xa0часов
# 19120  Удаленная работа                  Удалённо    8\xa0часов
#
#       work_schedule_by_days            professional_roles          experience  \
# 0                       5/2  BI-аналитик, аналитик данных           Нет опыта
# 2                       5/2  BI-аналитик, аналитик данных           Нет опыта
# 3                    Другое  BI-аналитик, аналитик данных  От 1 года до 3 лет
# 4                       5/2  BI-аналитик, аналитик данных  От 1 года до 3 лет
# 5                       5/2  BI-аналитик, аналитик данных  От 1 года до 3 лет
# ...                     ...                           ...                 ...
# 19116                   5/2          Технический писатель  От 1 года до 3 лет
# 19117                   5/2          Технический писатель  От 1 года до 3 лет
# 19118                   5/2          Технический писатель  От 1 года до 3 лет
# 19119                   5/2          Технический писатель  От 1 года до 3 лет
# 19120                   5/2          Технический писатель  От 1 года до 3 лет
#
#                 employment employment_form
# 0         Полная занятость          Полная
# 2         Полная занятость          Полная
# 3      Частичная занятость       Частичная
# 4      Частичная занятость       Частичная
# 5         Полная занятость          Полная
# ...                    ...             ...
# 19116  Частичная занятость       Частичная
# 19117  Частичная занятость       Частичная
# 19118     Полная занятость          Полная
# 19119     Полная занятость          Полная
# 19120     Полная занятость          Полная
#
# [17836 rows x 13 columns]

# %%
data_hh_cleaned["salary"].describe()
# Out:
# count    17,836.00
# mean    104,233.82
# std      56,522.83
# min          12.50
# 25%      61,500.00
# 50%      90,000.00
# 75%     140,000.00
# max     255,000.00
# Name: salary, dtype: float64

# %%
plt.figure(figsize=(16, 5))
sns.boxplot(x=data_hh_cleaned["salary"])
plt.xlabel("Зарплата (RUB)")
plt.title("Распределение зарплат")
plt.grid(axis="x")

# %%
# @title experience

from matplotlib import pyplot as plt
import seaborn as sns
data_hh_cleaned.groupby('experience').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
# @title work_format

data_hh_cleaned.groupby('work_format').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
# @title schedule

data_hh_cleaned.groupby('schedule').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
# @title Гипотеза 1. Влияние опыта на уровень зарплаты
# Группируем данные по опыту и считаем среднюю зарплату
experience_salary = data_hh_cleaned.groupby("experience")["salary"].median().reset_index()

# Строим график зависимости зарплаты от опыта
plt.figure(figsize=(10, 5))
sns.barplot(x="experience", y="salary", data=experience_salary, order=[
    "Нет опыта", "От 1 года до 3 лет", "От 3 до 6 лет", "Более 6 лет"
], palette='Blues')
plt.xlabel("Опыт работы")
plt.ylabel("Медианная зарплата (RUB)")
plt.title("Влияние опыта на уровень зарплаты")
plt.xticks(rotation=45)
plt.grid(axis="y")

# Отображаем график
plt.show()
# Out:
# <ipython-input-153-6a3ac092c762>:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x="experience", y="salary", data=experience_salary, order=[

# %%
# @title Гипотеза 2. В Москве и Санкт-Петербурге средняя зарплата выше, чем в других регионах
# Группируем данные по городам и считаем среднюю зарплату
city_salary = data_hh_cleaned.groupby("area")["salary"].median().reset_index()

# Отбираем топ-20 городов с наибольшим количеством вакансий
top_cities = data_hh_cleaned["area"].value_counts().head(20).index
city_salary = city_salary[city_salary["area"].isin(top_cities)]

# Строим график
plt.figure(figsize=(12, 6))
sns.barplot(x="salary", y="area", data=city_salary, order=top_cities, palette='crest')
plt.xlabel("Медианная зарплата (RUB)")
plt.ylabel("Город")
plt.title("Сравнение медианной зарплаты в разных городах")
plt.grid(axis="x")

# Отображаем график
plt.show()
# Out:
# <ipython-input-154-88c5abc5d9a5>:11: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x="salary", y="area", data=city_salary, order=top_cities, palette='crest')

# %% [markdown]
# Во Владивостоке высокая зарплата. Почему?

# %%
# Фильтруем данные по Владивостоку
vladivostok_data = data_hh_cleaned[data_hh_cleaned["area"] == "Владивосток"]

# Строим боксплот зарплат во Владивостоке
plt.figure(figsize=(15, 5))
sns.boxplot(x=vladivostok_data["salary"])
plt.xlabel("Зарплата (RUB)")
plt.title("Распределение зарплат во Владивостоке")
plt.grid(axis="x")

# %%
# Анализируем распределение зарплат во Владивостоке
vladivostok_data["salary"].describe()
# Out:
# count       213.00
# mean    109,372.92
# std      43,454.50
# min       1,000.00
# 25%      77,500.00
# 50%     100,000.00
# 75%     140,000.00
# max     250,000.00
# Name: salary, dtype: float64

# %% [markdown]
# 25% - 77,500 рублей, это значит, что во Владивостоке в большинстве своем высокая ожидаемая заработная плата.

# %%
# Анализируем профессии во Владивостоке
vladivostok_data["professional_roles"].value_counts()
# Out:
# professional_roles
# Руководитель проектов                           27
# Специалист по информационной безопасности       26
# Системный администратор                         23
# Специалист технической поддержки                22
# Аналитик                                        18
# Программист, разработчик                        14
# Менеджер продукта                               11
# Сетевой инженер                                 10
# Технический директор (CTO)                       9
# Дизайнер, художник                               9
# Системный аналитик                               8
# Системный инженер                                7
# BI-аналитик, аналитик данных                     7
# Руководитель группы разработки                   5
# Бизнес-аналитик                                  5
# Тестировщик                                      3
# Дата-сайентист                                   2
# Продуктовый аналитик                             2
# Руководитель отдела аналитики                    1
# DevOps-инженер                                   1
# Методолог                                        1
# Директор по информационным технологиям (CIO)     1
# Гейм-дизайнер                                    1
# Name: count, dtype: int64

# %% [markdown]
# Нет никакой аномалии, это значит, что высокий спрос на специалистов в IT и управлении, в последствии высокая зарплата, может быть связан со спецификой региона, так как Владивосток — крупный порт и бизнес-центр Дальнего Востока

# %%
# @title Самая полулярная профессия
data_hh_cleaned['name'].value_counts().head(5)
# Out:
# name
# Системный администратор                      1015
# Специалист технической поддержки              316
# Графический дизайнер                          296
# Специалист по информационной безопасности     189
# Дизайнер                                      159
# Name: count, dtype: int64

# %%
syst_adm = data_hh_cleaned[data_hh_cleaned['name'] == 'Системный администратор']
syst_adm
# Out:
#                           name                           area     salary  \
# 5202   Системный администратор                      Махачкала  75,000.00
# 7155   Системный администратор                       Смоленск 100,000.00
# 7628   Системный администратор  Подольск (Московская область) 100,000.00
# 7808   Системный администратор                         Рязань  48,000.00
# 9580   Системный администратор                Санкт-Петербург  80,000.00
# ...                        ...                            ...        ...
# 17397  Системный администратор                       Владимир  50,000.00
# 17475  Системный администратор                         Москва  92,000.00
# 17498  Системный администратор               Великий Новгород  83,000.00
# 17706  Системный администратор                      Волгоград  27,500.00
# 17798  Системный администратор                         Тамбов  51,984.00
#
#            type                                           employer  \
# 5202   Открытая                               Махачкалатеплосервис
# 7155   Открытая                                      Романишин СМК
# 7628   Открытая                                     ДЖЕЙКЕТ РАБОТА
# 7808   Открытая                     ГБУ РО ОДКБ им. Н.В.Дмитриевой
# 9580   Открытая                                                Скс
# ...         ...                                                ...
# 17397  Открытая  МИНИСТЕРСТВО ПРИРОДОПОЛЬЗОВАНИЯ И ЭКОЛОГИИ ВЛА...
# 17475  Открытая                                            РАСВЭРО
# 17498  Открытая                             МАГНИТ, Розничная сеть
# 17706  Открытая  Филиал ФКУ Налог-Сервис ФНС России по ЦОД в г....
# 17798  Открытая                                      ИНТЕР РАО ОЦО
#
#           schedule               work_format working_hours  \
# 5202   Полный день  На\xa0месте работодателя    8\xa0часов
# 7155   Полный день  На\xa0месте работодателя    8\xa0часов
# 7628   Полный день                      None    8\xa0часов
# 7808   Полный день                      None    8\xa0часов
# 9580   Полный день  На\xa0месте работодателя    8\xa0часов
# ...            ...                       ...           ...
# 17397  Полный день  На\xa0месте работодателя    8\xa0часов
# 17475  Полный день  На\xa0месте работодателя    8\xa0часов
# 17498  Полный день                Разъездной    8\xa0часов
# 17706  Полный день                      None    8\xa0часов
# 17798  Полный день  На\xa0месте работодателя    8\xa0часов
#
#       work_schedule_by_days                            professional_roles  \
# 5202                    5/2  Директор по информационным технологиям (CIO)
# 7155                    5/2                      Программист, разработчик
# 7628                    5/2                      Программист, разработчик
# 7808                    5/2                      Программист, разработчик
# 9580                    5/2                         Руководитель проектов
# ...                     ...                                           ...
# 17397                   5/2              Специалист технической поддержки
# 17475                   5/2              Специалист технической поддержки
# 17498                   5/2              Специалист технической поддержки
# 17706                   5/2              Специалист технической поддержки
# 17798                   5/2              Специалист технической поддержки
#
#                experience        employment employment_form
# 5202   От 1 года до 3 лет  Полная занятость          Полная
# 7155   От 1 года до 3 лет  Полная занятость          Полная
# 7628   От 1 года до 3 лет  Полная занятость          Полная
# 7808            Нет опыта  Полная занятость          Полная
# 9580        От 3 до 6 лет  Полная занятость          Полная
# ...                   ...               ...             ...
# 17397           Нет опыта  Полная занятость          Полная
# 17475  От 1 года до 3 лет  Полная занятость          Полная
# 17498           Нет опыта  Полная занятость          Полная
# 17706           Нет опыта  Полная занятость          Полная
# 17798           Нет опыта  Полная занятость          Полная
#
# [1015 rows x 13 columns]

# %%
syst_adm.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1015 entries, 5202 to 17798
# Data columns (total 13 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   name                   1015 non-null   object
#  1   area                   1015 non-null   object
#  2   salary                 1015 non-null   float64
#  3   type                   1015 non-null   object
#  4   employer               1014 non-null   object
#  5   schedule               1015 non-null   object
#  6   work_format            670 non-null    object
#  7   working_hours          1015 non-null   object
#  8   work_schedule_by_days  1015 non-null   object
#  9   professional_roles     1015 non-null   object
#  10  experience             1015 non-null   object
#  11  employment             1015 non-null   object
#  12  employment_form        1015 non-null   object
# dtypes: float64(1), object(12)
# memory usage: 111.0+ KB

# %%
adm_area = syst_adm['area'].value_counts()
adm_area = adm_area.drop(adm_area[adm_area < 40].index)
adm_area
# Out:
# area
# Москва             178
# Санкт-Петербург    116
# Name: count, dtype: int64

# %%
msk_spb_adm = syst_adm[syst_adm['area'].isin(['Москва', 'Санкт-Петербург'])]
msk_spb_adm
# Out:
#                           name             area     salary      type  \
# 9580   Системный администратор  Санкт-Петербург  80,000.00  Открытая
# 11283  Системный администратор  Санкт-Петербург 130,000.00  Открытая
# 11450  Системный администратор           Москва  80,000.00  Открытая
# 11468  Системный администратор           Москва 210,000.00  Открытая
# 11472  Системный администратор  Санкт-Петербург 150,000.00  Открытая
# ...                        ...              ...        ...       ...
# 15200  Системный администратор  Санкт-Петербург  88,500.00  Открытая
# 16245  Системный администратор           Москва  77,500.00  Открытая
# 16539  Системный администратор  Санкт-Петербург  85,000.00  Открытая
# 17211  Системный администратор           Москва 150,000.00  Открытая
# 17475  Системный администратор           Москва  92,000.00  Открытая
#
#                 employer          schedule               work_format  \
# 9580                 Скс       Полный день  На\xa0месте работодателя
# 11283  Бизнес Технологии       Полный день  На\xa0месте работодателя
# 11450   Доступный Сервис       Полный день  На\xa0месте работодателя
# 11468               ЮТИМ       Полный день                    Гибрид
# 11472                ГДС  Удаленная работа                      None
# ...                  ...               ...                       ...
# 15200         ГСР Энерго       Полный день                      None
# 16245          Альфасофт       Полный день  На\xa0месте работодателя
# 16539           МЕГАТЭКС       Полный день  На\xa0месте работодателя
# 17211                 РБ       Полный день  На\xa0месте работодателя
# 17475            РАСВЭРО       Полный день  На\xa0месте работодателя
#
#       working_hours work_schedule_by_days  \
# 9580     8\xa0часов                   5/2
# 11283    8\xa0часов                   5/2
# 11450       9 часов                   5/2
# 11468    8\xa0часов                   5/2
# 11472    8\xa0часов                   5/2
# ...             ...                   ...
# 15200    8\xa0часов                   5/2
# 16245    8\xa0часов                   5/2
# 16539    8\xa0часов                   5/2
# 17211       9 часов                   5/2
# 17475    8\xa0часов                   5/2
#
#                               professional_roles          experience  \
# 9580                       Руководитель проектов       От 3 до 6 лет
# 11283                            Сетевой инженер       От 3 до 6 лет
# 11450                    Системный администратор  От 1 года до 3 лет
# 11468                    Системный администратор       От 3 до 6 лет
# 11472                    Системный администратор  От 1 года до 3 лет
# ...                                          ...                 ...
# 15200  Специалист по информационной безопасности  От 1 года до 3 лет
# 16245           Специалист технической поддержки           Нет опыта
# 16539           Специалист технической поддержки  От 1 года до 3 лет
# 17211           Специалист технической поддержки       От 3 до 6 лет
# 17475           Специалист технической поддержки  От 1 года до 3 лет
#
#              employment employment_form
# 9580   Полная занятость          Полная
# 11283  Полная занятость          Полная
# 11450  Полная занятость          Полная
# 11468  Полная занятость          Полная
# 11472  Полная занятость          Полная
# ...                 ...             ...
# 15200  Полная занятость          Полная
# 16245  Полная занятость          Полная
# 16539  Полная занятость          Полная
# 17211  Полная занятость          Полная
# 17475  Полная занятость          Полная
#
# [294 rows x 13 columns]

# %%
plt.figure(figsize=(12, 5))
plt.grid()
sns.violinplot(data=msk_spb_adm, x='experience', y='salary', hue='area', split=True, palette=['m','c'])
plt.ylabel("Медианная зарплата (RUB)")
plt.xlabel("Опыт работы")
plt.title("Сравнение ЗП системных администраторов по опыту работы в Москве и Санкт-Петербурге")
# Out:
# Text(0.5, 1.0, 'Сравнение ЗП системных администраторов по опыту работы в Москве и Санкт-Петербурге')

# %%
# @title Гипотеза 5. Разница зарплат между профессиями
# Группируем данные по профессиональным ролям и считаем медианную зарплату
role_salary = data_hh_cleaned.groupby("professional_roles")["salary"].median().reset_index()

# Отбираем топ-30 профессий с наибольшим количеством вакансий
top_roles = data_hh_cleaned["professional_roles"].value_counts().head(30).index
role_salary = role_salary[role_salary["professional_roles"].isin(top_roles)]

# Строим горизонтальный барплот
plt.figure(figsize=(12, 6))
sns.barplot(x="salary", y="professional_roles", data=role_salary, order=top_roles, palette="cubehelix")
plt.xlabel("Медианная зарплата (RUB)")
plt.ylabel("Профессиональная роль")
plt.title("Сравнение медианной зарплаты по профессиональным ролям")
plt.grid(axis="x")
# Out:
# <ipython-input-167-0b032e66e68d>:11: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x="salary", y="professional_roles", data=role_salary, order=top_roles, palette="cubehelix")

# %%
get_match_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1137 entries, 0 to 1199
# Data columns (total 13 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   title            1137 non-null   object
#  1   company          1069 non-null   object
#  2   locations        836 non-null    object
#  3   type             1137 non-null   object
#  4   relocation       1137 non-null   int64
#  5   relocation_help  1137 non-null   int64
#  6   specialization   1137 non-null   object
#  7   level            1137 non-null   object
#  8   english_level    1137 non-null   object
#  9   min_experience   1137 non-null   int64
#  10  stack            1006 non-null   object
#  11  description      1012 non-null   object
#  12  salary           1137 non-null   float64
# dtypes: float64(1), int64(3), object(9)
# memory usage: 124.4+ KB

# %%
data_hh_cleaned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 17836 entries, 0 to 19120
# Data columns (total 13 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   name                   17836 non-null  object
#  1   area                   17836 non-null  object
#  2   salary                 17836 non-null  float64
#  3   type                   17836 non-null  object
#  4   employer               17832 non-null  object
#  5   schedule               17836 non-null  object
#  6   work_format            12651 non-null  object
#  7   working_hours          17834 non-null  object
#  8   work_schedule_by_days  17836 non-null  object
#  9   professional_roles     17836 non-null  object
#  10  experience             17836 non-null  object
#  11  employment             17836 non-null  object
#  12  employment_form        17836 non-null  object
# dtypes: float64(1), object(12)
# memory usage: 1.9+ MB

# %%
get_match_df.head(5)
# Out:
#                                                title  \
# 0                   Senior DevOps/DevSecOps Engineer
# 1  Разработчик на Python (Непрерывная интеграция ...
# 2  Ведущий продакт-менеджер экосистемы по взаимод...
# 3     Архитектор продукта (1С: Управление проектами)
# 4                                  Affiliate Manager
#
#                      company  \
# 0                  Collectly
# 1  Яндекс (Поисковый портал)
# 2                      Avito
# 3                   Гринатом
# 4                    Winline
#
#                                            locations    type  relocation  \
# 0  Бразилия, Сербия, Аргентина, Черногория, Испан...  remote           0
# 1                                             Москва  hybrid           0
# 2                                             Москва  remote           0
# 3                                             Москва  hybrid           0
# 4                                             Москва  hybrid           0
#
#    relocation_help                                     specialization   level  \
# 0                0                      DevOps / Information Security  Senior
# 1                0                                             Python  Middle
# 2                0                                    Product Manager  Senior
# 3                0                                                 1C  Middle
# 4                0  Product Analyst / Product Manager / Project Ma...  Middle
#
#   english_level  min_experience  \
# 0            B2               0
# 1  Не требуется               3
# 2  Не требуется               0
# 3  Не требуется               3
# 4  Не требуется               2
#
#                                                stack  \
# 0  Ansible, Terraform, CI/CD, AWS/Azure/GCP, Jenk...
# 1                                      Python, CI/CD
# 2                                                NaN
# 3  1С: Предприятие 8, 1С:PM Управление проектами ...
# 4  Google Analytics, Яндекс.Метрика, Excel, Power...
#
#                                          description     salary
# 0  Design, develop, and maintain robust infrastru... 623,000.00
# 1  Стремитесь выбирать хорошие архитектурные реше... 335,000.00
# 2  Разработка и внедрение стратегии развития CRM-... 410,500.00
# 3  Быть единой точкой архитектурных решений за ко... 300,000.00
# 4  Поддерживать и развивать партнерские отношения... 175,000.00

# %%
data_hh_cleaned.head(5)
# Out:
#                              name             area     salary      type  \
# 0                 Junior аналитик  Санкт-Петербург  80,000.00  Открытая
# 2         Младший аналитик данных  Санкт-Петербург  35,000.00  Открытая
# 3         Аналитик данных в Excel           Москва  50,000.00  Открытая
# 4             Аналитик баз данных           Казань  62,500.00  Открытая
# 5  Специалист по работе с данными           Москва 100,000.00  Открытая
#
#                                             employer          schedule  \
# 0                      Агентство судебного взыскания       Полный день
# 2                                      Topface Media       Полный день
# 3                                            Genesis  Удаленная работа
# 4                                          RentHouse  Удаленная работа
# 5  АНО Университет Национальной Технологической И...  Удаленная работа
#
#                 work_format working_hours work_schedule_by_days  \
# 0                    Гибрид    8\xa0часов                   5/2
# 2  На\xa0месте работодателя    8\xa0часов                   5/2
# 3                  Удалённо        Другое                Другое
# 4                  Удалённо     4\xa0часа                   5/2
# 5                  Удалённо    8\xa0часов                   5/2
#
#              professional_roles          experience           employment  \
# 0  BI-аналитик, аналитик данных           Нет опыта     Полная занятость
# 2  BI-аналитик, аналитик данных           Нет опыта     Полная занятость
# 3  BI-аналитик, аналитик данных  От 1 года до 3 лет  Частичная занятость
# 4  BI-аналитик, аналитик данных  От 1 года до 3 лет  Частичная занятость
# 5  BI-аналитик, аналитик данных  От 1 года до 3 лет     Полная занятость
#
#   employment_form
# 0          Полная
# 2          Полная
# 3       Частичная
# 4       Частичная
# 5          Полная

# %%
common_rows = get_match_df.merge(data_hh_cleaned, left_on=["title", "company"], right_on=["name", "employer"], how="inner")
common_rows
# Out:
#                                              title        company  \
# 0                          Системный администратор            NaN
# 1      Senior Data Scientist (Recommender Systems)        FunCorp
# 2                           Senior QA (WholeSaler)       Островок
# 3  Middle Fullstack Developer (React.js + Node.js)  Linked Helper
# 4                                  Тестировщик RPA           СГМК
# 5                                  Тестировщик RPA           СГМК
# 6                Специалист поддержки рабочих мест  Газпром нефть
# 7                Специалист поддержки рабочих мест  Газпром нефть
#
#                    locations  type_x  relocation  relocation_help  \
# 0                     Москва  hybrid           0                0
# 1                    Лимасол  remote           0                0
# 2                        NaN  remote           0                0
# 3                        NaN  remote           0                0
# 4  Екатеринбург, Новокузнецк  hybrid           0                0
# 5  Екатеринбург, Новокузнецк  hybrid           0                0
# 6            Санкт-Петербург  hybrid           0                0
# 7            Санкт-Петербург  hybrid           0                0
#
#         specialization   level english_level  min_experience  ...    type_y  \
# 0     Support Engineer  Junior  Не требуется               1  ...  Открытая
# 1       Data Scientist  Senior  Не требуется               3  ...  Открытая
# 2              QA Auto  Senior            B1               3  ...  Открытая
# 3              Node.js  Middle            B1               2  ...  Открытая
# 4  QA Manual / QA Auto  Middle  Не требуется               1  ...  Открытая
# 5  QA Manual / QA Auto  Middle  Не требуется               1  ...  Открытая
# 6     Support Engineer  Middle  Не требуется               1  ...  Открытая
# 7     Support Engineer  Middle  Не требуется               1  ...  Открытая
#
#         employer          schedule               work_format working_hours  \
# 0           None       Полный день  На\xa0месте работодателя    8\xa0часов
# 1        FunCorp  Удаленная работа                  Удалённо    8\xa0часов
# 2       Островок       Полный день                      None    8\xa0часов
# 3  Linked Helper  Удаленная работа                  Удалённо    8\xa0часов
# 4           СГМК       Полный день  На\xa0месте работодателя    8\xa0часов
# 5           СГМК       Полный день                      None    8\xa0часов
# 6  Газпром нефть       Полный день  На\xa0месте работодателя    8\xa0часов
# 7  Газпром нефть       Полный день  На\xa0месте работодателя    8\xa0часов
#
#    work_schedule_by_days                professional_roles  \
# 0                    5/2           Системный администратор
# 1                    5/2                    Дата-сайентист
# 2                    5/2                       Тестировщик
# 3                    5/2          Программист, разработчик
# 4                    5/2                       Тестировщик
# 5                    5/2                       Тестировщик
# 6                    5/2  Специалист технической поддержки
# 7                    5/2  Специалист технической поддержки
#
#            experience        employment employment_form
# 0  От 1 года до 3 лет  Полная занятость          Полная
# 1       От 3 до 6 лет  Полная занятость          Полная
# 2       От 3 до 6 лет  Полная занятость          Полная
# 3  От 1 года до 3 лет  Полная занятость          Полная
# 4  От 1 года до 3 лет  Полная занятость          Полная
# 5  От 1 года до 3 лет  Полная занятость          Полная
# 6           Нет опыта  Полная занятость          Полная
# 7  От 1 года до 3 лет  Полная занятость          Полная
#
# [8 rows x 26 columns]

# %%
df = get_match_df.merge(data_hh_cleaned, how="outer")
df
# Out:
#                                           title                company  \
# 0      Инженер внутренней технической поддержки                     T2
# 1                               Тестировщик RPA                   СГМК
# 2                 Инженер технической поддержки             Galileosky
# 3                      Инженер мониторинга (L1)                 Nexign
# 4              Специалист технической поддержки  Лучи (ex. BestDoctor)
# ...                                         ...                    ...
# 18968                                       NaN                    NaN
# 18969                                       NaN                    NaN
# 18970                                       NaN                    NaN
# 18971                                       NaN                    NaN
# 18972                                       NaN                    NaN
#
#                              locations      type  relocation  relocation_help  \
# 0      Нижний Новгород, Ростов-на-Дону    hybrid        0.00             0.00
# 1            Екатеринбург, Новокузнецк    hybrid        0.00             0.00
# 2                                Пермь    hybrid        0.00             0.00
# 3                      Санкт-Петербург    hybrid        0.00             0.00
# 4                               Москва    hybrid        0.00             0.00
# ...                                ...       ...         ...              ...
# 18968                              NaN  Открытая         NaN              NaN
# 18969                              NaN  Открытая         NaN              NaN
# 18970                              NaN  Открытая         NaN              NaN
# 18971                              NaN  Открытая         NaN              NaN
# 18972                              NaN  Открытая         NaN              NaN
#
#             specialization   level english_level  min_experience  ...  \
# 0         Suppоrt Engineer  Middle  Не требуется            0.00  ...
# 1      QA Manual / QA Auto  Middle  Не требуется            1.00  ...
# 2         Suppоrt Engineer  Middle            B2            1.00  ...
# 3         Support Engineer  Middle  Не требуется            1.00  ...
# 4         Support Engineer  Junior  Не требуется            0.00  ...
# ...                    ...     ...           ...             ...  ...
# 18968                  NaN     NaN           NaN             NaN  ...
# 18969                  NaN     NaN           NaN             NaN  ...
# 18970                  NaN     NaN           NaN             NaN  ...
# 18971                  NaN     NaN           NaN             NaN  ...
# 18972                  NaN     NaN           NaN             NaN  ...
#
#                   area                 employer          schedule  \
# 0                  NaN                      NaN               NaN
# 1                  NaN                      NaN               NaN
# 2                  NaN                      NaN               NaN
# 3                  NaN                      NaN               NaN
# 4                  NaN                      NaN               NaN
# ...                ...                      ...               ...
# 18968           Москва  Рылова Мария Евгеньевна  Удаленная работа
# 18969        Челябинск                 1C-Рарус  Удаленная работа
# 18970           Москва            Платформа ОФД       Полный день
# 18971  Санкт-Петербург                 Эстелинк       Полный день
# 18972              Уфа                      РНГ       Полный день
#
#                     work_format working_hours work_schedule_by_days  \
# 0                           NaN           NaN                   NaN
# 1                           NaN           NaN                   NaN
# 2                           NaN           NaN                   NaN
# 3                           NaN           NaN                   NaN
# 4                           NaN           NaN                   NaN
# ...                         ...           ...                   ...
# 18968                  Удалённо    8\xa0часов                   5/2
# 18969  На\xa0месте работодателя    8\xa0часов                   5/2
# 18970                      None    8\xa0часов                   5/2
# 18971                      None    8\xa0часов                   5/2
# 18972                      None    8\xa0часов                   5/2
#
#              professional_roles          experience        employment  \
# 0                           NaN                 NaN               NaN
# 1                           NaN                 NaN               NaN
# 2                           NaN                 NaN               NaN
# 3                           NaN                 NaN               NaN
# 4                           NaN                 NaN               NaN
# ...                         ...                 ...               ...
# 18968  Программист, разработчик       От 3 до 6 лет  Полная занятость
# 18969     Руководитель проектов       От 3 до 6 лет  Полная занятость
# 18970   Системный администратор  От 1 года до 3 лет  Полная занятость
# 18971        Системный аналитик       От 3 до 6 лет  Полная занятость
# 18972         Системный инженер       От 3 до 6 лет  Полная занятость
#
#       employment_form
# 0                 NaN
# 1                 NaN
# 2                 NaN
# 3                 NaN
# 4                 NaN
# ...               ...
# 18968          Полная
# 18969          Полная
# 18970          Полная
# 18971          Полная
# 18972          Полная
#
# [18973 rows x 24 columns]

# %%
#этот код длится 15 часов и это больше лимита сессии
import os
import time
import logging
import requests
from tqdm import tqdm

full_vacancies = []
max_retries = 5  #ограничиваем число попыток

for vac in tqdm(vacancies):
    vac_id = vac['id']
    attempt = 0

    while attempt < max_retries:
        try:
            response = requests.get(os.path.join(url, vac_id), headers=HEADERS, params=params)

            if response.status_code == 404:
                logging.warning(f"Vacancy {vac_id} not found. Skipping.")
                break  #пропускаем и не повторяем запрос

            response.raise_for_status()  #вызывает ошибку для 4xx и 5xx

            full_vacancies.append(response.json())  #успешный запрос
            time.sleep(2)  #увеличиваем задержку между запросами
            break

        except requests.exceptions.RequestException as e:
            logging.warning(f"Error: {e}, retrying in {20 * (attempt + 1)} seconds...")
            time.sleep(20 * (attempt + 1))  #увеличиваем время ожидания
            attempt += 1

logging.warning(f'Parsed all {len(full_vacancies)} vacancies')

hh_ru_df = pd.DataFrame(full_vacancies)
hh_ru_df.to_csv('data_mnogo.csv', index=False)
# Out:
#   1%|          | 158/18832 [08:04<15:20:15,  2.96s/it]WARNING:root:Error: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response')), retrying in 20 seconds...
#   1%|▏         | 246/18832 [12:59<15:43:04,  3.04s/it]WARNING:root:Error: ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer')), retrying in 20 seconds...
#   2%|▏         | 444/18832 [23:49<16:26:52,  3.22s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-16-6d97b1701bd3> in <cell line: 0>()
#      23
#      24             full_vacancies.append(response.json())  # Успешный запрос
# ---> 25             time.sleep(2)  # Увеличил задержку между запросами
#      26             break
#      27
#
# KeyboardInterrupt:
